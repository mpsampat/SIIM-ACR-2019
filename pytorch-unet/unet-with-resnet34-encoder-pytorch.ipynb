# %% [markdown]
# This Kernel uses UNet architecture with ResNet34 encoder, I've used [segmentation_models.pytorch](https://github.com/qubvel/segmentation_models.pytorch) library which has many inbuilt segmentation architectures. This kernel is inspired by [Yury](https://www.kaggle.com/deyury)'s discussion thread [here](https://www.kaggle.com/c/siim-acr-pneumothorax-segmentation/discussion/99440#591985). I've used snippets from multiple other public kernels I've given due credits at the end of this notebook.
#
# What's down below?
#
# * UNet with imagenet pretrained ResNet34 architecture
# * Training on 512x512 sized images/masks with Standard Augmentations
# * MixedLoss (weighted sum of Focal loss and dice loss)
# * Gradient Accumulution

# %%
#!pip install git+https://github.com/qubvel/segmentation_models.pytorch > /dev/null 2>&1 # run bash cmd without output.

# %%
import os
import cv2
import pdb
import time
import warnings
import random
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold
import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader, Dataset, sampler
from matplotlib import pyplot as plt
from albumentations import (HorizontalFlip, ShiftScaleRotate, Normalize, Resize, Compose, GaussNoise)
from albumentations.torch import ToTensor
import segmentation_models_pytorch as smp
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Utility functions

# %%
def run_length_decode(rle, height=1024, width=1024, fill_value=1):
    component = np.zeros((height, width), np.float32)
    component = component.reshape(-1)
    rle = np.array([int(s) for s in rle.strip().split(' ')])
    rle = rle.reshape(-1, 2)
    start = 0
    for index, length in rle:
        start = start+index
        end = start+length
        component[start: end] = fill_value
        start = end
    component = component.reshape(width, height).T
    return component

def run_length_encode(component):
    component = component.T.flatten()
    start = np.where(component[1:] > component[:-1])[0]+1
    end = np.where(component[:-1] > component[1:])[0]+1
    length = end-start
    rle = []
    for i in range(len(length)):
        if i == 0:
            rle.extend([start[0], length[0]])
        else:
            rle.extend([start[i]-end[i-1], length[i]])
    rle = ' '.join([str(r) for r in rle])
    return rle

# %% [markdown]
# ## Dataloader

# %%
class SIIMDataset(Dataset):
    def __init__(self, df, data_folder, size, mean, std, phase):
        self.df = df
        self.root = data_folder
        self.size = size
        self.mean = mean
        self.std = std
        self.phase = phase
        self.transforms = get_transforms(phase, size, mean, std)
        self.gb = self.df.groupby('ImageId')
        self.fnames = list(self.gb.groups.keys())

    def __getitem__(self, idx):
        image_id = self.fnames[idx]
        df = self.gb.get_group(image_id)
        annotations = df[' EncodedPixels'].tolist()
        image_path = os.path.join(self.root, image_id + ".png")
        image = cv2.imread(image_path)
        mask = np.zeros([1024, 1024])
        if annotations[0] != '-1':
            for rle in annotations:
                mask += run_length_decode(rle)
        mask = (mask >= 1).astype('float32') # for overlap cases
        augmented = self.transforms(image=image, mask=mask)
        image = augmented['image']
        mask = augmented['mask']
        return image, mask

    def __len__(self):
        return len(self.fnames)


def get_transforms(phase, size, mean, std):
    list_transforms = []
    if phase == "train":
        list_transforms.extend(
            [
#                 HorizontalFlip(),
                ShiftScaleRotate(
                    shift_limit=0,  # no resizing
                    scale_limit=0.1,
                    rotate_limit=10, # rotate
                    p=0.5,
                    border_mode=cv2.BORDER_CONSTANT
                ),
#                 GaussNoise(),
            ]
        )
    list_transforms.extend(
        [
            Normalize(mean=mean, std=std, p=1),
            Resize(size, size),
            ToTensor(),
        ]
    )

    list_trfms = Compose(list_transforms)
    return list_trfms

def provider(
    fold,
    total_folds,
    data_folder,
    df_path,
    phase,
    size,
    mean=None,
    std=None,
    batch_size=8,
    num_workers=4,
):
    df = pd.read_csv(df_path)
    df = df.drop_duplicates('ImageId')
    df_with_mask = df[df[" EncodedPixels"] != " -1"]
    df_with_mask['has_mask'] = 1
    df_without_mask = df[df[" EncodedPixels"] != " -1"]
    df_without_mask['has_mask'] = 0
    df_without_mask_sampled = df_without_mask.sample(len(df_with_mask))
    df = pd.concat([df_with_mask, df_without_mask_sampled])
    #NOTE: equal number of positive and negative cases are chosen.
    
    kfold = StratifiedKFold(total_folds, shuffle=True, random_state=69)
    train_idx, val_idx = list(kfold.split(
        df["ImageId"], df["has_mask"]))[fold]
    train_df, val_df = df.iloc[train_idx], df.iloc[val_idx]
    df = train_df if phase == "train" else val_df
    # NOTE: total_folds=5 -> train/val : 80%/20%
    
    image_dataset = SIIMDataset(df, data_folder, size, mean, std, phase)

    dataloader = DataLoader(
        image_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=True,
        shuffle=True,
    )
    return dataloader

# %%
torch.cuda.set_device(1)
sample_submission_path = '../sample_submission.csv'
train_rle_path = '../train-rle.csv'
data_folder = "../data512/train"
test_data_folder = "../data512/test"

# %% [markdown]
# ### Dataloader sanity check

# %%
dataloader = provider(
    fold=0,
    total_folds=5,
    data_folder=data_folder,
    df_path=train_rle_path,
    phase="train",
    size=512,
    mean = (0.485, 0.456, 0.406),
    std = (0.229, 0.224, 0.225),
    batch_size=16,
    num_workers=4,
)

# %%
batch = next(iter(dataloader)) # get a batch from the dataloader
images, masks = batch

# %%
# plot some random images in the `batch`
idx = random.choice(range(16))
plt.imshow(images[idx][0], cmap='bone')
plt.imshow(masks[idx][0], alpha=0.2, cmap='Reds')
plt.show()

# %% [markdown]
# ## Losses
#
# This kernel uses a weighted sum of Focal Loss and Dice Loss, let's call it MixedLoss

# %%
def dice_loss(input, target):
    input = torch.sigmoid(input)
    smooth = 1.0
    iflat = input.view(-1)
    tflat = target.view(-1)
    intersection = (iflat * tflat).sum()
    return ((2.0 * intersection + smooth) / (iflat.sum() + tflat.sum() + smooth))


class FocalLoss(nn.Module):
    def __init__(self, gamma):
        super().__init__()
        self.gamma = gamma

    def forward(self, input, target):
        if not (target.size() == input.size()):
            raise ValueError("Target size ({}) must be the same as input size ({})"
                             .format(target.size(), input.size()))
        max_val = (-input).clamp(min=0)
        loss = input - input * target + max_val + \
            ((-max_val).exp() + (-input - max_val).exp()).log()
        invprobs = F.logsigmoid(-input * (target * 2.0 - 1.0))
        loss = (invprobs * self.gamma).exp() * loss
        return loss.mean()


class MixedLoss(nn.Module):
    def __init__(self, alpha, gamma):
        super().__init__()
        self.alpha = alpha
        self.focal = FocalLoss(gamma)

    def forward(self, input, target):
        loss = self.alpha*self.focal(input, target) - torch.log(dice_loss(input, target))
        return loss.mean()

# %% [markdown]
# ## Some more utility functions
#
# Here are some utility functions for calculating IoU and Dice scores

# %%
def predict(X, threshold):
    X_p = np.copy(X)
    preds = (X_p > threshold).astype('uint8')
    return preds

def metric(probability, truth, threshold=0.5, reduction='none'):
    '''Calculates dice of positive and negative images seperately'''
    '''probability and truth must be torch tensors'''
    batch_size = len(truth)
    with torch.no_grad():
        probability = probability.view(batch_size, -1)
        truth = truth.view(batch_size, -1)
        assert(probability.shape == truth.shape)

        p = (probability > threshold).float()
        t = (truth > 0.5).float()

        t_sum = t.sum(-1)
        p_sum = p.sum(-1)
        neg_index = torch.nonzero(t_sum == 0)
        pos_index = torch.nonzero(t_sum >= 1)

        dice_neg = (p_sum == 0).float()
        dice_pos = 2 * (p*t).sum(-1)/((p+t).sum(-1))

        dice_neg = dice_neg[neg_index]
        dice_pos = dice_pos[pos_index]
        dice = torch.cat([dice_pos, dice_neg])

        dice_neg = np.nan_to_num(dice_neg.mean().item(), 0)
        dice_pos = np.nan_to_num(dice_pos.mean().item(), 0)
        dice = dice.mean().item()

        num_neg = len(neg_index)
        num_pos = len(pos_index)

    return dice, dice_neg, dice_pos, num_neg, num_pos

class Meter:
    '''A meter to keep track of iou and dice scores throughout an epoch'''
    def __init__(self, phase, epoch):
        self.base_threshold = 0.5 # <<<<<<<<<<< here's the threshold
        self.base_dice_scores = []
        self.dice_neg_scores = []
        self.dice_pos_scores = []
        self.iou_scores = []

    def update(self, targets, outputs):
        probs = torch.sigmoid(outputs)
        dice, dice_neg, dice_pos, _, _ = metric(probs, targets, self.base_threshold)
        self.base_dice_scores.append(dice)
        self.dice_pos_scores.append(dice_pos)
        self.dice_neg_scores.append(dice_neg)
        preds = predict(probs, self.base_threshold)
        iou = compute_iou_batch(preds, targets, classes=[1])
        self.iou_scores.append(iou)

    def get_metrics(self):
        dice = np.mean(self.base_dice_scores)
        dice_neg = np.mean(self.dice_neg_scores)
        dice_pos = np.mean(self.dice_pos_scores)
        dices = [dice, dice_neg, dice_pos]
        iou = np.nanmean(self.iou_scores)
        return dices, iou

def epoch_log(phase, epoch, epoch_loss, meter, start):
    '''logging the metrics at the end of an epoch'''
    dices, iou = meter.get_metrics()
    dice, dice_neg, dice_pos = dices
    print("Loss: %0.4f | dice: %0.4f | dice_neg: %0.4f | dice_pos: %0.4f | IoU: %0.4f" % (epoch_loss, dice, dice_neg, dice_pos, iou))
    return dice, iou

def compute_ious(pred, label, classes, ignore_index=255, only_present=True):
    '''computes iou for one ground truth mask and predicted mask'''
    pred[label == ignore_index] = 0
    ious = []
    for c in classes:
        label_c = label == c
        if only_present and np.sum(label_c) == 0:
            ious.append(np.nan)
            continue
        pred_c = pred == c
        intersection = np.logical_and(pred_c, label_c).sum()
        union = np.logical_or(pred_c, label_c).sum()
        if union != 0:
            ious.append(intersection / union)
    return ious if ious else [1]


def compute_iou_batch(outputs, labels, classes=None):
    '''computes mean iou for a batch of ground truth masks and predicted masks'''
    ious = []
    preds = np.copy(outputs) # copy is imp
    labels = np.array(labels) # tensor to np
    for pred, label in zip(preds, labels):
        ious.append(np.nanmean(compute_ious(pred, label, classes)))
    iou = np.nanmean(ious)
    return iou

# %% [markdown]
# ## UNet with ResNet34 model
# Let's take a look at the model

# %%
model = smp.Unet("resnet34", encoder_weights="imagenet", activation=None)

# %%
model # a *deeper* look
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (decoder): UnetDecoder(
#     (layer1): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer2): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer3): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer4): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer5): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (final_conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## Model Training and validation

# %%
class Trainer(object):
    '''This class takes care of training and validation of our model'''
    def __init__(self, model):
        self.fold = 1
        self.total_folds = 5
        self.num_workers = 6
        self.batch_size = {"train": 4, "val": 4}
        self.accumulation_steps = 32 // self.batch_size['train']
        self.lr = 5e-4
        self.num_epochs = 75
        self.best_loss = float("inf")
        self.phases = ["train", "val"]
        self.device = torch.device("cuda:1")
        torch.set_default_tensor_type("torch.cuda.FloatTensor")
        self.net = model
        self.criterion = MixedLoss(10.0, 2.0)
        self.optimizer = optim.Adam(self.net.parameters(), lr=self.lr)
        self.scheduler = ReduceLROnPlateau(self.optimizer, mode="min", patience=3, verbose=True)
        self.net = self.net.to(self.device)
        cudnn.benchmark = True
        self.dataloaders = {
            phase: provider(
                fold=1,
                total_folds=5,
                data_folder=data_folder,
                df_path=train_rle_path,
                phase=phase,
                size=512,
                mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225),
                batch_size=self.batch_size[phase],
                num_workers=self.num_workers,
            )
            for phase in self.phases
        }
        self.losses = {phase: [] for phase in self.phases}
        self.iou_scores = {phase: [] for phase in self.phases}
        self.dice_scores = {phase: [] for phase in self.phases}
        
    def forward(self, images, targets):
        images = images.to(self.device)
        masks = targets.to(self.device)
        outputs = self.net(images)
        loss = self.criterion(outputs, masks)
        return loss, outputs

    def iterate(self, epoch, phase):
        meter = Meter(phase, epoch)
        start = time.strftime("%H:%M:%S")
        print(f"Starting epoch: {epoch} | phase: {phase} | ⏰: {start}")
        batch_size = self.batch_size[phase]
        self.net.train(phase == "train")
        dataloader = self.dataloaders[phase]
        running_loss = 0.0
        total_batches = len(dataloader)
#         tk0 = tqdm(dataloader, total=total_batches)
        self.optimizer.zero_grad()
        for itr, batch in enumerate(dataloader):
            images, targets = batch
            loss, outputs = self.forward(images, targets)
            loss = loss / self.accumulation_steps
            if phase == "train":
                loss.backward()
                if (itr + 1 ) % self.accumulation_steps == 0:
                    self.optimizer.step()
                    self.optimizer.zero_grad()
            running_loss += loss.item()
            outputs = outputs.detach().cpu()
            meter.update(targets, outputs)
#             tk0.set_postfix(loss=(running_loss / ((itr + 1))))
        epoch_loss = running_loss / total_batches
        dice, iou = epoch_log(phase, epoch, epoch_loss, meter, start)
        self.losses[phase].append(epoch_loss)
        self.dice_scores[phase].append(dice)
        self.iou_scores[phase].append(iou)
        torch.cuda.empty_cache()
        return epoch_loss

    def start(self):
        for epoch in range(self.num_epochs):
            self.iterate(epoch, "train")
            state = {
                "epoch": epoch,
                "best_loss": self.best_loss,
                "state_dict": self.net.state_dict(),
                "optimizer": self.optimizer.state_dict(),
            }
            val_loss = self.iterate(epoch, "val")
            self.scheduler.step(val_loss)
            if val_loss < self.best_loss:
                print("******** New optimal found, saving state ********")
                state["best_loss"] = self.best_loss = val_loss
                torch.save(state, "./model.pth")
            print()

# %%
model_trainer = Trainer(model)
model_trainer.start()
# Out:
# Starting epoch: 0 | phase: train | ⏰: 14:31:37
# Loss: 0.6998 | dice: 0.1120 | dice_neg: 0.0000 | dice_pos: 0.1120 | IoU: 0.0659
# Starting epoch: 0 | phase: val | ⏰: 14:34:26
# Loss: 0.4678 | dice: 0.2724 | dice_neg: 0.0000 | dice_pos: 0.2724 | IoU: 0.1806
# ******** New optimal found, saving state ********
#
# Starting epoch: 1 | phase: train | ⏰: 14:35:11
# Loss: 0.3630 | dice: 0.2937 | dice_neg: 0.0000 | dice_pos: 0.2937 | IoU: 0.1950
# Starting epoch: 1 | phase: val | ⏰: 14:37:56
# Loss: 0.3735 | dice: 0.3153 | dice_neg: 0.0000 | dice_pos: 0.3153 | IoU: 0.2116
# ******** New optimal found, saving state ********
#
# Starting epoch: 2 | phase: train | ⏰: 14:38:39
# Loss: 0.3212 | dice: 0.3376 | dice_neg: 0.0000 | dice_pos: 0.3376 | IoU: 0.2299
# Starting epoch: 2 | phase: val | ⏰: 14:41:22
# Loss: 0.3497 | dice: 0.3690 | dice_neg: 0.0000 | dice_pos: 0.3690 | IoU: 0.2578
# ******** New optimal found, saving state ********
#
# Starting epoch: 3 | phase: train | ⏰: 14:42:06
# Loss: 0.2860 | dice: 0.3698 | dice_neg: 0.0000 | dice_pos: 0.3698 | IoU: 0.2584
# Starting epoch: 3 | phase: val | ⏰: 14:44:51
# Loss: 0.2606 | dice: 0.4228 | dice_neg: 0.0000 | dice_pos: 0.4228 | IoU: 0.3050
# ******** New optimal found, saving state ********
#
# Starting epoch: 4 | phase: train | ⏰: 14:45:33
# Loss: 0.2544 | dice: 0.4048 | dice_neg: 0.0000 | dice_pos: 0.4048 | IoU: 0.2909
# Starting epoch: 4 | phase: val | ⏰: 14:48:18
# Loss: 0.2614 | dice: 0.4205 | dice_neg: 0.0000 | dice_pos: 0.4205 | IoU: 0.2981
#
# Starting epoch: 5 | phase: train | ⏰: 14:49:01
# Loss: 0.2264 | dice: 0.4310 | dice_neg: 0.0000 | dice_pos: 0.4310 | IoU: 0.3152
# Starting epoch: 5 | phase: val | ⏰: 14:51:44
# Loss: 0.2210 | dice: 0.4788 | dice_neg: 0.0000 | dice_pos: 0.4788 | IoU: 0.3557
# ******** New optimal found, saving state ********
#
# Starting epoch: 6 | phase: train | ⏰: 14:52:27
# Loss: 0.2041 | dice: 0.4441 | dice_neg: 0.0000 | dice_pos: 0.4441 | IoU: 0.3267
# Starting epoch: 6 | phase: val | ⏰: 14:55:12
# Loss: 0.2014 | dice: 0.4406 | dice_neg: 0.0000 | dice_pos: 0.4406 | IoU: 0.3225
# ******** New optimal found, saving state ********
#
# Starting epoch: 7 | phase: train | ⏰: 14:55:56
# Loss: 0.1842 | dice: 0.4575 | dice_neg: 0.0000 | dice_pos: 0.4575 | IoU: 0.3398
# Starting epoch: 7 | phase: val | ⏰: 14:58:40
# Loss: 0.1880 | dice: 0.4924 | dice_neg: 0.0000 | dice_pos: 0.4924 | IoU: 0.3728
# ******** New optimal found, saving state ********
#
# Starting epoch: 8 | phase: train | ⏰: 14:59:23
# Loss: 0.1659 | dice: 0.4741 | dice_neg: 0.0000 | dice_pos: 0.4741 | IoU: 0.3561
# Starting epoch: 8 | phase: val | ⏰: 15:02:05
# Loss: 0.1906 | dice: 0.5135 | dice_neg: 0.0000 | dice_pos: 0.5135 | IoU: 0.3939
#
# Starting epoch: 9 | phase: train | ⏰: 15:02:49
# Loss: 0.1497 | dice: 0.4837 | dice_neg: 0.0000 | dice_pos: 0.4837 | IoU: 0.3686
# Starting epoch: 9 | phase: val | ⏰: 15:05:34
# Loss: 0.3089 | dice: 0.5070 | dice_neg: 0.0000 | dice_pos: 0.5070 | IoU: 0.3843
#
# Starting epoch: 10 | phase: train | ⏰: 15:06:17
# Loss: 0.1361 | dice: 0.5060 | dice_neg: 0.0000 | dice_pos: 0.5060 | IoU: 0.3866
# Starting epoch: 10 | phase: val | ⏰: 15:09:02
# Loss: 0.1412 | dice: 0.5475 | dice_neg: 0.0000 | dice_pos: 0.5475 | IoU: 0.4265
# ******** New optimal found, saving state ********
#
# Starting epoch: 11 | phase: train | ⏰: 15:09:46
# Loss: 0.1255 | dice: 0.5045 | dice_neg: 0.0000 | dice_pos: 0.5045 | IoU: 0.3871
# Starting epoch: 11 | phase: val | ⏰: 15:12:28
# Loss: 0.1259 | dice: 0.5250 | dice_neg: 0.0000 | dice_pos: 0.5250 | IoU: 0.4108
# ******** New optimal found, saving state ********
#
# Starting epoch: 12 | phase: train | ⏰: 15:13:13
# Loss: 0.1156 | dice: 0.5218 | dice_neg: 0.0000 | dice_pos: 0.5218 | IoU: 0.4040
# Starting epoch: 12 | phase: val | ⏰: 15:15:57
# Loss: 0.1337 | dice: 0.5412 | dice_neg: 0.0000 | dice_pos: 0.5412 | IoU: 0.4245
#
# Starting epoch: 13 | phase: train | ⏰: 15:16:40
# Loss: 0.1122 | dice: 0.5155 | dice_neg: 0.0000 | dice_pos: 0.5155 | IoU: 0.3990
# Starting epoch: 13 | phase: val | ⏰: 15:19:23
# Loss: 0.1325 | dice: 0.5169 | dice_neg: 0.0000 | dice_pos: 0.5169 | IoU: 0.4010
#
# Starting epoch: 14 | phase: train | ⏰: 15:20:05
# Loss: 0.1101 | dice: 0.5195 | dice_neg: 0.0000 | dice_pos: 0.5198 | IoU: 0.4035
# Starting epoch: 14 | phase: val | ⏰: 15:22:52
# Loss: 0.1292 | dice: 0.5029 | dice_neg: 0.0000 | dice_pos: 0.5029 | IoU: 0.3839
#
# Starting epoch: 15 | phase: train | ⏰: 15:23:35
# Loss: 0.1042 | dice: 0.5281 | dice_neg: 0.0000 | dice_pos: 0.5281 | IoU: 0.4107
# Starting epoch: 15 | phase: val | ⏰: 15:26:19
# Loss: 0.1185 | dice: 0.5457 | dice_neg: 0.0000 | dice_pos: 0.5457 | IoU: 0.4298
# ******** New optimal found, saving state ********
#
# Starting epoch: 16 | phase: train | ⏰: 15:27:04
# Loss: 0.0904 | dice: 0.5544 | dice_neg: 0.0000 | dice_pos: 0.5544 | IoU: 0.4385
# Starting epoch: 16 | phase: val | ⏰: 15:29:47
# Loss: 0.0914 | dice: 0.5794 | dice_neg: 0.0000 | dice_pos: 0.5794 | IoU: 0.4585
# ******** New optimal found, saving state ********
#
# Starting epoch: 17 | phase: train | ⏰: 15:30:31
# Loss: 0.0870 | dice: 0.5595 | dice_neg: 0.0000 | dice_pos: 0.5595 | IoU: 0.4424
# Starting epoch: 17 | phase: val | ⏰: 15:33:15
# Loss: 0.0940 | dice: 0.5664 | dice_neg: 0.0000 | dice_pos: 0.5664 | IoU: 0.4510
#
# Starting epoch: 18 | phase: train | ⏰: 15:33:58
# Loss: 0.0896 | dice: 0.5517 | dice_neg: 0.0000 | dice_pos: 0.5517 | IoU: 0.4354
# Starting epoch: 18 | phase: val | ⏰: 15:36:40
# Loss: 0.0902 | dice: 0.5833 | dice_neg: 0.0000 | dice_pos: 0.5833 | IoU: 0.4667
# ******** New optimal found, saving state ********
#
# Starting epoch: 19 | phase: train | ⏰: 15:37:24
# Loss: 0.0826 | dice: 0.5750 | dice_neg: 0.0000 | dice_pos: 0.5752 | IoU: 0.4576
# Starting epoch: 19 | phase: val | ⏰: 15:40:08
# Loss: 0.0968 | dice: 0.5977 | dice_neg: 0.0000 | dice_pos: 0.5977 | IoU: 0.4740
#
# Starting epoch: 20 | phase: train | ⏰: 15:40:53
# Loss: 0.0752 | dice: 0.5880 | dice_neg: 0.0000 | dice_pos: 0.5880 | IoU: 0.4700
# Starting epoch: 20 | phase: val | ⏰: 15:43:37
# Loss: 0.0736 | dice: 0.5896 | dice_neg: 0.0000 | dice_pos: 0.5896 | IoU: 0.4766
# ******** New optimal found, saving state ********
#
# Starting epoch: 21 | phase: train | ⏰: 15:44:20
# Loss: 0.0801 | dice: 0.5677 | dice_neg: 0.0000 | dice_pos: 0.5677 | IoU: 0.4523
# Starting epoch: 21 | phase: val | ⏰: 15:47:06
# Loss: 0.0778 | dice: 0.5662 | dice_neg: 0.0000 | dice_pos: 0.5662 | IoU: 0.4550
#
# Starting epoch: 22 | phase: train | ⏰: 15:47:48
# Loss: 0.0764 | dice: 0.5935 | dice_neg: 0.0000 | dice_pos: 0.5935 | IoU: 0.4748
# Starting epoch: 22 | phase: val | ⏰: 15:50:32
# Loss: 0.0827 | dice: 0.5717 | dice_neg: 0.0000 | dice_pos: 0.5717 | IoU: 0.4540
#
# Starting epoch: 23 | phase: train | ⏰: 15:51:16
# Loss: 0.0754 | dice: 0.5854 | dice_neg: 0.0000 | dice_pos: 0.5854 | IoU: 0.4691
# Starting epoch: 23 | phase: val | ⏰: 15:54:03
# Loss: 0.0675 | dice: 0.6186 | dice_neg: 0.0000 | dice_pos: 0.6186 | IoU: 0.5032
# ******** New optimal found, saving state ********
#
# Starting epoch: 24 | phase: train | ⏰: 15:54:46
# Loss: 0.0727 | dice: 0.5820 | dice_neg: 0.0000 | dice_pos: 0.5823 | IoU: 0.4679
# Starting epoch: 24 | phase: val | ⏰: 15:57:31
# Loss: 0.0687 | dice: 0.6250 | dice_neg: 0.0000 | dice_pos: 0.6250 | IoU: 0.5107
#
# Starting epoch: 25 | phase: train | ⏰: 15:58:15
# Loss: 0.0756 | dice: 0.5815 | dice_neg: 0.0000 | dice_pos: 0.5815 | IoU: 0.4654
# Starting epoch: 25 | phase: val | ⏰: 16:01:00
# Loss: 0.0726 | dice: 0.5900 | dice_neg: 0.0000 | dice_pos: 0.5900 | IoU: 0.4766
#
# Starting epoch: 26 | phase: train | ⏰: 16:01:43
# Loss: 0.0722 | dice: 0.5913 | dice_neg: 0.0000 | dice_pos: 0.5913 | IoU: 0.4748
# Starting epoch: 26 | phase: val | ⏰: 16:04:27
# Loss: 0.0624 | dice: 0.6333 | dice_neg: 0.0000 | dice_pos: 0.6333 | IoU: 0.5170
# ******** New optimal found, saving state ********
#
# Starting epoch: 27 | phase: train | ⏰: 16:05:11
# Loss: 0.0643 | dice: 0.6041 | dice_neg: 0.0000 | dice_pos: 0.6041 | IoU: 0.4896
# Starting epoch: 27 | phase: val | ⏰: 16:07:59
# Loss: 0.0615 | dice: 0.6390 | dice_neg: 0.0000 | dice_pos: 0.6390 | IoU: 0.5286
# ******** New optimal found, saving state ********
#
# Starting epoch: 28 | phase: train | ⏰: 16:08:44
# Loss: 0.0576 | dice: 0.6286 | dice_neg: 0.0000 | dice_pos: 0.6286 | IoU: 0.5144
# Starting epoch: 28 | phase: val | ⏰: 16:11:18
# Loss: 0.0671 | dice: 0.6338 | dice_neg: 0.0000 | dice_pos: 0.6338 | IoU: 0.5248
#
# Starting epoch: 29 | phase: train | ⏰: 16:11:53
# Loss: 0.0579 | dice: 0.6416 | dice_neg: 0.0000 | dice_pos: 0.6416 | IoU: 0.5259
# Starting epoch: 29 | phase: val | ⏰: 16:14:14
# Loss: 0.0607 | dice: 0.6398 | dice_neg: 0.0000 | dice_pos: 0.6398 | IoU: 0.5232
# ******** New optimal found, saving state ********
#
# Starting epoch: 30 | phase: train | ⏰: 16:14:49
# Loss: 0.0707 | dice: 0.6043 | dice_neg: 0.0000 | dice_pos: 0.6043 | IoU: 0.4878
# Starting epoch: 30 | phase: val | ⏰: 16:17:10
# Loss: 0.0677 | dice: 0.6017 | dice_neg: 0.0000 | dice_pos: 0.6017 | IoU: 0.4880
#
# Starting epoch: 31 | phase: train | ⏰: 16:17:46
# Loss: 0.0679 | dice: 0.6022 | dice_neg: 0.0000 | dice_pos: 0.6022 | IoU: 0.4865
# Starting epoch: 31 | phase: val | ⏰: 16:20:07
# Loss: 0.0692 | dice: 0.6183 | dice_neg: 0.0000 | dice_pos: 0.6183 | IoU: 0.4978
#
# Starting epoch: 32 | phase: train | ⏰: 16:20:42
# Loss: 0.0706 | dice: 0.5991 | dice_neg: 0.0000 | dice_pos: 0.5991 | IoU: 0.4812
# Starting epoch: 32 | phase: val | ⏰: 16:23:03
# Loss: 0.0633 | dice: 0.6205 | dice_neg: 0.0000 | dice_pos: 0.6205 | IoU: 0.5083
#
# Starting epoch: 33 | phase: train | ⏰: 16:23:38
# Loss: 0.0643 | dice: 0.6095 | dice_neg: 0.0000 | dice_pos: 0.6095 | IoU: 0.4931
# Starting epoch: 33 | phase: val | ⏰: 16:25:59
# Loss: 0.0588 | dice: 0.6405 | dice_neg: 0.0000 | dice_pos: 0.6405 | IoU: 0.5252
# ******** New optimal found, saving state ********
#
# Starting epoch: 34 | phase: train | ⏰: 16:26:34
# Loss: 0.0658 | dice: 0.6106 | dice_neg: 0.0000 | dice_pos: 0.6106 | IoU: 0.4937
# Starting epoch: 34 | phase: val | ⏰: 16:28:55
# Loss: 0.0629 | dice: 0.6068 | dice_neg: 0.0000 | dice_pos: 0.6068 | IoU: 0.4982
#
# Starting epoch: 35 | phase: train | ⏰: 16:29:30
# Loss: 0.0577 | dice: 0.6368 | dice_neg: 0.0000 | dice_pos: 0.6368 | IoU: 0.5204
# Starting epoch: 35 | phase: val | ⏰: 16:32:15
# Loss: 0.0544 | dice: 0.6376 | dice_neg: 0.0000 | dice_pos: 0.6376 | IoU: 0.5299
# ******** New optimal found, saving state ********
#
# Starting epoch: 36 | phase: train | ⏰: 16:32:51
# Loss: 0.0594 | dice: 0.6336 | dice_neg: 0.0000 | dice_pos: 0.6336 | IoU: 0.5177
# Starting epoch: 36 | phase: val | ⏰: 16:35:10
# Loss: 0.0658 | dice: 0.6224 | dice_neg: 0.0000 | dice_pos: 0.6224 | IoU: 0.5092
#
# Starting epoch: 37 | phase: train | ⏰: 16:35:45
# Loss: 0.0535 | dice: 0.6421 | dice_neg: 0.0000 | dice_pos: 0.6421 | IoU: 0.5280
# Starting epoch: 37 | phase: val | ⏰: 16:38:04
# Loss: 0.0510 | dice: 0.6753 | dice_neg: 0.0000 | dice_pos: 0.6753 | IoU: 0.5629
# ******** New optimal found, saving state ********
#
# Starting epoch: 38 | phase: train | ⏰: 16:38:40
# Loss: 0.0492 | dice: 0.6667 | dice_neg: 0.0000 | dice_pos: 0.6667 | IoU: 0.5541
# Starting epoch: 38 | phase: val | ⏰: 16:41:01
# Loss: 0.0553 | dice: 0.6704 | dice_neg: 0.0000 | dice_pos: 0.6704 | IoU: 0.5647
#
# Starting epoch: 39 | phase: train | ⏰: 16:41:36
# Loss: 0.0473 | dice: 0.6761 | dice_neg: 0.0000 | dice_pos: 0.6761 | IoU: 0.5632
# Starting epoch: 39 | phase: val | ⏰: 16:43:55
# Loss: 0.0503 | dice: 0.6929 | dice_neg: 0.0000 | dice_pos: 0.6929 | IoU: 0.5809
# ******** New optimal found, saving state ********
#
# Starting epoch: 40 | phase: train | ⏰: 16:44:30
# Loss: 0.0564 | dice: 0.6392 | dice_neg: 0.0000 | dice_pos: 0.6392 | IoU: 0.5248
# Starting epoch: 40 | phase: val | ⏰: 16:46:51
# Loss: 0.0619 | dice: 0.6218 | dice_neg: 0.0000 | dice_pos: 0.6218 | IoU: 0.5096
#
# Starting epoch: 41 | phase: train | ⏰: 16:47:26
# Loss: 0.0564 | dice: 0.6380 | dice_neg: 0.0000 | dice_pos: 0.6380 | IoU: 0.5240
# Starting epoch: 41 | phase: val | ⏰: 16:49:47
# Loss: 0.0505 | dice: 0.6747 | dice_neg: 0.0000 | dice_pos: 0.6747 | IoU: 0.5665
#
# Starting epoch: 42 | phase: train | ⏰: 16:50:22
# Loss: 0.0496 | dice: 0.6699 | dice_neg: 0.0000 | dice_pos: 0.6699 | IoU: 0.5559
# Starting epoch: 42 | phase: val | ⏰: 16:52:43
# Loss: 0.0468 | dice: 0.6900 | dice_neg: 0.0000 | dice_pos: 0.6900 | IoU: 0.5828
# ******** New optimal found, saving state ********
#
# Starting epoch: 43 | phase: train | ⏰: 16:53:18
# Loss: 0.0456 | dice: 0.6834 | dice_neg: 0.0000 | dice_pos: 0.6834 | IoU: 0.5713
# Starting epoch: 43 | phase: val | ⏰: 16:55:36
# Loss: 0.0444 | dice: 0.7072 | dice_neg: 0.0000 | dice_pos: 0.7072 | IoU: 0.6019
# ******** New optimal found, saving state ********
#
# Starting epoch: 44 | phase: train | ⏰: 16:56:11
# Loss: 0.0419 | dice: 0.6994 | dice_neg: 0.0000 | dice_pos: 0.6994 | IoU: 0.5884
# Starting epoch: 44 | phase: val | ⏰: 16:58:30
# Loss: 0.0479 | dice: 0.6913 | dice_neg: 0.0000 | dice_pos: 0.6913 | IoU: 0.5911
#
# Starting epoch: 45 | phase: train | ⏰: 16:59:05
# Loss: 0.0437 | dice: 0.7002 | dice_neg: 0.0000 | dice_pos: 0.7002 | IoU: 0.5887
# Starting epoch: 45 | phase: val | ⏰: 17:01:24
# Loss: 0.0477 | dice: 0.6891 | dice_neg: 0.0000 | dice_pos: 0.6891 | IoU: 0.5814
#
# Starting epoch: 46 | phase: train | ⏰: 17:01:59
# Loss: 0.0475 | dice: 0.6730 | dice_neg: 0.0000 | dice_pos: 0.6730 | IoU: 0.5618
# Starting epoch: 46 | phase: val | ⏰: 17:04:18
# Loss: 0.0509 | dice: 0.6832 | dice_neg: 0.0000 | dice_pos: 0.6832 | IoU: 0.5781
#
# Starting epoch: 47 | phase: train | ⏰: 17:04:54
# Loss: 0.0431 | dice: 0.6901 | dice_neg: 0.0000 | dice_pos: 0.6901 | IoU: 0.5801
# Starting epoch: 47 | phase: val | ⏰: 17:07:14
# Loss: 0.0473 | dice: 0.6992 | dice_neg: 0.0000 | dice_pos: 0.6992 | IoU: 0.5928
# Epoch    47: reducing learning rate of group 0 to 5.0000e-05.
#
# Starting epoch: 48 | phase: train | ⏰: 17:07:49
# Loss: 0.0368 | dice: 0.7233 | dice_neg: 0.0000 | dice_pos: 0.7233 | IoU: 0.6178
# Starting epoch: 48 | phase: val | ⏰: 17:10:09
# Loss: 0.0390 | dice: 0.7272 | dice_neg: 0.0000 | dice_pos: 0.7272 | IoU: 0.6284
# ******** New optimal found, saving state ********
#
# Starting epoch: 49 | phase: train | ⏰: 17:10:44
# Loss: 0.0354 | dice: 0.7392 | dice_neg: 0.0000 | dice_pos: 0.7392 | IoU: 0.6349
# Starting epoch: 49 | phase: val | ⏰: 17:13:03
# Loss: 0.0461 | dice: 0.7155 | dice_neg: 0.0000 | dice_pos: 0.7155 | IoU: 0.6163
#
# Starting epoch: 50 | phase: train | ⏰: 17:13:39
# Loss: 0.0341 | dice: 0.7455 | dice_neg: 0.0000 | dice_pos: 0.7455 | IoU: 0.6412
# Starting epoch: 50 | phase: val | ⏰: 17:15:57
# Loss: 0.0416 | dice: 0.7248 | dice_neg: 0.0000 | dice_pos: 0.7248 | IoU: 0.6262
#
# Starting epoch: 51 | phase: train | ⏰: 17:16:33
# Loss: 0.0336 | dice: 0.7497 | dice_neg: 0.0000 | dice_pos: 0.7497 | IoU: 0.6466
# Starting epoch: 51 | phase: val | ⏰: 17:18:51
# Loss: 0.0392 | dice: 0.7355 | dice_neg: 0.0000 | dice_pos: 0.7355 | IoU: 0.6377
#
# Starting epoch: 52 | phase: train | ⏰: 17:19:27
# Loss: 0.0324 | dice: 0.7545 | dice_neg: 0.0000 | dice_pos: 0.7545 | IoU: 0.6530
# Starting epoch: 52 | phase: val | ⏰: 17:21:46
# Loss: 0.0379 | dice: 0.7449 | dice_neg: 0.0000 | dice_pos: 0.7449 | IoU: 0.6494
# ******** New optimal found, saving state ********
#
# Starting epoch: 53 | phase: train | ⏰: 17:22:20
# Loss: 0.0326 | dice: 0.7582 | dice_neg: 0.0000 | dice_pos: 0.7582 | IoU: 0.6549
# Starting epoch: 53 | phase: val | ⏰: 17:24:41
# Loss: 0.0412 | dice: 0.7373 | dice_neg: 0.0000 | dice_pos: 0.7373 | IoU: 0.6421
#
# Starting epoch: 54 | phase: train | ⏰: 17:25:16
# Loss: 0.0316 | dice: 0.7611 | dice_neg: 0.0000 | dice_pos: 0.7611 | IoU: 0.6589
# Starting epoch: 54 | phase: val | ⏰: 17:27:35
# Loss: 0.0424 | dice: 0.7370 | dice_neg: 0.0000 | dice_pos: 0.7370 | IoU: 0.6405
#
# Starting epoch: 55 | phase: train | ⏰: 17:28:10
# Loss: 0.0307 | dice: 0.7637 | dice_neg: 0.0000 | dice_pos: 0.7637 | IoU: 0.6624
# Starting epoch: 55 | phase: val | ⏰: 17:30:29
# Loss: 0.0398 | dice: 0.7438 | dice_neg: 0.0000 | dice_pos: 0.7438 | IoU: 0.6488
#
# Starting epoch: 56 | phase: train | ⏰: 17:31:04
# Loss: 0.0304 | dice: 0.7677 | dice_neg: 0.0000 | dice_pos: 0.7677 | IoU: 0.6658
# Starting epoch: 56 | phase: val | ⏰: 17:33:25
# Loss: 0.0458 | dice: 0.7389 | dice_neg: 0.0000 | dice_pos: 0.7389 | IoU: 0.6430
# Epoch    56: reducing learning rate of group 0 to 5.0000e-06.
#
# Starting epoch: 57 | phase: train | ⏰: 17:34:00
# Loss: 0.0302 | dice: 0.7686 | dice_neg: 0.0018 | dice_pos: 0.7689 | IoU: 0.6678
# Starting epoch: 57 | phase: val | ⏰: 17:36:21
# Loss: 0.0424 | dice: 0.7461 | dice_neg: 0.0000 | dice_pos: 0.7461 | IoU: 0.6520
#
# Starting epoch: 58 | phase: train | ⏰: 17:36:55
# Loss: 0.0301 | dice: 0.7665 | dice_neg: 0.0000 | dice_pos: 0.7665 | IoU: 0.6665
# Starting epoch: 58 | phase: val | ⏰: 17:39:15
# Loss: 0.0417 | dice: 0.7438 | dice_neg: 0.0000 | dice_pos: 0.7438 | IoU: 0.6487
#
# Starting epoch: 59 | phase: train | ⏰: 17:39:49
# Loss: 0.0304 | dice: 0.7662 | dice_neg: 0.0000 | dice_pos: 0.7662 | IoU: 0.6658
# Starting epoch: 59 | phase: val | ⏰: 17:42:10
# Loss: 0.0433 | dice: 0.7423 | dice_neg: 0.0000 | dice_pos: 0.7423 | IoU: 0.6465
#
# Starting epoch: 60 | phase: train | ⏰: 17:42:45
# Loss: 0.0300 | dice: 0.7707 | dice_neg: 0.0000 | dice_pos: 0.7707 | IoU: 0.6711
# Starting epoch: 60 | phase: val | ⏰: 17:45:05
# Loss: 0.0444 | dice: 0.7422 | dice_neg: 0.0000 | dice_pos: 0.7422 | IoU: 0.6469
# Epoch    60: reducing learning rate of group 0 to 5.0000e-07.
#
# Starting epoch: 61 | phase: train | ⏰: 17:45:39
# Loss: 0.0300 | dice: 0.7715 | dice_neg: 0.0000 | dice_pos: 0.7715 | IoU: 0.6709
# Starting epoch: 61 | phase: val | ⏰: 17:47:59
# Loss: 0.0406 | dice: 0.7495 | dice_neg: 0.0000 | dice_pos: 0.7495 | IoU: 0.6553
#
# Starting epoch: 62 | phase: train | ⏰: 17:48:35
# Loss: 0.0302 | dice: 0.7704 | dice_neg: 0.0000 | dice_pos: 0.7704 | IoU: 0.6706
# Starting epoch: 62 | phase: val | ⏰: 17:50:54
# Loss: 0.0418 | dice: 0.7462 | dice_neg: 0.0000 | dice_pos: 0.7462 | IoU: 0.6521
#
# Starting epoch: 63 | phase: train | ⏰: 17:51:29
# Loss: 0.0295 | dice: 0.7733 | dice_neg: 0.0018 | dice_pos: 0.7732 | IoU: 0.6727
# Starting epoch: 63 | phase: val | ⏰: 17:53:48
# Loss: 0.0439 | dice: 0.7422 | dice_neg: 0.0000 | dice_pos: 0.7422 | IoU: 0.6469
#
# Starting epoch: 64 | phase: train | ⏰: 17:54:22
# Loss: 0.0295 | dice: 0.7765 | dice_neg: 0.0000 | dice_pos: 0.7765 | IoU: 0.6763
# Starting epoch: 64 | phase: val | ⏰: 17:56:42
# Loss: 0.0402 | dice: 0.7480 | dice_neg: 0.0000 | dice_pos: 0.7480 | IoU: 0.6534
# Epoch    64: reducing learning rate of group 0 to 5.0000e-08.
#
# Starting epoch: 65 | phase: train | ⏰: 17:57:18
# Loss: 0.0307 | dice: 0.7671 | dice_neg: 0.0000 | dice_pos: 0.7671 | IoU: 0.6667
# Starting epoch: 65 | phase: val | ⏰: 17:59:38
# Loss: 0.0445 | dice: 0.7410 | dice_neg: 0.0000 | dice_pos: 0.7410 | IoU: 0.6452
#
# Starting epoch: 66 | phase: train | ⏰: 18:00:12
# Loss: 0.0297 | dice: 0.7713 | dice_neg: 0.0000 | dice_pos: 0.7713 | IoU: 0.6715
# Starting epoch: 66 | phase: val | ⏰: 18:02:31
# Loss: 0.0384 | dice: 0.7500 | dice_neg: 0.0000 | dice_pos: 0.7500 | IoU: 0.6558
#
# Starting epoch: 67 | phase: train | ⏰: 18:03:06
# Loss: 0.0305 | dice: 0.7720 | dice_neg: 0.0000 | dice_pos: 0.7720 | IoU: 0.6717
# Starting epoch: 67 | phase: val | ⏰: 18:05:26
# Loss: 0.0473 | dice: 0.7351 | dice_neg: 0.0000 | dice_pos: 0.7351 | IoU: 0.6390
#
# Starting epoch: 68 | phase: train | ⏰: 18:06:00
# Loss: 0.0299 | dice: 0.7700 | dice_neg: 0.0000 | dice_pos: 0.7700 | IoU: 0.6697
# Starting epoch: 68 | phase: val | ⏰: 18:08:20
# Loss: 0.0417 | dice: 0.7470 | dice_neg: 0.0000 | dice_pos: 0.7470 | IoU: 0.6522
# Epoch    68: reducing learning rate of group 0 to 5.0000e-09.
#
# Starting epoch: 69 | phase: train | ⏰: 18:08:55
# Loss: 0.0298 | dice: 0.7698 | dice_neg: 0.0000 | dice_pos: 0.7698 | IoU: 0.6694
# Starting epoch: 69 | phase: val | ⏰: 18:11:14
# Loss: 0.0402 | dice: 0.7492 | dice_neg: 0.0000 | dice_pos: 0.7492 | IoU: 0.6542
#
# Starting epoch: 70 | phase: train | ⏰: 18:11:50
# Loss: 0.0301 | dice: 0.7664 | dice_neg: 0.0000 | dice_pos: 0.7664 | IoU: 0.6660
# Starting epoch: 70 | phase: val | ⏰: 18:14:11
# Loss: 0.0378 | dice: 0.7527 | dice_neg: 0.0000 | dice_pos: 0.7527 | IoU: 0.6595
# ******** New optimal found, saving state ********
#
# Starting epoch: 71 | phase: train | ⏰: 18:14:46
# Loss: 0.0301 | dice: 0.7725 | dice_neg: 0.0018 | dice_pos: 0.7724 | IoU: 0.6725
# Starting epoch: 71 | phase: val | ⏰: 18:17:04
# Loss: 0.0380 | dice: 0.7507 | dice_neg: 0.0000 | dice_pos: 0.7507 | IoU: 0.6575
#
# Starting epoch: 72 | phase: train | ⏰: 18:17:39
# Loss: 0.0301 | dice: 0.7701 | dice_neg: 0.0000 | dice_pos: 0.7701 | IoU: 0.6697
# Starting epoch: 72 | phase: val | ⏰: 18:19:58
# Loss: 0.0395 | dice: 0.7478 | dice_neg: 0.0000 | dice_pos: 0.7478 | IoU: 0.6536
#
# Starting epoch: 73 | phase: train | ⏰: 18:20:33
# Loss: 0.0297 | dice: 0.7693 | dice_neg: 0.0000 | dice_pos: 0.7693 | IoU: 0.6699
# Starting epoch: 73 | phase: val | ⏰: 18:22:53
# Loss: 0.0389 | dice: 0.7505 | dice_neg: 0.0000 | dice_pos: 0.7505 | IoU: 0.6565
#
# Starting epoch: 74 | phase: train | ⏰: 18:23:29
# Loss: 0.0302 | dice: 0.7708 | dice_neg: 0.0000 | dice_pos: 0.7708 | IoU: 0.6701
# Starting epoch: 74 | phase: val | ⏰: 18:25:50
# Loss: 0.0387 | dice: 0.7489 | dice_neg: 0.0000 | dice_pos: 0.7489 | IoU: 0.6548

# %%
# PLOT TRAINING
losses = model_trainer.losses
dice_scores = model_trainer.dice_scores # overall dice
iou_scores = model_trainer.iou_scores

def plot(scores, name):
    plt.figure(figsize=(15,5))
    plt.plot(range(len(scores["train"])), scores["train"], label=f'train {name}')
    plt.plot(range(len(scores["train"])), scores["val"], label=f'val {name}')
    plt.title(f'{name} plot'); plt.xlabel('Epoch'); plt.ylabel(f'{name}');
    plt.legend(); 
    plt.show()

plot(losses, "BCE loss")
plot(dice_scores, "Dice score")
plot(iou_scores, "IoU score")

# %% [markdown]
# ## Test prediction

# %%
class TestDataset(Dataset):
    def __init__(self, root, df, size, mean, std, tta=4):
        self.root = root
        self.size = size
        self.fnames = list(df["ImageId"])
        self.num_samples = len(self.fnames)
        self.transform = Compose(
            [
                Normalize(mean=mean, std=std, p=1),
                Resize(size, size),
                ToTensor(),
            ]
        )

    def __getitem__(self, idx):
        fname = self.fnames[idx]
        path = os.path.join(self.root, fname + ".png")
        image = cv2.imread(path)
        images = self.transform(image=image)["image"]
        return images

    def __len__(self):
        return self.num_samples

def post_process(probability, threshold, min_size):
    mask = cv2.threshold(probability, threshold, 1, cv2.THRESH_BINARY)[1]
    num_component, component = cv2.connectedComponents(mask.astype(np.uint8))
    predictions = np.zeros((1024, 1024), np.float32)
    num = 0
    for c in range(1, num_component):
        p = (component == c)
        if p.sum() > min_size:
            predictions[p] = 1
            num += 1
    return predictions, num

# %%
size = 512
mean = (0.485, 0.456, 0.406)
std = (0.229, 0.224, 0.225)
num_workers = 8
batch_size = 16
best_threshold = 0.5
min_size = 0
device = torch.device("cuda:01")
df = pd.read_csv(sample_submission_path)
testset = DataLoader(
    TestDataset(test_data_folder, df, size, mean, std),
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
)
model = model_trainer.net # get the model from model_trainer object
model.eval()
state = torch.load('./model.pth', map_location=lambda storage, loc: storage)
model.load_state_dict(state["state_dict"])
encoded_pixels = []
for i, batch in enumerate(tqdm(testset)):
    preds = torch.sigmoid(model(batch.to(device)))
    preds = preds.detach().cpu().numpy()[:, 0, :, :] # (batch_size, 1, size, size) -> (batch_size, size, size)
    for probability in preds:
        if probability.shape != (1024, 1024):
            probability = cv2.resize(probability, dsize=(1024, 1024), interpolation=cv2.INTER_LINEAR)
        predict, num_predict = post_process(probability, best_threshold, min_size)
        if num_predict == 0:
            encoded_pixels.append('-1')
        else:
            r = run_length_encode(predict)
            encoded_pixels.append(r)
df['EncodedPixels'] = encoded_pixels
df.to_csv('submission.csv', columns=['ImageId', 'EncodedPixels'], index=False)
# Out:
# HBox(children=(IntProgress(value=0, max=86), HTML(value='')))

# %%
df.head()
# Out:
#                                              ImageId  \
# 0  1.2.276.0.7230010.3.1.4.8323329.6067.151787519...
# 1  1.2.276.0.7230010.3.1.4.8323329.6214.151787519...
# 2  1.2.276.0.7230010.3.1.4.8323329.6177.151787519...
# 3  1.2.276.0.7230010.3.1.4.8323329.6655.151787519...
# 4  1.2.276.0.7230010.3.1.4.8323329.6359.151787519...
#
#                                        EncodedPixels
# 0                                                 -1
# 1                                                 -1
# 2  567379 8 1010 21 1000 27 994 33 990 34 987 37 ...
# 3                                                 -1
# 4                                                 -1

# %% [markdown]
# This kernel has a lot of scope for improvement, specially with augmentations part, I'll push updates soon.
#
# I've achieved 0.8432 by training this exact model on 512 sized images then fine-tuning it on 1024 then combining the results with a seperately trained EfficientNet-b5 binary classifier.
#
# `segmentation_models_pytorch` has got many other segmentation models implemented, try them out :)
#
# I've learnt a lot from fellow kagglers, I've borrowed a lot of code from you guys, special shout-out to [@Abhishek](https://www.kaggle.com/abhishek), [@Yury](https://www.kaggle.com/deyury), [Heng](https://www.kaggle.com/hengck23), [Ekhtiar](https://www.kaggle.com/ekhtiar), [lafoss](https://www.kaggle.com/iafoss), [Siddhartha](https://www.kaggle.com/meaninglesslives) and many other kagglers :)
#
# Kaggle is <3
