# %% [markdown]
# This Kernel uses UNet architecture with ResNet34 encoder, I've used [segmentation_models.pytorch](https://github.com/qubvel/segmentation_models.pytorch) library which has many inbuilt segmentation architectures. This kernel is inspired by [Yury](https://www.kaggle.com/deyury)'s discussion thread [here](https://www.kaggle.com/c/siim-acr-pneumothorax-segmentation/discussion/99440#591985). I've used snippets from multiple other public kernels I've given due credits at the end of this notebook.
#
# What's down below?
#
# * UNet with imagenet pretrained ResNet34 architecture
# * Training on 512x512 sized images/masks with Standard Augmentations
# * MixedLoss (weighted sum of Focal loss and dice loss)
# * Gradient Accumulution

# %%
#!pip install git+https://github.com/qubvel/segmentation_models.pytorch > /dev/null 2>&1 # run bash cmd without output.

# %%
import os
import cv2
import pdb
import time
import warnings
import random
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold
import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader, Dataset, sampler
from matplotlib import pyplot as plt
from albumentations import (HorizontalFlip, ShiftScaleRotate, Normalize, Resize, Compose, GaussNoise)
from albumentations.torch import ToTensor
import segmentation_models_pytorch as smp
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Utility functions

# %%
def run_length_decode(rle, height=1024, width=1024, fill_value=1):
    component = np.zeros((height, width), np.float32)
    component = component.reshape(-1)
    rle = np.array([int(s) for s in rle.strip().split(' ')])
    rle = rle.reshape(-1, 2)
    start = 0
    for index, length in rle:
        start = start+index
        end = start+length
        component[start: end] = fill_value
        start = end
    component = component.reshape(width, height).T
    return component

def run_length_encode(component):
    component = component.T.flatten()
    start = np.where(component[1:] > component[:-1])[0]+1
    end = np.where(component[:-1] > component[1:])[0]+1
    length = end-start
    rle = []
    for i in range(len(length)):
        if i == 0:
            rle.extend([start[0], length[0]])
        else:
            rle.extend([start[i]-end[i-1], length[i]])
    rle = ' '.join([str(r) for r in rle])
    return rle

# %% [markdown]
# ## Dataloader

# %%
class SIIMDataset(Dataset):
    def __init__(self, df, data_folder, size, mean, std, phase):
        self.df = df
        self.root = data_folder
        self.size = size
        self.mean = mean
        self.std = std
        self.phase = phase
        self.transforms = get_transforms(phase, size, mean, std)
        self.gb = self.df.groupby('ImageId')
        self.fnames = list(self.gb.groups.keys())

    def __getitem__(self, idx):
        image_id = self.fnames[idx]
        df = self.gb.get_group(image_id)
        annotations = df[' EncodedPixels'].tolist()
        image_path = os.path.join(self.root, image_id + ".png")
        image = cv2.imread(image_path)
        mask = np.zeros([1024, 1024])
        if annotations[0] != '-1':
            for rle in annotations:
                mask += run_length_decode(rle)
        mask = (mask >= 1).astype('float32') # for overlap cases
        augmented = self.transforms(image=image, mask=mask)
        image = augmented['image']
        mask = augmented['mask']
        return image, mask

    def __len__(self):
        return len(self.fnames)


def get_transforms(phase, size, mean, std):
    list_transforms = []
    if phase == "train":
        list_transforms.extend(
            [
#                 HorizontalFlip(),
                ShiftScaleRotate(
                    shift_limit=0,  # no resizing
                    scale_limit=0.1,
                    rotate_limit=10, # rotate
                    p=0.5,
                    border_mode=cv2.BORDER_CONSTANT
                ),
#                 GaussNoise(),
            ]
        )
    list_transforms.extend(
        [
            Normalize(mean=mean, std=std, p=1),
            Resize(size, size),
            ToTensor(),
        ]
    )

    list_trfms = Compose(list_transforms)
    return list_trfms

def provider(
    fold,
    total_folds,
    data_folder,
    df_path,
    phase,
    size,
    mean=None,
    std=None,
    batch_size=8,
    num_workers=4,
):
    df = pd.read_csv(df_path)
    df = df.drop_duplicates('ImageId')
    df_with_mask = df[df[" EncodedPixels"] != " -1"]
    df_with_mask['has_mask'] = 1
    df_without_mask = df[df[" EncodedPixels"] != " -1"]
    df_without_mask['has_mask'] = 0
    df_without_mask_sampled = df_without_mask.sample(len(df_with_mask))
    df = pd.concat([df_with_mask, df_without_mask_sampled])
    #NOTE: equal number of positive and negative cases are chosen.
    
    kfold = StratifiedKFold(total_folds, shuffle=True, random_state=69)
    train_idx, val_idx = list(kfold.split(
        df["ImageId"], df["has_mask"]))[fold]
    train_df, val_df = df.iloc[train_idx], df.iloc[val_idx]
    df = train_df if phase == "train" else val_df
    # NOTE: total_folds=5 -> train/val : 80%/20%
    
    image_dataset = SIIMDataset(df, data_folder, size, mean, std, phase)

    dataloader = DataLoader(
        image_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=True,
        shuffle=True,
    )
    return dataloader

# %%
torch.cuda.set_device(1)
sample_submission_path = '../sample_submission.csv'
train_rle_path = '../train-rle.csv'
data_folder = "../data512/train"
test_data_folder = "../data512/test"

# %% [markdown]
# ### Dataloader sanity check

# %%
dataloader = provider(
    fold=0,
    total_folds=5,
    data_folder=data_folder,
    df_path=train_rle_path,
    phase="train",
    size=512,
    mean = (0.485, 0.456, 0.406),
    std = (0.229, 0.224, 0.225),
    batch_size=16,
    num_workers=4,
)

# %%
batch = next(iter(dataloader)) # get a batch from the dataloader
images, masks = batch

# %%
# plot some random images in the `batch`
idx = random.choice(range(16))
plt.imshow(images[idx][0], cmap='bone')
plt.imshow(masks[idx][0], alpha=0.2, cmap='Reds')
plt.show()

# %% [markdown]
# ## Losses
#
# This kernel uses a weighted sum of Focal Loss and Dice Loss, let's call it MixedLoss

# %%
def dice_loss(input, target):
    input = torch.sigmoid(input)
    smooth = 1.0
    iflat = input.view(-1)
    tflat = target.view(-1)
    intersection = (iflat * tflat).sum()
    return ((2.0 * intersection + smooth) / (iflat.sum() + tflat.sum() + smooth))


class FocalLoss(nn.Module):
    def __init__(self, gamma):
        super().__init__()
        self.gamma = gamma

    def forward(self, input, target):
        if not (target.size() == input.size()):
            raise ValueError("Target size ({}) must be the same as input size ({})"
                             .format(target.size(), input.size()))
        max_val = (-input).clamp(min=0)
        loss = input - input * target + max_val + \
            ((-max_val).exp() + (-input - max_val).exp()).log()
        invprobs = F.logsigmoid(-input * (target * 2.0 - 1.0))
        loss = (invprobs * self.gamma).exp() * loss
        return loss.mean()


class MixedLoss(nn.Module):
    def __init__(self, alpha, gamma):
        super().__init__()
        self.alpha = alpha
        self.focal = FocalLoss(gamma)

    def forward(self, input, target):
        loss = self.alpha*self.focal(input, target) - torch.log(dice_loss(input, target))
        return loss.mean()

# %% [markdown]
# ## Some more utility functions
#
# Here are some utility functions for calculating IoU and Dice scores

# %%
def predict(X, threshold):
    X_p = np.copy(X)
    preds = (X_p > threshold).astype('uint8')
    return preds

def metric(probability, truth, threshold=0.5, reduction='none'):
    '''Calculates dice of positive and negative images seperately'''
    '''probability and truth must be torch tensors'''
    batch_size = len(truth)
    with torch.no_grad():
        probability = probability.view(batch_size, -1)
        truth = truth.view(batch_size, -1)
        assert(probability.shape == truth.shape)

        p = (probability > threshold).float()
        t = (truth > 0.5).float()

        t_sum = t.sum(-1)
        p_sum = p.sum(-1)
        neg_index = torch.nonzero(t_sum == 0)
        pos_index = torch.nonzero(t_sum >= 1)

        dice_neg = (p_sum == 0).float()
        dice_pos = 2 * (p*t).sum(-1)/((p+t).sum(-1))

        dice_neg = dice_neg[neg_index]
        dice_pos = dice_pos[pos_index]
        dice = torch.cat([dice_pos, dice_neg])

        dice_neg = np.nan_to_num(dice_neg.mean().item(), 0)
        dice_pos = np.nan_to_num(dice_pos.mean().item(), 0)
        dice = dice.mean().item()

        num_neg = len(neg_index)
        num_pos = len(pos_index)

    return dice, dice_neg, dice_pos, num_neg, num_pos

class Meter:
    '''A meter to keep track of iou and dice scores throughout an epoch'''
    def __init__(self, phase, epoch):
        self.base_threshold = 0.5 # <<<<<<<<<<< here's the threshold
        self.base_dice_scores = []
        self.dice_neg_scores = []
        self.dice_pos_scores = []
        self.iou_scores = []

    def update(self, targets, outputs):
        probs = torch.sigmoid(outputs)
        dice, dice_neg, dice_pos, _, _ = metric(probs, targets, self.base_threshold)
        self.base_dice_scores.append(dice)
        self.dice_pos_scores.append(dice_pos)
        self.dice_neg_scores.append(dice_neg)
        preds = predict(probs, self.base_threshold)
        iou = compute_iou_batch(preds, targets, classes=[1])
        self.iou_scores.append(iou)

    def get_metrics(self):
        dice = np.mean(self.base_dice_scores)
        dice_neg = np.mean(self.dice_neg_scores)
        dice_pos = np.mean(self.dice_pos_scores)
        dices = [dice, dice_neg, dice_pos]
        iou = np.nanmean(self.iou_scores)
        return dices, iou

def epoch_log(phase, epoch, epoch_loss, meter, start):
    '''logging the metrics at the end of an epoch'''
    dices, iou = meter.get_metrics()
    dice, dice_neg, dice_pos = dices
    print("Loss: %0.4f | dice: %0.4f | dice_neg: %0.4f | dice_pos: %0.4f | IoU: %0.4f" % (epoch_loss, dice, dice_neg, dice_pos, iou))
    return dice, iou

def compute_ious(pred, label, classes, ignore_index=255, only_present=True):
    '''computes iou for one ground truth mask and predicted mask'''
    pred[label == ignore_index] = 0
    ious = []
    for c in classes:
        label_c = label == c
        if only_present and np.sum(label_c) == 0:
            ious.append(np.nan)
            continue
        pred_c = pred == c
        intersection = np.logical_and(pred_c, label_c).sum()
        union = np.logical_or(pred_c, label_c).sum()
        if union != 0:
            ious.append(intersection / union)
    return ious if ious else [1]


def compute_iou_batch(outputs, labels, classes=None):
    '''computes mean iou for a batch of ground truth masks and predicted masks'''
    ious = []
    preds = np.copy(outputs) # copy is imp
    labels = np.array(labels) # tensor to np
    for pred, label in zip(preds, labels):
        ious.append(np.nanmean(compute_ious(pred, label, classes)))
    iou = np.nanmean(ious)
    return iou

# %% [markdown]
# ## UNet with ResNet34 model
# Let's take a look at the model

# %%
model = smp.Unet("resnet34", encoder_weights="imagenet", activation=None)

# %%
model # a *deeper* look
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   )
#   (decoder): UnetDecoder(
#     (layer1): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer2): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer3): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer4): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer5): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (final_conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## Model Training and validation

# %%
class Trainer(object):
    '''This class takes care of training and validation of our model'''
    def __init__(self, model):
        self.fold = 1
        self.total_folds = 5
        self.num_workers = 6
        self.batch_size = {"train": 4, "val": 4}
        self.accumulation_steps = 32 // self.batch_size['train']
        self.lr = 5e-4
        self.num_epochs = 75
        self.best_loss = float("inf")
        self.phases = ["train", "val"]
        self.device = torch.device("cuda:1")
        torch.set_default_tensor_type("torch.cuda.FloatTensor")
        self.net = model
        self.criterion = MixedLoss(10.0, 2.0)
        self.optimizer = optim.Adam(self.net.parameters(), lr=self.lr)
        self.scheduler = ReduceLROnPlateau(self.optimizer, mode="min", patience=3, verbose=True)
        self.net = self.net.to(self.device)
        cudnn.benchmark = True
        self.dataloaders = {
            phase: provider(
                fold=1,
                total_folds=5,
                data_folder=data_folder,
                df_path=train_rle_path,
                phase=phase,
                size=512,
                mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225),
                batch_size=self.batch_size[phase],
                num_workers=self.num_workers,
            )
            for phase in self.phases
        }
        self.losses = {phase: [] for phase in self.phases}
        self.iou_scores = {phase: [] for phase in self.phases}
        self.dice_scores = {phase: [] for phase in self.phases}
        
    def forward(self, images, targets):
        images = images.to(self.device)
        masks = targets.to(self.device)
        outputs = self.net(images)
        loss = self.criterion(outputs, masks)
        return loss, outputs

    def iterate(self, epoch, phase):
        meter = Meter(phase, epoch)
        start = time.strftime("%H:%M:%S")
        print(f"Starting epoch: {epoch} | phase: {phase} | ⏰: {start}")
        batch_size = self.batch_size[phase]
        self.net.train(phase == "train")
        dataloader = self.dataloaders[phase]
        running_loss = 0.0
        total_batches = len(dataloader)
#         tk0 = tqdm(dataloader, total=total_batches)
        self.optimizer.zero_grad()
        for itr, batch in enumerate(dataloader):
            images, targets = batch
            loss, outputs = self.forward(images, targets)
            loss = loss / self.accumulation_steps
            if phase == "train":
                loss.backward()
                if (itr + 1 ) % self.accumulation_steps == 0:
                    self.optimizer.step()
                    self.optimizer.zero_grad()
            running_loss += loss.item()
            outputs = outputs.detach().cpu()
            meter.update(targets, outputs)
#             tk0.set_postfix(loss=(running_loss / ((itr + 1))))
        epoch_loss = running_loss / total_batches
        dice, iou = epoch_log(phase, epoch, epoch_loss, meter, start)
        self.losses[phase].append(epoch_loss)
        self.dice_scores[phase].append(dice)
        self.iou_scores[phase].append(iou)
        torch.cuda.empty_cache()
        return epoch_loss

    def start(self):
        for epoch in range(self.num_epochs):
            self.iterate(epoch, "train")
            state = {
                "epoch": epoch,
                "best_loss": self.best_loss,
                "state_dict": self.net.state_dict(),
                "optimizer": self.optimizer.state_dict(),
            }
            val_loss = self.iterate(epoch, "val")
            self.scheduler.step(val_loss)
            if val_loss < self.best_loss:
                print("******** New optimal found, saving state ********")
                state["best_loss"] = self.best_loss = val_loss
                torch.save(state, "./model.pth")
            print()

# %%
model_trainer = Trainer(model)
model_trainer.start()
# Out:
# Starting epoch: 0 | phase: train | ⏰: 12:36:29
# Loss: 0.4716 | dice: 0.2160 | dice_neg: 0.0000 | dice_pos: 0.2160 | IoU: 0.1387
# Starting epoch: 0 | phase: val | ⏰: 12:38:56
# Loss: 0.2623 | dice: 0.3407 | dice_neg: 0.0000 | dice_pos: 0.3407 | IoU: 0.2320
# ******** New optimal found, saving state ********
#
# Starting epoch: 1 | phase: train | ⏰: 12:39:31
# Loss: 0.2279 | dice: 0.3592 | dice_neg: 0.0000 | dice_pos: 0.3592 | IoU: 0.2524
# Starting epoch: 1 | phase: val | ⏰: 12:41:51
# Loss: 0.1982 | dice: 0.3844 | dice_neg: 0.0000 | dice_pos: 0.3844 | IoU: 0.2702
# ******** New optimal found, saving state ********
#
# Starting epoch: 2 | phase: train | ⏰: 12:42:26
# Loss: 0.2042 | dice: 0.3804 | dice_neg: 0.0000 | dice_pos: 0.3807 | IoU: 0.2714
# Starting epoch: 2 | phase: val | ⏰: 12:44:46
# Loss: 0.1776 | dice: 0.4222 | dice_neg: 0.0000 | dice_pos: 0.4222 | IoU: 0.3073
# ******** New optimal found, saving state ********
#
# Starting epoch: 3 | phase: train | ⏰: 12:45:21
# Loss: 0.1829 | dice: 0.4009 | dice_neg: 0.0000 | dice_pos: 0.4009 | IoU: 0.2910
# Starting epoch: 3 | phase: val | ⏰: 12:47:41
# Loss: 0.1732 | dice: 0.4272 | dice_neg: 0.0000 | dice_pos: 0.4272 | IoU: 0.3223
# ******** New optimal found, saving state ********
#
# Starting epoch: 4 | phase: train | ⏰: 12:48:16
# Loss: 0.1665 | dice: 0.4219 | dice_neg: 0.0000 | dice_pos: 0.4219 | IoU: 0.3092
# Starting epoch: 4 | phase: val | ⏰: 12:50:35
# Loss: 0.1470 | dice: 0.4641 | dice_neg: 0.0000 | dice_pos: 0.4641 | IoU: 0.3499
# ******** New optimal found, saving state ********
#
# Starting epoch: 5 | phase: train | ⏰: 12:51:11
# Loss: 0.1494 | dice: 0.4394 | dice_neg: 0.0000 | dice_pos: 0.4394 | IoU: 0.3281
# Starting epoch: 5 | phase: val | ⏰: 12:53:31
# Loss: 0.1434 | dice: 0.4226 | dice_neg: 0.0000 | dice_pos: 0.4226 | IoU: 0.3226
# ******** New optimal found, saving state ********
#
# Starting epoch: 6 | phase: train | ⏰: 12:54:06
# Loss: 0.1373 | dice: 0.4590 | dice_neg: 0.0000 | dice_pos: 0.4590 | IoU: 0.3459
# Starting epoch: 6 | phase: val | ⏰: 12:56:27
# Loss: 0.1228 | dice: 0.5071 | dice_neg: 0.0000 | dice_pos: 0.5071 | IoU: 0.3931
# ******** New optimal found, saving state ********
#
# Starting epoch: 7 | phase: train | ⏰: 12:57:02
# Loss: 0.1286 | dice: 0.4660 | dice_neg: 0.0000 | dice_pos: 0.4660 | IoU: 0.3548
# Starting epoch: 7 | phase: val | ⏰: 12:59:22
# Loss: 0.1305 | dice: 0.4734 | dice_neg: 0.0000 | dice_pos: 0.4734 | IoU: 0.3585
#
# Starting epoch: 8 | phase: train | ⏰: 12:59:57
# Loss: 0.1253 | dice: 0.4735 | dice_neg: 0.0000 | dice_pos: 0.4735 | IoU: 0.3620
# Starting epoch: 8 | phase: val | ⏰: 13:02:16
# Loss: 0.1190 | dice: 0.4838 | dice_neg: 0.0000 | dice_pos: 0.4838 | IoU: 0.3803
# ******** New optimal found, saving state ********
#
# Starting epoch: 9 | phase: train | ⏰: 13:02:51
# Loss: 0.1191 | dice: 0.4843 | dice_neg: 0.0000 | dice_pos: 0.4843 | IoU: 0.3703
# Starting epoch: 9 | phase: val | ⏰: 13:05:11
# Loss: 0.1048 | dice: 0.5245 | dice_neg: 0.0000 | dice_pos: 0.5245 | IoU: 0.4107
# ******** New optimal found, saving state ********
#
# Starting epoch: 10 | phase: train | ⏰: 13:05:46
# Loss: 0.1132 | dice: 0.4979 | dice_neg: 0.0000 | dice_pos: 0.4979 | IoU: 0.3831
# Starting epoch: 10 | phase: val | ⏰: 13:08:06
# Loss: 0.0974 | dice: 0.5327 | dice_neg: 0.0000 | dice_pos: 0.5327 | IoU: 0.4195
# ******** New optimal found, saving state ********
#
# Starting epoch: 11 | phase: train | ⏰: 13:08:41
# Loss: 0.1076 | dice: 0.5024 | dice_neg: 0.0000 | dice_pos: 0.5024 | IoU: 0.3879
# Starting epoch: 11 | phase: val | ⏰: 13:11:02
# Loss: 0.1072 | dice: 0.5044 | dice_neg: 0.0000 | dice_pos: 0.5044 | IoU: 0.3942
#
# Starting epoch: 12 | phase: train | ⏰: 13:11:37
# Loss: 0.1094 | dice: 0.4984 | dice_neg: 0.0000 | dice_pos: 0.4987 | IoU: 0.3842
# Starting epoch: 12 | phase: val | ⏰: 13:13:56
# Loss: 0.1332 | dice: 0.4735 | dice_neg: 0.0000 | dice_pos: 0.4735 | IoU: 0.3602
#
# Starting epoch: 13 | phase: train | ⏰: 13:14:31
# Loss: 0.1042 | dice: 0.5075 | dice_neg: 0.0000 | dice_pos: 0.5075 | IoU: 0.3934
# Starting epoch: 13 | phase: val | ⏰: 13:16:50
# Loss: 0.0921 | dice: 0.5342 | dice_neg: 0.0000 | dice_pos: 0.5342 | IoU: 0.4206
# ******** New optimal found, saving state ********
#
# Starting epoch: 14 | phase: train | ⏰: 13:17:25
# Loss: 0.0951 | dice: 0.5157 | dice_neg: 0.0000 | dice_pos: 0.5157 | IoU: 0.4029
# Starting epoch: 14 | phase: val | ⏰: 13:19:45
# Loss: 0.0879 | dice: 0.5665 | dice_neg: 0.0000 | dice_pos: 0.5665 | IoU: 0.4435
# ******** New optimal found, saving state ********
#
# Starting epoch: 15 | phase: train | ⏰: 13:20:21
# Loss: 0.0915 | dice: 0.5398 | dice_neg: 0.0000 | dice_pos: 0.5398 | IoU: 0.4245
# Starting epoch: 15 | phase: val | ⏰: 13:22:40
# Loss: 0.0879 | dice: 0.5326 | dice_neg: 0.0000 | dice_pos: 0.5326 | IoU: 0.4272
# ******** New optimal found, saving state ********
#
# Starting epoch: 16 | phase: train | ⏰: 13:23:16
# Loss: 0.0882 | dice: 0.5382 | dice_neg: 0.0000 | dice_pos: 0.5382 | IoU: 0.4243
# Starting epoch: 16 | phase: val | ⏰: 13:25:34
# Loss: 0.0850 | dice: 0.5306 | dice_neg: 0.0000 | dice_pos: 0.5306 | IoU: 0.4211
# ******** New optimal found, saving state ********
#
# Starting epoch: 17 | phase: train | ⏰: 13:26:10
# Loss: 0.0854 | dice: 0.5442 | dice_neg: 0.0000 | dice_pos: 0.5442 | IoU: 0.4294
# Starting epoch: 17 | phase: val | ⏰: 13:28:31
# Loss: 0.0784 | dice: 0.5887 | dice_neg: 0.0000 | dice_pos: 0.5887 | IoU: 0.4729
# ******** New optimal found, saving state ********
#
# Starting epoch: 18 | phase: train | ⏰: 13:29:06
# Loss: 0.0874 | dice: 0.5486 | dice_neg: 0.0000 | dice_pos: 0.5486 | IoU: 0.4321
# Starting epoch: 18 | phase: val | ⏰: 13:31:26
# Loss: 0.0803 | dice: 0.5279 | dice_neg: 0.0000 | dice_pos: 0.5279 | IoU: 0.4214
#
# Starting epoch: 19 | phase: train | ⏰: 13:32:01
# Loss: 0.0866 | dice: 0.5418 | dice_neg: 0.0000 | dice_pos: 0.5418 | IoU: 0.4273
# Starting epoch: 19 | phase: val | ⏰: 13:34:23
# Loss: 0.0776 | dice: 0.5873 | dice_neg: 0.0000 | dice_pos: 0.5873 | IoU: 0.4645
# ******** New optimal found, saving state ********
#
# Starting epoch: 20 | phase: train | ⏰: 13:34:57
# Loss: 0.0832 | dice: 0.5504 | dice_neg: 0.0000 | dice_pos: 0.5504 | IoU: 0.4348
# Starting epoch: 20 | phase: val | ⏰: 13:37:17
# Loss: 0.0819 | dice: 0.5664 | dice_neg: 0.0000 | dice_pos: 0.5664 | IoU: 0.4490
#
# Starting epoch: 21 | phase: train | ⏰: 13:37:52
# Loss: 0.0770 | dice: 0.5677 | dice_neg: 0.0000 | dice_pos: 0.5677 | IoU: 0.4520
# Starting epoch: 21 | phase: val | ⏰: 13:40:12
# Loss: 0.0662 | dice: 0.6116 | dice_neg: 0.0000 | dice_pos: 0.6116 | IoU: 0.5000
# ******** New optimal found, saving state ********
#
# Starting epoch: 22 | phase: train | ⏰: 13:40:47
# Loss: 0.0790 | dice: 0.5730 | dice_neg: 0.0018 | dice_pos: 0.5731 | IoU: 0.4560
# Starting epoch: 22 | phase: val | ⏰: 13:43:06
# Loss: 0.0747 | dice: 0.5932 | dice_neg: 0.0000 | dice_pos: 0.5932 | IoU: 0.4724
#
# Starting epoch: 23 | phase: train | ⏰: 13:43:40
# Loss: 0.0803 | dice: 0.5656 | dice_neg: 0.0000 | dice_pos: 0.5656 | IoU: 0.4496
# Starting epoch: 23 | phase: val | ⏰: 13:46:02
# Loss: 0.0716 | dice: 0.5880 | dice_neg: 0.0000 | dice_pos: 0.5880 | IoU: 0.4735
#
# Starting epoch: 24 | phase: train | ⏰: 13:46:37
# Loss: 0.0753 | dice: 0.5815 | dice_neg: 0.0000 | dice_pos: 0.5815 | IoU: 0.4633
# Starting epoch: 24 | phase: val | ⏰: 13:48:57
# Loss: 0.0654 | dice: 0.6055 | dice_neg: 0.0000 | dice_pos: 0.6055 | IoU: 0.4933
# ******** New optimal found, saving state ********
#
# Starting epoch: 25 | phase: train | ⏰: 13:49:32
# Loss: 0.0796 | dice: 0.5645 | dice_neg: 0.0000 | dice_pos: 0.5645 | IoU: 0.4492
# Starting epoch: 25 | phase: val | ⏰: 13:51:51
# Loss: 0.0679 | dice: 0.5667 | dice_neg: 0.0000 | dice_pos: 0.5667 | IoU: 0.4589
#
# Starting epoch: 26 | phase: train | ⏰: 13:52:27
# Loss: 0.0714 | dice: 0.5815 | dice_neg: 0.0000 | dice_pos: 0.5815 | IoU: 0.4676
# Starting epoch: 26 | phase: val | ⏰: 13:54:46
# Loss: 0.0761 | dice: 0.5623 | dice_neg: 0.0000 | dice_pos: 0.5623 | IoU: 0.4511
#
# Starting epoch: 27 | phase: train | ⏰: 13:55:20
# Loss: 0.0727 | dice: 0.5796 | dice_neg: 0.0000 | dice_pos: 0.5798 | IoU: 0.4645
# Starting epoch: 27 | phase: val | ⏰: 13:57:41
# Loss: 0.0620 | dice: 0.6005 | dice_neg: 0.0000 | dice_pos: 0.6005 | IoU: 0.4931
# ******** New optimal found, saving state ********
#
# Starting epoch: 28 | phase: train | ⏰: 13:58:17
# Loss: 0.0642 | dice: 0.6063 | dice_neg: 0.0000 | dice_pos: 0.6063 | IoU: 0.4925
# Starting epoch: 28 | phase: val | ⏰: 14:00:37
# Loss: 0.0630 | dice: 0.6027 | dice_neg: 0.0000 | dice_pos: 0.6027 | IoU: 0.4962
#
# Starting epoch: 29 | phase: train | ⏰: 14:01:11
# Loss: 0.0623 | dice: 0.6222 | dice_neg: 0.0018 | dice_pos: 0.6221 | IoU: 0.5053
# Starting epoch: 29 | phase: val | ⏰: 14:03:31
# Loss: 0.0639 | dice: 0.6266 | dice_neg: 0.0000 | dice_pos: 0.6266 | IoU: 0.5143
#
# Starting epoch: 30 | phase: train | ⏰: 14:04:06
# Loss: 0.0613 | dice: 0.6120 | dice_neg: 0.0000 | dice_pos: 0.6120 | IoU: 0.4978
# Starting epoch: 30 | phase: val | ⏰: 14:06:26
# Loss: 0.0592 | dice: 0.6386 | dice_neg: 0.0000 | dice_pos: 0.6386 | IoU: 0.5241
# ******** New optimal found, saving state ********
#
# Starting epoch: 31 | phase: train | ⏰: 14:07:01
# Loss: 0.0772 | dice: 0.5759 | dice_neg: 0.0018 | dice_pos: 0.5757 | IoU: 0.4611
# Starting epoch: 31 | phase: val | ⏰: 14:09:20
# Loss: 0.0715 | dice: 0.5883 | dice_neg: 0.0000 | dice_pos: 0.5883 | IoU: 0.4735
#
# Starting epoch: 32 | phase: train | ⏰: 14:09:55
# Loss: 0.0753 | dice: 0.5816 | dice_neg: 0.0000 | dice_pos: 0.5816 | IoU: 0.4650
# Starting epoch: 32 | phase: val | ⏰: 14:12:16
# Loss: 0.0708 | dice: 0.6059 | dice_neg: 0.0000 | dice_pos: 0.6059 | IoU: 0.4876
#
# Starting epoch: 33 | phase: train | ⏰: 14:12:51
# Loss: 0.0651 | dice: 0.6003 | dice_neg: 0.0000 | dice_pos: 0.6003 | IoU: 0.4842
# Starting epoch: 33 | phase: val | ⏰: 14:15:12
# Loss: 0.0585 | dice: 0.6304 | dice_neg: 0.0000 | dice_pos: 0.6304 | IoU: 0.5193
# ******** New optimal found, saving state ********
#
# Starting epoch: 34 | phase: train | ⏰: 14:15:47
# Loss: 0.0627 | dice: 0.6095 | dice_neg: 0.0000 | dice_pos: 0.6095 | IoU: 0.4949
# Starting epoch: 34 | phase: val | ⏰: 14:18:07
# Loss: 0.0569 | dice: 0.6389 | dice_neg: 0.0000 | dice_pos: 0.6389 | IoU: 0.5282
# ******** New optimal found, saving state ********
#
# Starting epoch: 35 | phase: train | ⏰: 14:18:42
# Loss: 0.0600 | dice: 0.6195 | dice_neg: 0.0000 | dice_pos: 0.6198 | IoU: 0.5060
# Starting epoch: 35 | phase: val | ⏰: 14:21:01
# Loss: 0.0579 | dice: 0.6522 | dice_neg: 0.0000 | dice_pos: 0.6522 | IoU: 0.5331
#
# Starting epoch: 36 | phase: train | ⏰: 14:21:36
# Loss: 0.0568 | dice: 0.6346 | dice_neg: 0.0000 | dice_pos: 0.6346 | IoU: 0.5206
# Starting epoch: 36 | phase: val | ⏰: 14:23:56
# Loss: 0.0553 | dice: 0.6455 | dice_neg: 0.0000 | dice_pos: 0.6455 | IoU: 0.5359
# ******** New optimal found, saving state ********
#
# Starting epoch: 37 | phase: train | ⏰: 14:24:31
# Loss: 0.0591 | dice: 0.6304 | dice_neg: 0.0000 | dice_pos: 0.6304 | IoU: 0.5158
# Starting epoch: 37 | phase: val | ⏰: 14:26:50
# Loss: 0.0533 | dice: 0.6494 | dice_neg: 0.0000 | dice_pos: 0.6494 | IoU: 0.5392
# ******** New optimal found, saving state ********
#
# Starting epoch: 38 | phase: train | ⏰: 14:27:24
# Loss: 0.0722 | dice: 0.5734 | dice_neg: 0.0000 | dice_pos: 0.5734 | IoU: 0.4602
# Starting epoch: 38 | phase: val | ⏰: 14:29:43
# Loss: 0.0767 | dice: 0.5329 | dice_neg: 0.0000 | dice_pos: 0.5329 | IoU: 0.4306
#
# Starting epoch: 39 | phase: train | ⏰: 14:30:17
# Loss: 0.0651 | dice: 0.5992 | dice_neg: 0.0000 | dice_pos: 0.5992 | IoU: 0.4834
# Starting epoch: 39 | phase: val | ⏰: 14:32:37
# Loss: 0.0544 | dice: 0.6609 | dice_neg: 0.0000 | dice_pos: 0.6609 | IoU: 0.5508
#
# Starting epoch: 40 | phase: train | ⏰: 14:33:11
# Loss: 0.0548 | dice: 0.6394 | dice_neg: 0.0000 | dice_pos: 0.6394 | IoU: 0.5253
# Starting epoch: 40 | phase: val | ⏰: 14:35:32
# Loss: 0.0509 | dice: 0.6533 | dice_neg: 0.0000 | dice_pos: 0.6533 | IoU: 0.5472
# ******** New optimal found, saving state ********
#
# Starting epoch: 41 | phase: train | ⏰: 14:36:07
# Loss: 0.0532 | dice: 0.6437 | dice_neg: 0.0000 | dice_pos: 0.6437 | IoU: 0.5312
# Starting epoch: 41 | phase: val | ⏰: 14:38:28
# Loss: 0.0538 | dice: 0.6561 | dice_neg: 0.0000 | dice_pos: 0.6561 | IoU: 0.5488
#
# Starting epoch: 42 | phase: train | ⏰: 14:39:03
# Loss: 0.0553 | dice: 0.6459 | dice_neg: 0.0000 | dice_pos: 0.6459 | IoU: 0.5303
# Starting epoch: 42 | phase: val | ⏰: 14:41:24
# Loss: 0.0524 | dice: 0.6725 | dice_neg: 0.0000 | dice_pos: 0.6725 | IoU: 0.5630
#
# Starting epoch: 43 | phase: train | ⏰: 14:41:59
# Loss: 0.0525 | dice: 0.6508 | dice_neg: 0.0000 | dice_pos: 0.6508 | IoU: 0.5385
# Starting epoch: 43 | phase: val | ⏰: 14:44:18
# Loss: 0.0497 | dice: 0.6691 | dice_neg: 0.0000 | dice_pos: 0.6691 | IoU: 0.5625
# ******** New optimal found, saving state ********
#
# Starting epoch: 44 | phase: train | ⏰: 14:44:54
# Loss: 0.0513 | dice: 0.6593 | dice_neg: 0.0000 | dice_pos: 0.6593 | IoU: 0.5456
# Starting epoch: 44 | phase: val | ⏰: 14:47:14
# Loss: 0.0484 | dice: 0.6966 | dice_neg: 0.0000 | dice_pos: 0.6966 | IoU: 0.5847
# ******** New optimal found, saving state ********
#
# Starting epoch: 45 | phase: train | ⏰: 14:47:49
# Loss: 0.0522 | dice: 0.6528 | dice_neg: 0.0000 | dice_pos: 0.6528 | IoU: 0.5402
# Starting epoch: 45 | phase: val | ⏰: 14:50:08
# Loss: 0.0496 | dice: 0.6759 | dice_neg: 0.0000 | dice_pos: 0.6759 | IoU: 0.5673
#
# Starting epoch: 46 | phase: train | ⏰: 14:50:43
# Loss: 0.0537 | dice: 0.6420 | dice_neg: 0.0000 | dice_pos: 0.6420 | IoU: 0.5287
# Starting epoch: 46 | phase: val | ⏰: 14:53:02
# Loss: 0.0462 | dice: 0.6851 | dice_neg: 0.0000 | dice_pos: 0.6851 | IoU: 0.5780
# ******** New optimal found, saving state ********
#
# Starting epoch: 47 | phase: train | ⏰: 14:53:38
# Loss: 0.0451 | dice: 0.6831 | dice_neg: 0.0018 | dice_pos: 0.6830 | IoU: 0.5710
# Starting epoch: 47 | phase: val | ⏰: 14:56:00
# Loss: 0.0464 | dice: 0.6986 | dice_neg: 0.0000 | dice_pos: 0.6986 | IoU: 0.5939
#
# Starting epoch: 48 | phase: train | ⏰: 14:56:36
# Loss: 0.0461 | dice: 0.6822 | dice_neg: 0.0000 | dice_pos: 0.6825 | IoU: 0.5712
# Starting epoch: 48 | phase: val | ⏰: 14:58:56
# Loss: 0.0505 | dice: 0.6595 | dice_neg: 0.0000 | dice_pos: 0.6595 | IoU: 0.5536
#
# Starting epoch: 49 | phase: train | ⏰: 14:59:30
# Loss: 0.0481 | dice: 0.6675 | dice_neg: 0.0000 | dice_pos: 0.6675 | IoU: 0.5533
# Starting epoch: 49 | phase: val | ⏰: 15:01:51
# Loss: 0.0468 | dice: 0.6955 | dice_neg: 0.0000 | dice_pos: 0.6955 | IoU: 0.5885
#
# Starting epoch: 50 | phase: train | ⏰: 15:02:26
# Loss: 0.0453 | dice: 0.6808 | dice_neg: 0.0000 | dice_pos: 0.6808 | IoU: 0.5701
# Starting epoch: 50 | phase: val | ⏰: 15:04:47
# Loss: 0.0452 | dice: 0.6924 | dice_neg: 0.0000 | dice_pos: 0.6924 | IoU: 0.5893
# ******** New optimal found, saving state ********
#
# Starting epoch: 51 | phase: train | ⏰: 15:05:21
# Loss: 0.0686 | dice: 0.6097 | dice_neg: 0.0000 | dice_pos: 0.6097 | IoU: 0.4957
# Starting epoch: 51 | phase: val | ⏰: 15:07:40
# Loss: 0.0603 | dice: 0.6361 | dice_neg: 0.0000 | dice_pos: 0.6361 | IoU: 0.5243
#
# Starting epoch: 52 | phase: train | ⏰: 15:08:15
# Loss: 0.0573 | dice: 0.6345 | dice_neg: 0.0000 | dice_pos: 0.6345 | IoU: 0.5193
# Starting epoch: 52 | phase: val | ⏰: 15:10:34
# Loss: 0.0504 | dice: 0.6789 | dice_neg: 0.0000 | dice_pos: 0.6789 | IoU: 0.5684
#
# Starting epoch: 53 | phase: train | ⏰: 15:11:08
# Loss: 0.0482 | dice: 0.6674 | dice_neg: 0.0000 | dice_pos: 0.6674 | IoU: 0.5565
# Starting epoch: 53 | phase: val | ⏰: 15:13:29
# Loss: 0.0471 | dice: 0.7077 | dice_neg: 0.0000 | dice_pos: 0.7077 | IoU: 0.5997
#
# Starting epoch: 54 | phase: train | ⏰: 15:14:04
# Loss: 0.0450 | dice: 0.6823 | dice_neg: 0.0000 | dice_pos: 0.6826 | IoU: 0.5721
# Starting epoch: 54 | phase: val | ⏰: 15:16:25
# Loss: 0.0476 | dice: 0.6911 | dice_neg: 0.0000 | dice_pos: 0.6911 | IoU: 0.5823
# Epoch    54: reducing learning rate of group 0 to 5.0000e-05.
#
# Starting epoch: 55 | phase: train | ⏰: 15:17:00
# Loss: 0.0410 | dice: 0.7027 | dice_neg: 0.0000 | dice_pos: 0.7027 | IoU: 0.5943
# Starting epoch: 55 | phase: val | ⏰: 15:19:21
# Loss: 0.0436 | dice: 0.7124 | dice_neg: 0.0000 | dice_pos: 0.7124 | IoU: 0.6116
# ******** New optimal found, saving state ********
#
# Starting epoch: 56 | phase: train | ⏰: 15:19:57
# Loss: 0.0377 | dice: 0.7209 | dice_neg: 0.0000 | dice_pos: 0.7209 | IoU: 0.6131
# Starting epoch: 56 | phase: val | ⏰: 15:22:17
# Loss: 0.0424 | dice: 0.7230 | dice_neg: 0.0000 | dice_pos: 0.7230 | IoU: 0.6217
# ******** New optimal found, saving state ********
#
# Starting epoch: 57 | phase: train | ⏰: 15:22:52
# Loss: 0.0377 | dice: 0.7232 | dice_neg: 0.0000 | dice_pos: 0.7232 | IoU: 0.6172
# Starting epoch: 57 | phase: val | ⏰: 15:25:13
# Loss: 0.0417 | dice: 0.7203 | dice_neg: 0.0000 | dice_pos: 0.7203 | IoU: 0.6210
# ******** New optimal found, saving state ********
#
# Starting epoch: 58 | phase: train | ⏰: 15:25:48
# Loss: 0.0357 | dice: 0.7306 | dice_neg: 0.0000 | dice_pos: 0.7306 | IoU: 0.6249
# Starting epoch: 58 | phase: val | ⏰: 15:28:07
# Loss: 0.0404 | dice: 0.7256 | dice_neg: 0.0000 | dice_pos: 0.7256 | IoU: 0.6267
# ******** New optimal found, saving state ********
#
# Starting epoch: 59 | phase: train | ⏰: 15:28:42
# Loss: 0.0361 | dice: 0.7312 | dice_neg: 0.0000 | dice_pos: 0.7312 | IoU: 0.6251
# Starting epoch: 59 | phase: val | ⏰: 15:31:04
# Loss: 0.0400 | dice: 0.7292 | dice_neg: 0.0000 | dice_pos: 0.7292 | IoU: 0.6305
# ******** New optimal found, saving state ********
#
# Starting epoch: 60 | phase: train | ⏰: 15:31:38
# Loss: 0.0347 | dice: 0.7372 | dice_neg: 0.0000 | dice_pos: 0.7372 | IoU: 0.6322
# Starting epoch: 60 | phase: val | ⏰: 15:33:58
# Loss: 0.0401 | dice: 0.7306 | dice_neg: 0.0000 | dice_pos: 0.7306 | IoU: 0.6327
#
# Starting epoch: 61 | phase: train | ⏰: 15:34:33
# Loss: 0.0343 | dice: 0.7423 | dice_neg: 0.0000 | dice_pos: 0.7423 | IoU: 0.6366
# Starting epoch: 61 | phase: val | ⏰: 15:36:52
# Loss: 0.0404 | dice: 0.7317 | dice_neg: 0.0000 | dice_pos: 0.7317 | IoU: 0.6348
#
# Starting epoch: 62 | phase: train | ⏰: 15:37:27
# Loss: 0.0339 | dice: 0.7408 | dice_neg: 0.0000 | dice_pos: 0.7408 | IoU: 0.6366
# Starting epoch: 62 | phase: val | ⏰: 15:39:45
# Loss: 0.0390 | dice: 0.7377 | dice_neg: 0.0000 | dice_pos: 0.7377 | IoU: 0.6403
# ******** New optimal found, saving state ********
#
# Starting epoch: 63 | phase: train | ⏰: 15:40:21
# Loss: 0.0335 | dice: 0.7463 | dice_neg: 0.0000 | dice_pos: 0.7463 | IoU: 0.6420
# Starting epoch: 63 | phase: val | ⏰: 15:42:40
# Loss: 0.0379 | dice: 0.7425 | dice_neg: 0.0000 | dice_pos: 0.7425 | IoU: 0.6453
# ******** New optimal found, saving state ********
#
# Starting epoch: 64 | phase: train | ⏰: 15:43:15
# Loss: 0.0334 | dice: 0.7451 | dice_neg: 0.0000 | dice_pos: 0.7451 | IoU: 0.6416
# Starting epoch: 64 | phase: val | ⏰: 15:45:36
# Loss: 0.0383 | dice: 0.7435 | dice_neg: 0.0000 | dice_pos: 0.7435 | IoU: 0.6466
#
# Starting epoch: 65 | phase: train | ⏰: 15:46:11
# Loss: 0.0330 | dice: 0.7489 | dice_neg: 0.0000 | dice_pos: 0.7489 | IoU: 0.6455
# Starting epoch: 65 | phase: val | ⏰: 15:48:30
# Loss: 0.0379 | dice: 0.7439 | dice_neg: 0.0000 | dice_pos: 0.7439 | IoU: 0.6480
#
# Starting epoch: 66 | phase: train | ⏰: 15:49:06
# Loss: 0.0334 | dice: 0.7491 | dice_neg: 0.0000 | dice_pos: 0.7491 | IoU: 0.6451
# Starting epoch: 66 | phase: val | ⏰: 15:51:27
# Loss: 0.0377 | dice: 0.7448 | dice_neg: 0.0000 | dice_pos: 0.7448 | IoU: 0.6493
# ******** New optimal found, saving state ********
#
# Starting epoch: 67 | phase: train | ⏰: 15:52:03
# Loss: 0.0328 | dice: 0.7541 | dice_neg: 0.0000 | dice_pos: 0.7541 | IoU: 0.6507
# Starting epoch: 67 | phase: val | ⏰: 15:54:23
# Loss: 0.0381 | dice: 0.7461 | dice_neg: 0.0000 | dice_pos: 0.7461 | IoU: 0.6508
#
# Starting epoch: 68 | phase: train | ⏰: 15:54:58
# Loss: 0.0329 | dice: 0.7556 | dice_neg: 0.0000 | dice_pos: 0.7556 | IoU: 0.6529
# Starting epoch: 68 | phase: val | ⏰: 15:57:18
# Loss: 0.0373 | dice: 0.7529 | dice_neg: 0.0000 | dice_pos: 0.7529 | IoU: 0.6567
# ******** New optimal found, saving state ********
#
# Starting epoch: 69 | phase: train | ⏰: 15:57:52
# Loss: 0.0316 | dice: 0.7575 | dice_neg: 0.0000 | dice_pos: 0.7575 | IoU: 0.6548
# Starting epoch: 69 | phase: val | ⏰: 16:00:12
# Loss: 0.0364 | dice: 0.7559 | dice_neg: 0.0000 | dice_pos: 0.7559 | IoU: 0.6602
# ******** New optimal found, saving state ********
#
# Starting epoch: 70 | phase: train | ⏰: 16:00:47
# Loss: 0.0314 | dice: 0.7605 | dice_neg: 0.0000 | dice_pos: 0.7605 | IoU: 0.6578
# Starting epoch: 70 | phase: val | ⏰: 16:03:07
# Loss: 0.0369 | dice: 0.7476 | dice_neg: 0.0000 | dice_pos: 0.7476 | IoU: 0.6537
#
# Starting epoch: 71 | phase: train | ⏰: 16:03:41
# Loss: 0.0313 | dice: 0.7606 | dice_neg: 0.0000 | dice_pos: 0.7609 | IoU: 0.6589
# Starting epoch: 71 | phase: val | ⏰: 16:06:02
# Loss: 0.0361 | dice: 0.7566 | dice_neg: 0.0000 | dice_pos: 0.7566 | IoU: 0.6629
# ******** New optimal found, saving state ********
#
# Starting epoch: 72 | phase: train | ⏰: 16:06:37
# Loss: 0.0310 | dice: 0.7630 | dice_neg: 0.0018 | dice_pos: 0.7629 | IoU: 0.6607
# Starting epoch: 72 | phase: val | ⏰: 16:08:57
# Loss: 0.0363 | dice: 0.7565 | dice_neg: 0.0000 | dice_pos: 0.7565 | IoU: 0.6630
#
# Starting epoch: 73 | phase: train | ⏰: 16:09:32
# Loss: 0.0302 | dice: 0.7660 | dice_neg: 0.0000 | dice_pos: 0.7660 | IoU: 0.6644
# Starting epoch: 73 | phase: val | ⏰: 16:11:51
# Loss: 0.0355 | dice: 0.7626 | dice_neg: 0.0000 | dice_pos: 0.7626 | IoU: 0.6690
# ******** New optimal found, saving state ********
#
# Starting epoch: 74 | phase: train | ⏰: 16:12:26
# Loss: 0.0303 | dice: 0.7650 | dice_neg: 0.0000 | dice_pos: 0.7650 | IoU: 0.6644
# Starting epoch: 74 | phase: val | ⏰: 16:14:45
# Loss: 0.0356 | dice: 0.7618 | dice_neg: 0.0000 | dice_pos: 0.7618 | IoU: 0.6688

# %%
# PLOT TRAINING
losses = model_trainer.losses
dice_scores = model_trainer.dice_scores # overall dice
iou_scores = model_trainer.iou_scores

def plot(scores, name):
    plt.figure(figsize=(15,5))
    plt.plot(range(len(scores["train"])), scores["train"], label=f'train {name}')
    plt.plot(range(len(scores["train"])), scores["val"], label=f'val {name}')
    plt.title(f'{name} plot'); plt.xlabel('Epoch'); plt.ylabel(f'{name}');
    plt.legend(); 
    plt.show()

plot(losses, "BCE loss")
plot(dice_scores, "Dice score")
plot(iou_scores, "IoU score")

# %% [markdown]
# ## Test prediction

# %%
class TestDataset(Dataset):
    def __init__(self, root, df, size, mean, std, tta=4):
        self.root = root
        self.size = size
        self.fnames = list(df["ImageId"])
        self.num_samples = len(self.fnames)
        self.transform = Compose(
            [
                Normalize(mean=mean, std=std, p=1),
                Resize(size, size),
                ToTensor(),
            ]
        )

    def __getitem__(self, idx):
        fname = self.fnames[idx]
        path = os.path.join(self.root, fname + ".png")
        image = cv2.imread(path)
        images = self.transform(image=image)["image"]
        return images

    def __len__(self):
        return self.num_samples

def post_process(probability, threshold, min_size):
    mask = cv2.threshold(probability, threshold, 1, cv2.THRESH_BINARY)[1]
    num_component, component = cv2.connectedComponents(mask.astype(np.uint8))
    predictions = np.zeros((1024, 1024), np.float32)
    num = 0
    for c in range(1, num_component):
        p = (component == c)
        if p.sum() > min_size:
            predictions[p] = 1
            num += 1
    return predictions, num

# %%
size = 512
mean = (0.485, 0.456, 0.406)
std = (0.229, 0.224, 0.225)
num_workers = 8
batch_size = 16
best_threshold = 0.5
min_size = 0
device = torch.device("cuda:01")
df = pd.read_csv(sample_submission_path)
testset = DataLoader(
    TestDataset(test_data_folder, df, size, mean, std),
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
)
model = model_trainer.net # get the model from model_trainer object
model.eval()
state = torch.load('./model.pth', map_location=lambda storage, loc: storage)
model.load_state_dict(state["state_dict"])
encoded_pixels = []
for i, batch in enumerate(tqdm(testset)):
    preds = torch.sigmoid(model(batch.to(device)))
    preds = preds.detach().cpu().numpy()[:, 0, :, :] # (batch_size, 1, size, size) -> (batch_size, size, size)
    for probability in preds:
        if probability.shape != (1024, 1024):
            probability = cv2.resize(probability, dsize=(1024, 1024), interpolation=cv2.INTER_LINEAR)
        predict, num_predict = post_process(probability, best_threshold, min_size)
        if num_predict == 0:
            encoded_pixels.append('-1')
        else:
            r = run_length_encode(predict)
            encoded_pixels.append(r)
df['EncodedPixels'] = encoded_pixels
df.to_csv('submission.csv', columns=['ImageId', 'EncodedPixels'], index=False)
# Out:
# HBox(children=(IntProgress(value=0, max=86), HTML(value='')))

# %%
df.head()
# Out:
#                                              ImageId  \
# 0  1.2.276.0.7230010.3.1.4.8323329.6067.151787519...
# 1  1.2.276.0.7230010.3.1.4.8323329.6214.151787519...
# 2  1.2.276.0.7230010.3.1.4.8323329.6177.151787519...
# 3  1.2.276.0.7230010.3.1.4.8323329.6655.151787519...
# 4  1.2.276.0.7230010.3.1.4.8323329.6359.151787519...
#
#                                        EncodedPixels
# 0  206257 14 1005 25 995 31 989 37 985 40 981 43 ...
# 1  595207 9 1013 12 1010 14 1009 16 1007 17 1006 ...
# 2  573505 12 1009 22 1000 25 997 28 994 30 993 32...
# 3                                                 -1
# 4  523427 5 1016 9 1014 10 1012 12 1011 13 1010 1...

# %% [markdown]
# This kernel has a lot of scope for improvement, specially with augmentations part, I'll push updates soon.
#
# I've achieved 0.8432 by training this exact model on 512 sized images then fine-tuning it on 1024 then combining the results with a seperately trained EfficientNet-b5 binary classifier.
#
# `segmentation_models_pytorch` has got many other segmentation models implemented, try them out :)
#
# I've learnt a lot from fellow kagglers, I've borrowed a lot of code from you guys, special shout-out to [@Abhishek](https://www.kaggle.com/abhishek), [@Yury](https://www.kaggle.com/deyury), [Heng](https://www.kaggle.com/hengck23), [Ekhtiar](https://www.kaggle.com/ekhtiar), [lafoss](https://www.kaggle.com/iafoss), [Siddhartha](https://www.kaggle.com/meaninglesslives) and many other kagglers :)
#
# Kaggle is <3
