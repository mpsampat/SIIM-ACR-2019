# %% [markdown]
# This Kernel uses UNet architecture with ResNet34 encoder, I've used [segmentation_models.pytorch](https://github.com/qubvel/segmentation_models.pytorch) library which has many inbuilt segmentation architectures. This kernel is inspired by [Yury](https://www.kaggle.com/deyury)'s discussion thread [here](https://www.kaggle.com/c/siim-acr-pneumothorax-segmentation/discussion/99440#591985). I've used snippets from multiple other public kernels I've given due credits at the end of this notebook.
#
# What's down below?
#
# * UNet with imagenet pretrained ResNet34 architecture
# * Training on 512x512 sized images/masks with Standard Augmentations
# * MixedLoss (weighted sum of Focal loss and dice loss)
# * Gradient Accumulution

# %%
#!pip install git+https://github.com/qubvel/segmentation_models.pytorch > /dev/null 2>&1 # run bash cmd without output.

# %%
import os
import cv2
import pdb
import time
import warnings
import random
import numpy as np
import pandas as pd
from tqdm import tqdm_notebook as tqdm
from torch.optim.lr_scheduler import ReduceLROnPlateau
from sklearn.model_selection import StratifiedKFold
import torch
import torch.nn as nn
from torch.nn import functional as F
import torch.optim as optim
import torch.backends.cudnn as cudnn
from torch.utils.data import DataLoader, Dataset, sampler
from matplotlib import pyplot as plt
from albumentations import (HorizontalFlip, ShiftScaleRotate, Normalize, Resize, Compose, GaussNoise)
from albumentations.torch import ToTensor
import segmentation_models_pytorch as smp
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Utility functions

# %%
def run_length_decode(rle, height=1024, width=1024, fill_value=1):
    component = np.zeros((height, width), np.float32)
    component = component.reshape(-1)
    rle = np.array([int(s) for s in rle.strip().split(' ')])
    rle = rle.reshape(-1, 2)
    start = 0
    for index, length in rle:
        start = start+index
        end = start+length
        component[start: end] = fill_value
        start = end
    component = component.reshape(width, height).T
    return component

def run_length_encode(component):
    component = component.T.flatten()
    start = np.where(component[1:] > component[:-1])[0]+1
    end = np.where(component[:-1] > component[1:])[0]+1
    length = end-start
    rle = []
    for i in range(len(length)):
        if i == 0:
            rle.extend([start[0], length[0]])
        else:
            rle.extend([start[i]-end[i-1], length[i]])
    rle = ' '.join([str(r) for r in rle])
    return rle

# %% [markdown]
# ## Dataloader

# %%
class SIIMDataset(Dataset):
    def __init__(self, df, data_folder, size, mean, std, phase):
        self.df = df
        self.root = data_folder
        self.size = size
        self.mean = mean
        self.std = std
        self.phase = phase
        self.transforms = get_transforms(phase, size, mean, std)
        self.gb = self.df.groupby('ImageId')
        self.fnames = list(self.gb.groups.keys())

    def __getitem__(self, idx):
        image_id = self.fnames[idx]
        df = self.gb.get_group(image_id)
        annotations = df[' EncodedPixels'].tolist()
        image_path = os.path.join(self.root, image_id + ".png")
        image = cv2.imread(image_path)
        mask = np.zeros([1024, 1024])
        if annotations[0] != '-1':
            for rle in annotations:
                mask += run_length_decode(rle)
        mask = (mask >= 1).astype('float32') # for overlap cases
        augmented = self.transforms(image=image, mask=mask)
        image = augmented['image']
        mask = augmented['mask']
        return image, mask

    def __len__(self):
        return len(self.fnames)


def get_transforms(phase, size, mean, std):
    list_transforms = []
    if phase == "train":
        list_transforms.extend(
            [
#                 HorizontalFlip(),
                ShiftScaleRotate(
                    shift_limit=0,  # no resizing
                    scale_limit=0.1,
                    rotate_limit=10, # rotate
                    p=0.5,
                    border_mode=cv2.BORDER_CONSTANT
                ),
#                 GaussNoise(),
            ]
        )
    list_transforms.extend(
        [
            Normalize(mean=mean, std=std, p=1),
            Resize(size, size),
            ToTensor(),
        ]
    )

    list_trfms = Compose(list_transforms)
    return list_trfms

def provider(
    fold,
    total_folds,
    data_folder,
    df_path,
    phase,
    size,
    mean=None,
    std=None,
    batch_size=8,
    num_workers=4,
):
    df = pd.read_csv(df_path)
    df = df.drop_duplicates('ImageId')
    df_with_mask = df[df[" EncodedPixels"] != " -1"]
    df_with_mask['has_mask'] = 1
    df_without_mask = df[df[" EncodedPixels"] != " -1"]
    df_without_mask['has_mask'] = 0
    df_without_mask_sampled = df_without_mask.sample(len(df_with_mask))
    df = pd.concat([df_with_mask, df_without_mask_sampled])
    #NOTE: equal number of positive and negative cases are chosen.
    
    # choose only positive samples:
    df = pd.concat([df_with_mask])
    
    kfold = StratifiedKFold(total_folds, shuffle=True, random_state=69)
    train_idx, val_idx = list(kfold.split(
        df["ImageId"], df["has_mask"]))[fold]
    train_df, val_df = df.iloc[train_idx], df.iloc[val_idx]
    df = train_df if phase == "train" else val_df
    # NOTE: total_folds=5 -> train/val : 80%/20%
    
    image_dataset = SIIMDataset(df, data_folder, size, mean, std, phase)

    dataloader = DataLoader(
        image_dataset,
        batch_size=batch_size,
        num_workers=num_workers,
        pin_memory=True,
        shuffle=True,
    )
    return dataloader

# %%
torch.cuda.set_device(1)
sample_submission_path = '../sample_submission.csv'
train_rle_path = '../train-rle.csv'
data_folder = "../data512/train"
test_data_folder = "../data512/test"

# %% [markdown]
# ### Dataloader sanity check

# %%
dataloader = provider(
    fold=0,
    total_folds=5,
    data_folder=data_folder,
    df_path=train_rle_path,
    phase="train",
    size=512,
    mean = (0.485, 0.456, 0.406),
    std = (0.229, 0.224, 0.225),
    batch_size=16,
    num_workers=4,
)

# %%
batch = next(iter(dataloader)) # get a batch from the dataloader
images, masks = batch

# %%
# plot some random images in the `batch`
idx = random.choice(range(16))
plt.imshow(images[idx][0], cmap='bone')
plt.imshow(masks[idx][0], alpha=0.2, cmap='Reds')
plt.show()

# %% [markdown]
# ## Losses
#
# This kernel uses a weighted sum of Focal Loss and Dice Loss, let's call it MixedLoss

# %%
def dice_loss(input, target):
    input = torch.sigmoid(input)
    smooth = 1.0
    iflat = input.view(-1)
    tflat = target.view(-1)
    intersection = (iflat * tflat).sum()
    return ((2.0 * intersection + smooth) / (iflat.sum() + tflat.sum() + smooth))


class FocalLoss(nn.Module):
    def __init__(self, gamma):
        super().__init__()
        self.gamma = gamma

    def forward(self, input, target):
        if not (target.size() == input.size()):
            raise ValueError("Target size ({}) must be the same as input size ({})"
                             .format(target.size(), input.size()))
        max_val = (-input).clamp(min=0)
        loss = input - input * target + max_val + \
            ((-max_val).exp() + (-input - max_val).exp()).log()
        invprobs = F.logsigmoid(-input * (target * 2.0 - 1.0))
        loss = (invprobs * self.gamma).exp() * loss
        return loss.mean()


class MixedLoss(nn.Module):
    def __init__(self, alpha, gamma):
        super().__init__()
        self.alpha = alpha
        self.focal = FocalLoss(gamma)

    def forward(self, input, target):
        loss = self.alpha*self.focal(input, target) - torch.log(dice_loss(input, target))
        return loss.mean()

# %% [markdown]
# ## Some more utility functions
#
# Here are some utility functions for calculating IoU and Dice scores

# %%
def predict(X, threshold):
    X_p = np.copy(X)
    preds = (X_p > threshold).astype('uint8')
    return preds

def metric(probability, truth, threshold=0.5, reduction='none'):
    '''Calculates dice of positive and negative images seperately'''
    '''probability and truth must be torch tensors'''
    batch_size = len(truth)
    with torch.no_grad():
        probability = probability.view(batch_size, -1)
        truth = truth.view(batch_size, -1)
        assert(probability.shape == truth.shape)

        p = (probability > threshold).float()
        t = (truth > 0.5).float()

        t_sum = t.sum(-1)
        p_sum = p.sum(-1)
        neg_index = torch.nonzero(t_sum == 0)
        pos_index = torch.nonzero(t_sum >= 1)

        dice_neg = (p_sum == 0).float()
        dice_pos = 2 * (p*t).sum(-1)/((p+t).sum(-1))

        dice_neg = dice_neg[neg_index]
        dice_pos = dice_pos[pos_index]
        dice = torch.cat([dice_pos, dice_neg])

        dice_neg = np.nan_to_num(dice_neg.mean().item(), 0)
        dice_pos = np.nan_to_num(dice_pos.mean().item(), 0)
        dice = dice.mean().item()

        num_neg = len(neg_index)
        num_pos = len(pos_index)

    return dice, dice_neg, dice_pos, num_neg, num_pos

class Meter:
    '''A meter to keep track of iou and dice scores throughout an epoch'''
    def __init__(self, phase, epoch):
        self.base_threshold = 0.5 # <<<<<<<<<<< here's the threshold
        self.base_dice_scores = []
        self.dice_neg_scores = []
        self.dice_pos_scores = []
        self.iou_scores = []

    def update(self, targets, outputs):
        probs = torch.sigmoid(outputs)
        dice, dice_neg, dice_pos, _, _ = metric(probs, targets, self.base_threshold)
        self.base_dice_scores.append(dice)
        self.dice_pos_scores.append(dice_pos)
        self.dice_neg_scores.append(dice_neg)
        preds = predict(probs, self.base_threshold)
        iou = compute_iou_batch(preds, targets, classes=[1])
        self.iou_scores.append(iou)

    def get_metrics(self):
        dice = np.mean(self.base_dice_scores)
        dice_neg = np.mean(self.dice_neg_scores)
        dice_pos = np.mean(self.dice_pos_scores)
        dices = [dice, dice_neg, dice_pos]
        iou = np.nanmean(self.iou_scores)
        return dices, iou

def epoch_log(phase, epoch, epoch_loss, meter, start):
    '''logging the metrics at the end of an epoch'''
    dices, iou = meter.get_metrics()
    dice, dice_neg, dice_pos = dices
    print("Loss: %0.4f | dice: %0.4f | dice_neg: %0.4f | dice_pos: %0.4f | IoU: %0.4f" % (epoch_loss, dice, dice_neg, dice_pos, iou))
    return dice, iou

def compute_ious(pred, label, classes, ignore_index=255, only_present=True):
    '''computes iou for one ground truth mask and predicted mask'''
    pred[label == ignore_index] = 0
    ious = []
    for c in classes:
        label_c = label == c
        if only_present and np.sum(label_c) == 0:
            ious.append(np.nan)
            continue
        pred_c = pred == c
        intersection = np.logical_and(pred_c, label_c).sum()
        union = np.logical_or(pred_c, label_c).sum()
        if union != 0:
            ious.append(intersection / union)
    return ious if ious else [1]


def compute_iou_batch(outputs, labels, classes=None):
    '''computes mean iou for a batch of ground truth masks and predicted masks'''
    ious = []
    preds = np.copy(outputs) # copy is imp
    labels = np.array(labels) # tensor to np
    for pred, label in zip(preds, labels):
        ious.append(np.nanmean(compute_ious(pred, label, classes)))
    iou = np.nanmean(ious)
    return iou

# %% [markdown]
# ## UNet with ResNet34 model
# Let's take a look at the model

# %%
model = smp.Unet("resnet34", encoder_weights="imagenet", activation=None)

# %%
model # a *deeper* look
# Out:
# Unet(
#   (encoder): ResNetEncoder(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AvgPool2d(kernel_size=7, stride=1, padding=0)
#   )
#   (decoder): UnetDecoder(
#     (layer1): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(768, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer2): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(384, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer3): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(192, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer4): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(128, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (layer5): DecoderBlock(
#       (block): Sequential(
#         (0): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(32, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#         (1): Conv2dReLU(
#           (block): Sequential(
#             (0): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#             (1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#             (2): ReLU(inplace)
#           )
#         )
#       )
#     )
#     (final_conv): Conv2d(16, 1, kernel_size=(1, 1), stride=(1, 1))
#   )
# )

# %% [markdown]
# ## Model Training and validation

# %%
class Trainer(object):
    '''This class takes care of training and validation of our model'''
    def __init__(self, model):
        self.fold = 1
        self.total_folds = 5
        self.num_workers = 6
        self.batch_size = {"train": 4, "val": 4}
        self.accumulation_steps = 32 // self.batch_size['train']
        self.lr = 5e-4
        self.num_epochs = 75
        self.best_loss = float("inf")
        self.phases = ["train", "val"]
        self.device = torch.device("cuda:1")
        torch.set_default_tensor_type("torch.cuda.FloatTensor")
        self.net = model
        self.criterion = MixedLoss(10.0, 2.0)
        self.optimizer = optim.Adam(self.net.parameters(), lr=self.lr)
        self.scheduler = ReduceLROnPlateau(self.optimizer, mode="min", patience=3, verbose=True)
        self.net = self.net.to(self.device)
        cudnn.benchmark = True
        self.dataloaders = {
            phase: provider(
                fold=1,
                total_folds=5,
                data_folder=data_folder,
                df_path=train_rle_path,
                phase=phase,
                size=512,
                mean=(0.485, 0.456, 0.406),
                std=(0.229, 0.224, 0.225),
                batch_size=self.batch_size[phase],
                num_workers=self.num_workers,
            )
            for phase in self.phases
        }
        self.losses = {phase: [] for phase in self.phases}
        self.iou_scores = {phase: [] for phase in self.phases}
        self.dice_scores = {phase: [] for phase in self.phases}
        
    def forward(self, images, targets):
        images = images.to(self.device)
        masks = targets.to(self.device)
        outputs = self.net(images)
        loss = self.criterion(outputs, masks)
        return loss, outputs

    def iterate(self, epoch, phase):
        meter = Meter(phase, epoch)
        start = time.strftime("%H:%M:%S")
        print(f"Starting epoch: {epoch} | phase: {phase} | ⏰: {start}")
        batch_size = self.batch_size[phase]
        self.net.train(phase == "train")
        dataloader = self.dataloaders[phase]
        running_loss = 0.0
        total_batches = len(dataloader)
#         tk0 = tqdm(dataloader, total=total_batches)
        self.optimizer.zero_grad()
        for itr, batch in enumerate(dataloader):
            images, targets = batch
            loss, outputs = self.forward(images, targets)
            loss = loss / self.accumulation_steps
            if phase == "train":
                loss.backward()
                if (itr + 1 ) % self.accumulation_steps == 0:
                    self.optimizer.step()
                    self.optimizer.zero_grad()
            running_loss += loss.item()
            outputs = outputs.detach().cpu()
            meter.update(targets, outputs)
#             tk0.set_postfix(loss=(running_loss / ((itr + 1))))
        epoch_loss = running_loss / total_batches
        dice, iou = epoch_log(phase, epoch, epoch_loss, meter, start)
        self.losses[phase].append(epoch_loss)
        self.dice_scores[phase].append(dice)
        self.iou_scores[phase].append(iou)
        torch.cuda.empty_cache()
        return epoch_loss

    def start(self):
        for epoch in range(self.num_epochs):
            self.iterate(epoch, "train")
            state = {
                "epoch": epoch,
                "best_loss": self.best_loss,
                "state_dict": self.net.state_dict(),
                "optimizer": self.optimizer.state_dict(),
            }
            val_loss = self.iterate(epoch, "val")
            self.scheduler.step(val_loss)
            if val_loss < self.best_loss:
                print("******** New optimal found, saving state ********")
                state["best_loss"] = self.best_loss = val_loss
                torch.save(state, "./model.pth")
            print()

# %%
device = torch.device("cuda:01")
model_trainer = Trainer(model)
model_trainer.start()
# Out:
# Starting epoch: 0 | phase: train | ⏰: 12:49:37
# Loss: 0.3928 | dice: 0.2330 | dice_neg: 0.0000 | dice_pos: 0.2330 | IoU: 0.1524
# Starting epoch: 0 | phase: val | ⏰: 12:51:41
# Loss: 0.2681 | dice: 0.3138 | dice_neg: 0.0000 | dice_pos: 0.3138 | IoU: 0.2125
# ******** New optimal found, saving state ********
#
# Starting epoch: 1 | phase: train | ⏰: 12:52:00
# Loss: 0.2309 | dice: 0.3537 | dice_neg: 0.0000 | dice_pos: 0.3537 | IoU: 0.2479
# Starting epoch: 1 | phase: val | ⏰: 12:53:56
# Loss: 0.2068 | dice: 0.3701 | dice_neg: 0.0000 | dice_pos: 0.3701 | IoU: 0.2624
# ******** New optimal found, saving state ********
#
# Starting epoch: 2 | phase: train | ⏰: 12:54:15
# Loss: 0.1921 | dice: 0.3905 | dice_neg: 0.0000 | dice_pos: 0.3905 | IoU: 0.2799
# Starting epoch: 2 | phase: val | ⏰: 12:56:10
# Loss: 0.1677 | dice: 0.4151 | dice_neg: 0.0000 | dice_pos: 0.4151 | IoU: 0.3027
# ******** New optimal found, saving state ********
#
# Starting epoch: 3 | phase: train | ⏰: 12:56:29
# Loss: 0.1671 | dice: 0.4080 | dice_neg: 0.0000 | dice_pos: 0.4080 | IoU: 0.2977
# Starting epoch: 3 | phase: val | ⏰: 12:58:24
# Loss: 0.1795 | dice: 0.3751 | dice_neg: 0.0000 | dice_pos: 0.3751 | IoU: 0.2617
#
# Starting epoch: 4 | phase: train | ⏰: 12:58:43
# Loss: 0.1600 | dice: 0.4066 | dice_neg: 0.0000 | dice_pos: 0.4066 | IoU: 0.2986
# Starting epoch: 4 | phase: val | ⏰: 13:00:39
# Loss: 0.1429 | dice: 0.4510 | dice_neg: 0.0000 | dice_pos: 0.4510 | IoU: 0.3364
# ******** New optimal found, saving state ********
#
# Starting epoch: 5 | phase: train | ⏰: 13:00:58
# Loss: 0.1425 | dice: 0.4434 | dice_neg: 0.0000 | dice_pos: 0.4434 | IoU: 0.3306
# Starting epoch: 5 | phase: val | ⏰: 13:02:53
# Loss: 0.1470 | dice: 0.4393 | dice_neg: 0.0000 | dice_pos: 0.4393 | IoU: 0.3286
#
# Starting epoch: 6 | phase: train | ⏰: 13:03:12
# Loss: 0.1268 | dice: 0.4657 | dice_neg: 0.0000 | dice_pos: 0.4657 | IoU: 0.3525
# Starting epoch: 6 | phase: val | ⏰: 13:05:07
# Loss: 0.1421 | dice: 0.4477 | dice_neg: 0.0000 | dice_pos: 0.4477 | IoU: 0.3360
# ******** New optimal found, saving state ********
#
# Starting epoch: 7 | phase: train | ⏰: 13:05:27
# Loss: 0.1238 | dice: 0.4622 | dice_neg: 0.0000 | dice_pos: 0.4622 | IoU: 0.3505
# Starting epoch: 7 | phase: val | ⏰: 13:07:22
# Loss: 0.1456 | dice: 0.4376 | dice_neg: 0.0000 | dice_pos: 0.4376 | IoU: 0.3298
#
# Starting epoch: 8 | phase: train | ⏰: 13:07:42
# Loss: 0.1192 | dice: 0.4777 | dice_neg: 0.0000 | dice_pos: 0.4777 | IoU: 0.3632
# Starting epoch: 8 | phase: val | ⏰: 13:09:37
# Loss: 0.1336 | dice: 0.4441 | dice_neg: 0.0000 | dice_pos: 0.4441 | IoU: 0.3374
# ******** New optimal found, saving state ********
#
# Starting epoch: 9 | phase: train | ⏰: 13:09:56
# Loss: 0.1092 | dice: 0.5016 | dice_neg: 0.0000 | dice_pos: 0.5020 | IoU: 0.3861
# Starting epoch: 9 | phase: val | ⏰: 13:11:50
# Loss: 0.1371 | dice: 0.4381 | dice_neg: 0.0000 | dice_pos: 0.4381 | IoU: 0.3285
#
# Starting epoch: 10 | phase: train | ⏰: 13:12:09
# Loss: 0.1060 | dice: 0.4975 | dice_neg: 0.0000 | dice_pos: 0.4975 | IoU: 0.3824
# Starting epoch: 10 | phase: val | ⏰: 13:14:04
# Loss: 0.1666 | dice: 0.3557 | dice_neg: 0.0000 | dice_pos: 0.3557 | IoU: 0.2643
#
# Starting epoch: 11 | phase: train | ⏰: 13:14:24
# Loss: 0.0980 | dice: 0.5074 | dice_neg: 0.0000 | dice_pos: 0.5074 | IoU: 0.3940
# Starting epoch: 11 | phase: val | ⏰: 13:16:18
# Loss: 0.1355 | dice: 0.4230 | dice_neg: 0.0000 | dice_pos: 0.4230 | IoU: 0.3208
#
# Starting epoch: 12 | phase: train | ⏰: 13:16:38
# Loss: 0.0968 | dice: 0.5113 | dice_neg: 0.0000 | dice_pos: 0.5113 | IoU: 0.3967
# Starting epoch: 12 | phase: val | ⏰: 13:18:33
# Loss: 0.1319 | dice: 0.4392 | dice_neg: 0.0000 | dice_pos: 0.4392 | IoU: 0.3327
# ******** New optimal found, saving state ********
#
# Starting epoch: 13 | phase: train | ⏰: 13:18:52
# Loss: 0.0908 | dice: 0.5278 | dice_neg: 0.0000 | dice_pos: 0.5278 | IoU: 0.4109
# Starting epoch: 13 | phase: val | ⏰: 13:20:49
# Loss: 0.1407 | dice: 0.4173 | dice_neg: 0.0000 | dice_pos: 0.4173 | IoU: 0.3207
#
# Starting epoch: 14 | phase: train | ⏰: 13:21:08
# Loss: 0.0914 | dice: 0.5287 | dice_neg: 0.0000 | dice_pos: 0.5287 | IoU: 0.4129
# Starting epoch: 14 | phase: val | ⏰: 13:23:04
# Loss: 0.1343 | dice: 0.4427 | dice_neg: 0.0000 | dice_pos: 0.4427 | IoU: 0.3391
#
# Starting epoch: 15 | phase: train | ⏰: 13:23:23
# Loss: 0.1010 | dice: 0.5058 | dice_neg: 0.0000 | dice_pos: 0.5058 | IoU: 0.3912
# Starting epoch: 15 | phase: val | ⏰: 13:25:19
# Loss: 0.1256 | dice: 0.4577 | dice_neg: 0.0000 | dice_pos: 0.4577 | IoU: 0.3502
# ******** New optimal found, saving state ********
#
# Starting epoch: 16 | phase: train | ⏰: 13:25:39
# Loss: 0.0858 | dice: 0.5425 | dice_neg: 0.0000 | dice_pos: 0.5425 | IoU: 0.4259
# Starting epoch: 16 | phase: val | ⏰: 13:27:34
# Loss: 0.1236 | dice: 0.4146 | dice_neg: 0.0000 | dice_pos: 0.4146 | IoU: 0.3237
# ******** New optimal found, saving state ********
#
# Starting epoch: 17 | phase: train | ⏰: 13:27:53
# Loss: 0.0859 | dice: 0.5477 | dice_neg: 0.0000 | dice_pos: 0.5477 | IoU: 0.4308
# Starting epoch: 17 | phase: val | ⏰: 13:29:50
# Loss: 0.1321 | dice: 0.4446 | dice_neg: 0.0000 | dice_pos: 0.4446 | IoU: 0.3393
#
# Starting epoch: 18 | phase: train | ⏰: 13:30:09
# Loss: 0.0773 | dice: 0.5499 | dice_neg: 0.0000 | dice_pos: 0.5502 | IoU: 0.4379
# Starting epoch: 18 | phase: val | ⏰: 13:32:05
# Loss: 0.1361 | dice: 0.4280 | dice_neg: 0.0000 | dice_pos: 0.4280 | IoU: 0.3299
#
# Starting epoch: 19 | phase: train | ⏰: 13:32:24
# Loss: 0.0779 | dice: 0.5618 | dice_neg: 0.0000 | dice_pos: 0.5618 | IoU: 0.4463
# Starting epoch: 19 | phase: val | ⏰: 13:34:18
# Loss: 0.1470 | dice: 0.3949 | dice_neg: 0.0000 | dice_pos: 0.3949 | IoU: 0.3026
#
# Starting epoch: 20 | phase: train | ⏰: 13:34:37
# Loss: 0.0926 | dice: 0.5195 | dice_neg: 0.0000 | dice_pos: 0.5195 | IoU: 0.4050
# Starting epoch: 20 | phase: val | ⏰: 13:36:31
# Loss: 0.1319 | dice: 0.4405 | dice_neg: 0.0000 | dice_pos: 0.4405 | IoU: 0.3322
# Epoch    20: reducing learning rate of group 0 to 5.0000e-05.
#
# Starting epoch: 21 | phase: train | ⏰: 13:36:50
# Loss: 0.0755 | dice: 0.5654 | dice_neg: 0.0000 | dice_pos: 0.5654 | IoU: 0.4490
# Starting epoch: 21 | phase: val | ⏰: 13:38:45
# Loss: 0.1287 | dice: 0.4399 | dice_neg: 0.0000 | dice_pos: 0.4399 | IoU: 0.3416
#
# Starting epoch: 22 | phase: train | ⏰: 13:39:05
# Loss: 0.0679 | dice: 0.5822 | dice_neg: 0.0000 | dice_pos: 0.5822 | IoU: 0.4683
# Starting epoch: 22 | phase: val | ⏰: 13:41:00
# Loss: 0.1242 | dice: 0.4521 | dice_neg: 0.0000 | dice_pos: 0.4521 | IoU: 0.3522
#
# Starting epoch: 23 | phase: train | ⏰: 13:41:20
# Loss: 0.0649 | dice: 0.6029 | dice_neg: 0.0000 | dice_pos: 0.6029 | IoU: 0.4882
# Starting epoch: 23 | phase: val | ⏰: 13:43:15
# Loss: 0.1193 | dice: 0.4535 | dice_neg: 0.0000 | dice_pos: 0.4535 | IoU: 0.3543
# ******** New optimal found, saving state ********
#
# Starting epoch: 24 | phase: train | ⏰: 13:43:34
# Loss: 0.0623 | dice: 0.6103 | dice_neg: 0.0000 | dice_pos: 0.6103 | IoU: 0.4958
# Starting epoch: 24 | phase: val | ⏰: 13:45:29
# Loss: 0.1230 | dice: 0.4264 | dice_neg: 0.0000 | dice_pos: 0.4264 | IoU: 0.3342
#
# Starting epoch: 25 | phase: train | ⏰: 13:45:48
# Loss: 0.0611 | dice: 0.6126 | dice_neg: 0.0000 | dice_pos: 0.6126 | IoU: 0.4989
# Starting epoch: 25 | phase: val | ⏰: 13:47:44
# Loss: 0.1201 | dice: 0.4569 | dice_neg: 0.0000 | dice_pos: 0.4569 | IoU: 0.3584
#
# Starting epoch: 26 | phase: train | ⏰: 13:48:03
# Loss: 0.0594 | dice: 0.6259 | dice_neg: 0.0000 | dice_pos: 0.6259 | IoU: 0.5111
# Starting epoch: 26 | phase: val | ⏰: 13:49:58
# Loss: 0.1411 | dice: 0.4269 | dice_neg: 0.0000 | dice_pos: 0.4269 | IoU: 0.3341
#
# Starting epoch: 27 | phase: train | ⏰: 13:50:17
# Loss: 0.0573 | dice: 0.6291 | dice_neg: 0.0000 | dice_pos: 0.6291 | IoU: 0.5155
# Starting epoch: 27 | phase: val | ⏰: 13:52:12
# Loss: 0.1249 | dice: 0.4307 | dice_neg: 0.0000 | dice_pos: 0.4307 | IoU: 0.3376
# Epoch    27: reducing learning rate of group 0 to 5.0000e-06.
#
# Starting epoch: 28 | phase: train | ⏰: 13:52:31
# Loss: 0.0570 | dice: 0.6298 | dice_neg: 0.0000 | dice_pos: 0.6298 | IoU: 0.5167
# Starting epoch: 28 | phase: val | ⏰: 13:54:26
# Loss: 0.1311 | dice: 0.4366 | dice_neg: 0.0000 | dice_pos: 0.4366 | IoU: 0.3421
#
# Starting epoch: 29 | phase: train | ⏰: 13:54:45
# Loss: 0.0571 | dice: 0.6300 | dice_neg: 0.0000 | dice_pos: 0.6300 | IoU: 0.5177
# Starting epoch: 29 | phase: val | ⏰: 13:56:39
# Loss: 0.1362 | dice: 0.4356 | dice_neg: 0.0000 | dice_pos: 0.4356 | IoU: 0.3415
#
# Starting epoch: 30 | phase: train | ⏰: 13:56:59
# Loss: 0.0556 | dice: 0.6337 | dice_neg: 0.0000 | dice_pos: 0.6337 | IoU: 0.5206
# Starting epoch: 30 | phase: val | ⏰: 13:58:54
# Loss: 0.1259 | dice: 0.4327 | dice_neg: 0.0000 | dice_pos: 0.4327 | IoU: 0.3390
#
# Starting epoch: 31 | phase: train | ⏰: 13:59:13
# Loss: 0.0555 | dice: 0.6367 | dice_neg: 0.0000 | dice_pos: 0.6367 | IoU: 0.5237
# Starting epoch: 31 | phase: val | ⏰: 14:01:08
# Loss: 0.1256 | dice: 0.4292 | dice_neg: 0.0000 | dice_pos: 0.4292 | IoU: 0.3361
# Epoch    31: reducing learning rate of group 0 to 5.0000e-07.
#
# Starting epoch: 32 | phase: train | ⏰: 14:01:28
# Loss: 0.0558 | dice: 0.6307 | dice_neg: 0.0021 | dice_pos: 0.6304 | IoU: 0.5181
# Starting epoch: 32 | phase: val | ⏰: 14:03:22
# Loss: 0.1267 | dice: 0.4341 | dice_neg: 0.0000 | dice_pos: 0.4341 | IoU: 0.3402
#
# Starting epoch: 33 | phase: train | ⏰: 14:03:41
# Loss: 0.0564 | dice: 0.6304 | dice_neg: 0.0000 | dice_pos: 0.6304 | IoU: 0.5184
# Starting epoch: 33 | phase: val | ⏰: 14:05:38
# Loss: 0.1254 | dice: 0.4291 | dice_neg: 0.0000 | dice_pos: 0.4291 | IoU: 0.3360
#
# Starting epoch: 34 | phase: train | ⏰: 14:05:57
# Loss: 0.0560 | dice: 0.6306 | dice_neg: 0.0000 | dice_pos: 0.6309 | IoU: 0.5187
# Starting epoch: 34 | phase: val | ⏰: 14:07:53
# Loss: 0.1260 | dice: 0.4307 | dice_neg: 0.0000 | dice_pos: 0.4307 | IoU: 0.3372
#
# Starting epoch: 35 | phase: train | ⏰: 14:08:13
# Loss: 0.0563 | dice: 0.6329 | dice_neg: 0.0000 | dice_pos: 0.6329 | IoU: 0.5201
# Starting epoch: 35 | phase: val | ⏰: 14:10:08
# Loss: 0.1437 | dice: 0.4206 | dice_neg: 0.0000 | dice_pos: 0.4206 | IoU: 0.3292
# Epoch    35: reducing learning rate of group 0 to 5.0000e-08.
#
# Starting epoch: 36 | phase: train | ⏰: 14:10:27
# Loss: 0.0562 | dice: 0.6345 | dice_neg: 0.0000 | dice_pos: 0.6345 | IoU: 0.5217
# Starting epoch: 36 | phase: val | ⏰: 14:12:22
# Loss: 0.1292 | dice: 0.4324 | dice_neg: 0.0000 | dice_pos: 0.4324 | IoU: 0.3381
#
# Starting epoch: 37 | phase: train | ⏰: 14:12:42
# Loss: 0.0560 | dice: 0.6373 | dice_neg: 0.0000 | dice_pos: 0.6373 | IoU: 0.5233
# Starting epoch: 37 | phase: val | ⏰: 14:14:37
# Loss: 0.1384 | dice: 0.4218 | dice_neg: 0.0000 | dice_pos: 0.4218 | IoU: 0.3303
#
# Starting epoch: 38 | phase: train | ⏰: 14:14:57
# Loss: 0.0560 | dice: 0.6366 | dice_neg: 0.0000 | dice_pos: 0.6366 | IoU: 0.5236
# Starting epoch: 38 | phase: val | ⏰: 14:16:53
# Loss: 0.1275 | dice: 0.4341 | dice_neg: 0.0000 | dice_pos: 0.4341 | IoU: 0.3407
#
# Starting epoch: 39 | phase: train | ⏰: 14:17:13
# Loss: 0.0547 | dice: 0.6367 | dice_neg: 0.0000 | dice_pos: 0.6367 | IoU: 0.5232
# Starting epoch: 39 | phase: val | ⏰: 14:19:08
# Loss: 0.1323 | dice: 0.4294 | dice_neg: 0.0000 | dice_pos: 0.4294 | IoU: 0.3357
# Epoch    39: reducing learning rate of group 0 to 5.0000e-09.
#
# Starting epoch: 40 | phase: train | ⏰: 14:19:27
# Loss: 0.0565 | dice: 0.6370 | dice_neg: 0.0000 | dice_pos: 0.6370 | IoU: 0.5236
# Starting epoch: 40 | phase: val | ⏰: 14:21:23
# Loss: 0.1299 | dice: 0.4274 | dice_neg: 0.0000 | dice_pos: 0.4274 | IoU: 0.3353
#
# Starting epoch: 41 | phase: train | ⏰: 14:21:42
# Loss: 0.0564 | dice: 0.6333 | dice_neg: 0.0000 | dice_pos: 0.6333 | IoU: 0.5208
# Starting epoch: 41 | phase: val | ⏰: 14:23:36
# Loss: 0.1303 | dice: 0.4289 | dice_neg: 0.0000 | dice_pos: 0.4289 | IoU: 0.3362
#
# Starting epoch: 42 | phase: train | ⏰: 14:23:55
# Loss: 0.0562 | dice: 0.6309 | dice_neg: 0.0000 | dice_pos: 0.6309 | IoU: 0.5185
# Starting epoch: 42 | phase: val | ⏰: 14:25:51
# Loss: 0.1311 | dice: 0.4278 | dice_neg: 0.0000 | dice_pos: 0.4278 | IoU: 0.3349
#
# Starting epoch: 43 | phase: train | ⏰: 14:26:11
# Loss: 0.0559 | dice: 0.6320 | dice_neg: 0.0000 | dice_pos: 0.6320 | IoU: 0.5189
# Starting epoch: 43 | phase: val | ⏰: 14:28:07
# Loss: 0.1269 | dice: 0.4257 | dice_neg: 0.0000 | dice_pos: 0.4257 | IoU: 0.3329
#
# Starting epoch: 44 | phase: train | ⏰: 14:28:26
# Loss: 0.0560 | dice: 0.6362 | dice_neg: 0.0000 | dice_pos: 0.6362 | IoU: 0.5233
# Starting epoch: 44 | phase: val | ⏰: 14:30:21
# Loss: 0.1356 | dice: 0.4228 | dice_neg: 0.0000 | dice_pos: 0.4228 | IoU: 0.3311
#
# Starting epoch: 45 | phase: train | ⏰: 14:30:40
# Loss: 0.0562 | dice: 0.6364 | dice_neg: 0.0000 | dice_pos: 0.6364 | IoU: 0.5231
# Starting epoch: 45 | phase: val | ⏰: 14:32:34
# Loss: 0.1251 | dice: 0.4228 | dice_neg: 0.0000 | dice_pos: 0.4228 | IoU: 0.3311
#
# Starting epoch: 46 | phase: train | ⏰: 14:32:53
# Loss: 0.0570 | dice: 0.6264 | dice_neg: 0.0000 | dice_pos: 0.6264 | IoU: 0.5144
# Starting epoch: 46 | phase: val | ⏰: 14:34:50
# Loss: 0.1424 | dice: 0.4325 | dice_neg: 0.0000 | dice_pos: 0.4325 | IoU: 0.3388
#
# Starting epoch: 47 | phase: train | ⏰: 14:35:09
# Loss: 0.0570 | dice: 0.6377 | dice_neg: 0.0000 | dice_pos: 0.6377 | IoU: 0.5245
# Starting epoch: 47 | phase: val | ⏰: 14:37:04
# Loss: 0.1324 | dice: 0.4252 | dice_neg: 0.0000 | dice_pos: 0.4252 | IoU: 0.3327
#
# Starting epoch: 48 | phase: train | ⏰: 14:37:23
# Loss: 0.0553 | dice: 0.6322 | dice_neg: 0.0000 | dice_pos: 0.6322 | IoU: 0.5189
# Starting epoch: 48 | phase: val | ⏰: 14:39:19
# Loss: 0.1351 | dice: 0.4263 | dice_neg: 0.0000 | dice_pos: 0.4263 | IoU: 0.3339
#
# Starting epoch: 49 | phase: train | ⏰: 14:39:38
# Loss: 0.0566 | dice: 0.6295 | dice_neg: 0.0000 | dice_pos: 0.6295 | IoU: 0.5171
# Starting epoch: 49 | phase: val | ⏰: 14:41:33
# Loss: 0.1363 | dice: 0.4257 | dice_neg: 0.0000 | dice_pos: 0.4257 | IoU: 0.3332
#
# Starting epoch: 50 | phase: train | ⏰: 14:41:52
# Loss: 0.0567 | dice: 0.6329 | dice_neg: 0.0000 | dice_pos: 0.6329 | IoU: 0.5202
# Starting epoch: 50 | phase: val | ⏰: 14:43:48
# Loss: 0.1294 | dice: 0.4277 | dice_neg: 0.0000 | dice_pos: 0.4277 | IoU: 0.3347
#
# Starting epoch: 51 | phase: train | ⏰: 14:44:08
# Loss: 0.0553 | dice: 0.6326 | dice_neg: 0.0000 | dice_pos: 0.6326 | IoU: 0.5209
# Starting epoch: 51 | phase: val | ⏰: 14:46:04
# Loss: 0.1352 | dice: 0.4300 | dice_neg: 0.0000 | dice_pos: 0.4300 | IoU: 0.3366
#
# Starting epoch: 52 | phase: train | ⏰: 14:46:23
# Loss: 0.0561 | dice: 0.6317 | dice_neg: 0.0000 | dice_pos: 0.6317 | IoU: 0.5200
# Starting epoch: 52 | phase: val | ⏰: 14:48:18
# Loss: 0.1315 | dice: 0.4252 | dice_neg: 0.0000 | dice_pos: 0.4252 | IoU: 0.3324
#
# Starting epoch: 53 | phase: train | ⏰: 14:48:37
# Loss: 0.0567 | dice: 0.6347 | dice_neg: 0.0000 | dice_pos: 0.6347 | IoU: 0.5219
# Starting epoch: 53 | phase: val | ⏰: 14:50:32
# Loss: 0.1296 | dice: 0.4327 | dice_neg: 0.0000 | dice_pos: 0.4327 | IoU: 0.3390
#
# Starting epoch: 54 | phase: train | ⏰: 14:50:52
# Loss: 0.0557 | dice: 0.6323 | dice_neg: 0.0000 | dice_pos: 0.6323 | IoU: 0.5193
# Starting epoch: 54 | phase: val | ⏰: 14:52:46
# Loss: 0.1394 | dice: 0.4217 | dice_neg: 0.0000 | dice_pos: 0.4217 | IoU: 0.3304
#
# Starting epoch: 55 | phase: train | ⏰: 14:53:06
# Loss: 0.0556 | dice: 0.6367 | dice_neg: 0.0000 | dice_pos: 0.6367 | IoU: 0.5239
# Starting epoch: 55 | phase: val | ⏰: 14:55:00
# Loss: 0.1385 | dice: 0.4148 | dice_neg: 0.0000 | dice_pos: 0.4148 | IoU: 0.3239
#
# Starting epoch: 56 | phase: train | ⏰: 14:55:19
# Loss: 0.0563 | dice: 0.6317 | dice_neg: 0.0000 | dice_pos: 0.6317 | IoU: 0.5201
# Starting epoch: 56 | phase: val | ⏰: 14:57:13
# Loss: 0.1245 | dice: 0.4314 | dice_neg: 0.0000 | dice_pos: 0.4314 | IoU: 0.3384
#
# Starting epoch: 57 | phase: train | ⏰: 14:57:32
# Loss: 0.0561 | dice: 0.6301 | dice_neg: 0.0000 | dice_pos: 0.6301 | IoU: 0.5174
# Starting epoch: 57 | phase: val | ⏰: 14:59:28
# Loss: 0.1304 | dice: 0.4274 | dice_neg: 0.0000 | dice_pos: 0.4274 | IoU: 0.3346
#
# Starting epoch: 58 | phase: train | ⏰: 14:59:47
# Loss: 0.0565 | dice: 0.6333 | dice_neg: 0.0021 | dice_pos: 0.6330 | IoU: 0.5204
# Starting epoch: 58 | phase: val | ⏰: 15:01:42
# Loss: 0.1285 | dice: 0.4299 | dice_neg: 0.0000 | dice_pos: 0.4299 | IoU: 0.3368
#
# Starting epoch: 59 | phase: train | ⏰: 15:02:02
# Loss: 0.0571 | dice: 0.6317 | dice_neg: 0.0000 | dice_pos: 0.6317 | IoU: 0.5198
# Starting epoch: 59 | phase: val | ⏰: 15:03:57
# Loss: 0.1341 | dice: 0.4262 | dice_neg: 0.0000 | dice_pos: 0.4262 | IoU: 0.3334
#
# Starting epoch: 60 | phase: train | ⏰: 15:04:16
# Loss: 0.0558 | dice: 0.6306 | dice_neg: 0.0000 | dice_pos: 0.6306 | IoU: 0.5185
# Starting epoch: 60 | phase: val | ⏰: 15:06:11
# Loss: 0.1304 | dice: 0.4312 | dice_neg: 0.0000 | dice_pos: 0.4312 | IoU: 0.3380
#
# Starting epoch: 61 | phase: train | ⏰: 15:06:30
# Loss: 0.0555 | dice: 0.6346 | dice_neg: 0.0000 | dice_pos: 0.6346 | IoU: 0.5214
# Starting epoch: 61 | phase: val | ⏰: 15:08:25
# Loss: 0.1382 | dice: 0.4341 | dice_neg: 0.0000 | dice_pos: 0.4341 | IoU: 0.3404
#
# Starting epoch: 62 | phase: train | ⏰: 15:08:45
# Loss: 0.0562 | dice: 0.6336 | dice_neg: 0.0000 | dice_pos: 0.6336 | IoU: 0.5209
# Starting epoch: 62 | phase: val | ⏰: 15:10:39
# Loss: 0.1383 | dice: 0.4174 | dice_neg: 0.0000 | dice_pos: 0.4174 | IoU: 0.3267
#
# Starting epoch: 63 | phase: train | ⏰: 15:10:59
# Loss: 0.0564 | dice: 0.6353 | dice_neg: 0.0000 | dice_pos: 0.6353 | IoU: 0.5221
# Starting epoch: 63 | phase: val | ⏰: 15:12:54
# Loss: 0.1288 | dice: 0.4232 | dice_neg: 0.0000 | dice_pos: 0.4232 | IoU: 0.3316
#
# Starting epoch: 64 | phase: train | ⏰: 15:13:13
# Loss: 0.0578 | dice: 0.6312 | dice_neg: 0.0000 | dice_pos: 0.6312 | IoU: 0.5184
# Starting epoch: 64 | phase: val | ⏰: 15:15:09
# Loss: 0.1278 | dice: 0.4298 | dice_neg: 0.0000 | dice_pos: 0.4298 | IoU: 0.3357
#
# Starting epoch: 65 | phase: train | ⏰: 15:15:29
# Loss: 0.0560 | dice: 0.6346 | dice_neg: 0.0000 | dice_pos: 0.6346 | IoU: 0.5216
# Starting epoch: 65 | phase: val | ⏰: 15:17:24
# Loss: 0.1353 | dice: 0.4336 | dice_neg: 0.0000 | dice_pos: 0.4336 | IoU: 0.3389
#
# Starting epoch: 66 | phase: train | ⏰: 15:17:44
# Loss: 0.0562 | dice: 0.6345 | dice_neg: 0.0000 | dice_pos: 0.6345 | IoU: 0.5220
# Starting epoch: 66 | phase: val | ⏰: 15:19:39
# Loss: 0.1401 | dice: 0.4241 | dice_neg: 0.0000 | dice_pos: 0.4241 | IoU: 0.3321
#
# Starting epoch: 67 | phase: train | ⏰: 15:19:59
# Loss: 0.0569 | dice: 0.6376 | dice_neg: 0.0000 | dice_pos: 0.6376 | IoU: 0.5241
# Starting epoch: 67 | phase: val | ⏰: 15:21:54
# Loss: 0.1403 | dice: 0.4082 | dice_neg: 0.0000 | dice_pos: 0.4082 | IoU: 0.3196
#
# Starting epoch: 68 | phase: train | ⏰: 15:22:13
# Loss: 0.0561 | dice: 0.6349 | dice_neg: 0.0000 | dice_pos: 0.6349 | IoU: 0.5223
# Starting epoch: 68 | phase: val | ⏰: 15:24:09
# Loss: 0.1313 | dice: 0.4252 | dice_neg: 0.0000 | dice_pos: 0.4252 | IoU: 0.3326
#
# Starting epoch: 69 | phase: train | ⏰: 15:24:28
# Loss: 0.0550 | dice: 0.6386 | dice_neg: 0.0000 | dice_pos: 0.6386 | IoU: 0.5251
# Starting epoch: 69 | phase: val | ⏰: 15:26:23
# Loss: 0.1430 | dice: 0.4191 | dice_neg: 0.0000 | dice_pos: 0.4191 | IoU: 0.3277
#
# Starting epoch: 70 | phase: train | ⏰: 15:26:43
# Loss: 0.0562 | dice: 0.6345 | dice_neg: 0.0000 | dice_pos: 0.6345 | IoU: 0.5221
# Starting epoch: 70 | phase: val | ⏰: 15:28:36
# Loss: 0.1319 | dice: 0.4239 | dice_neg: 0.0000 | dice_pos: 0.4239 | IoU: 0.3317
#
# Starting epoch: 71 | phase: train | ⏰: 15:28:55
# Loss: 0.0565 | dice: 0.6355 | dice_neg: 0.0000 | dice_pos: 0.6355 | IoU: 0.5219
# Starting epoch: 71 | phase: val | ⏰: 15:30:52
# Loss: 0.1351 | dice: 0.4204 | dice_neg: 0.0000 | dice_pos: 0.4204 | IoU: 0.3282
#
# Starting epoch: 72 | phase: train | ⏰: 15:31:11
# Loss: 0.0558 | dice: 0.6329 | dice_neg: 0.0000 | dice_pos: 0.6329 | IoU: 0.5212
# Starting epoch: 72 | phase: val | ⏰: 15:33:06
# Loss: 0.1299 | dice: 0.4357 | dice_neg: 0.0000 | dice_pos: 0.4357 | IoU: 0.3413
#
# Starting epoch: 73 | phase: train | ⏰: 15:33:25
# Loss: 0.0553 | dice: 0.6334 | dice_neg: 0.0000 | dice_pos: 0.6334 | IoU: 0.5209
# Starting epoch: 73 | phase: val | ⏰: 15:35:21
# Loss: 0.1438 | dice: 0.4247 | dice_neg: 0.0000 | dice_pos: 0.4247 | IoU: 0.3325
#
# Starting epoch: 74 | phase: train | ⏰: 15:35:40
# Loss: 0.0579 | dice: 0.6298 | dice_neg: 0.0000 | dice_pos: 0.6298 | IoU: 0.5180
# Starting epoch: 74 | phase: val | ⏰: 15:37:35
# Loss: 0.1359 | dice: 0.4293 | dice_neg: 0.0000 | dice_pos: 0.4293 | IoU: 0.3357

# %%
# PLOT TRAINING
losses = model_trainer.losses
dice_scores = model_trainer.dice_scores # overall dice
iou_scores = model_trainer.iou_scores

def plot(scores, name):
    plt.figure(figsize=(15,5))
    plt.plot(range(len(scores["train"])), scores["train"], label=f'train {name}')
    plt.plot(range(len(scores["train"])), scores["val"], label=f'val {name}')
    plt.title(f'{name} plot'); plt.xlabel('Epoch'); plt.ylabel(f'{name}');
    plt.legend(); 
    plt.show()

plot(losses, "BCE loss")
plot(dice_scores, "Dice score")
plot(iou_scores, "IoU score")

# %% [markdown]
# ## Test prediction

# %%
class TestDataset(Dataset):
    def __init__(self, root, df, size, mean, std, tta=4):
        self.root = root
        self.size = size
        self.fnames = list(df["ImageId"])
        self.num_samples = len(self.fnames)
        self.transform = Compose(
            [
                Normalize(mean=mean, std=std, p=1),
                Resize(size, size),
                ToTensor(),
            ]
        )

    def __getitem__(self, idx):
        fname = self.fnames[idx]
        path = os.path.join(self.root, fname + ".png")
        image = cv2.imread(path)
        images = self.transform(image=image)["image"]
        return images

    def __len__(self):
        return self.num_samples

def post_process(probability, threshold, min_size):
    mask = cv2.threshold(probability, threshold, 1, cv2.THRESH_BINARY)[1]
    num_component, component = cv2.connectedComponents(mask.astype(np.uint8))
    predictions = np.zeros((1024, 1024), np.float32)
    num = 0
    for c in range(1, num_component):
        p = (component == c)
        if p.sum() > min_size:
            predictions[p] = 1
            num += 1
    return predictions, num

# %%
size = 512
mean = (0.485, 0.456, 0.406)
std = (0.229, 0.224, 0.225)
num_workers = 8
batch_size = 16
best_threshold = 0.95
min_size = 3500
device = torch.device("cuda:01")
df = pd.read_csv(sample_submission_path)
testset = DataLoader(
    TestDataset(test_data_folder, df, size, mean, std),
    batch_size=batch_size,
    shuffle=False,
    num_workers=num_workers,
    pin_memory=True,
)
model = model_trainer.net # get the model from model_trainer object
model.eval()
state = torch.load('./model.pth', map_location=lambda storage, loc: storage)
model.load_state_dict(state["state_dict"])
encoded_pixels = []
for i, batch in enumerate(tqdm(testset)):
    preds = torch.sigmoid(model(batch.to(device)))
    preds = preds.detach().cpu().numpy()[:, 0, :, :] # (batch_size, 1, size, size) -> (batch_size, size, size)
    for probability in preds:
        if probability.shape != (1024, 1024):
            probability = cv2.resize(probability, dsize=(1024, 1024), interpolation=cv2.INTER_LINEAR)
        predict, num_predict = post_process(probability, best_threshold, min_size)
        if num_predict == 0:
            encoded_pixels.append('-1')
        else:
            r = run_length_encode(predict)
            encoded_pixels.append(r)
df['EncodedPixels'] = encoded_pixels
df.to_csv('submission.csv', columns=['ImageId', 'EncodedPixels'], index=False)
# Out:
# HBox(children=(IntProgress(value=0, max=86), HTML(value='')))

# %%
df.head()
# Out:
#                                              ImageId  \
# 0  1.2.276.0.7230010.3.1.4.8323329.6067.151787519...
# 1  1.2.276.0.7230010.3.1.4.8323329.6214.151787519...
# 2  1.2.276.0.7230010.3.1.4.8323329.6177.151787519...
# 3  1.2.276.0.7230010.3.1.4.8323329.6655.151787519...
# 4  1.2.276.0.7230010.3.1.4.8323329.6359.151787519...
#
#                                        EncodedPixels
# 0  197109 1 1018 9 1013 10 1011 11 1011 10 1014 5...
# 1                                                 -1
# 2  570438 3 1020 5 1017 7 1014 11 1012 12 1011 15...
# 3  653423 1 1020 6 1015 10 1013 11 1013 12 1011 1...
# 4  529565 3 1020 5 1018 6 1017 6 1017 7 1017 7 10...

# %% [markdown]
# This kernel has a lot of scope for improvement, specially with augmentations part, I'll push updates soon.
#
# I've achieved 0.8432 by training this exact model on 512 sized images then fine-tuning it on 1024 then combining the results with a seperately trained EfficientNet-b5 binary classifier.
#
# `segmentation_models_pytorch` has got many other segmentation models implemented, try them out :)
#
# I've learnt a lot from fellow kagglers, I've borrowed a lot of code from you guys, special shout-out to [@Abhishek](https://www.kaggle.com/abhishek), [@Yury](https://www.kaggle.com/deyury), [Heng](https://www.kaggle.com/hengck23), [Ekhtiar](https://www.kaggle.com/ekhtiar), [lafoss](https://www.kaggle.com/iafoss), [Siddhartha](https://www.kaggle.com/meaninglesslives) and many other kagglers :)
#
# Kaggle is <3
