# %% [markdown]
# # Import Cool Stuff

# %%
from __future__ import print_function

from collections import defaultdict, deque
import datetime
import pickle
import time
import torch.distributed as dist
import errno

import collections
import os
import numpy as np
import torch
import torch.utils.data
from PIL import Image, ImageFile
import pandas as pd
from tqdm import tqdm
from torchvision import transforms
import torchvision
import random
from torchvision.models.detection.faster_rcnn import FastRCNNPredictor
from torchvision.models.detection.mask_rcnn import MaskRCNNPredictor

ImageFile.LOAD_TRUNCATED_IMAGES = True

# %% [markdown]
# # Utility Functions (hidden)

# %%
class SmoothedValue(object):
    """Track a series of values and provide access to smoothed values over a
    window or the global series average.
    """

    def __init__(self, window_size=20, fmt=None):
        if fmt is None:
            fmt = "{median:.4f} ({global_avg:.4f})"
        self.deque = deque(maxlen=window_size)
        self.total = 0.0
        self.count = 0
        self.fmt = fmt

    def update(self, value, n=1):
        self.deque.append(value)
        self.count += n
        self.total += value * n

    def synchronize_between_processes(self):
        """
        Warning: does not synchronize the deque!
        """
        if not is_dist_avail_and_initialized():
            return
        t = torch.tensor([self.count, self.total], dtype=torch.float64, device='cuda')
        dist.barrier()
        dist.all_reduce(t)
        t = t.tolist()
        self.count = int(t[0])
        self.total = t[1]

    @property
    def median(self):
        d = torch.tensor(list(self.deque))
        return d.median().item()

    @property
    def avg(self):
        d = torch.tensor(list(self.deque), dtype=torch.float32)
        return d.mean().item()

    @property
    def global_avg(self):
        return self.total / self.count

    @property
    def max(self):
        return max(self.deque)

    @property
    def value(self):
        return self.deque[-1]

    def __str__(self):
        return self.fmt.format(
            median=self.median,
            avg=self.avg,
            global_avg=self.global_avg,
            max=self.max,
            value=self.value)


def all_gather(data):
    """
    Run all_gather on arbitrary picklable data (not necessarily tensors)
    Args:
        data: any picklable object
    Returns:
        list[data]: list of data gathered from each rank
    """
    world_size = get_world_size()
    if world_size == 1:
        return [data]

    # serialized to a Tensor
    buffer = pickle.dumps(data)
    storage = torch.ByteStorage.from_buffer(buffer)
    tensor = torch.ByteTensor(storage).to("cuda")

    # obtain Tensor size of each rank
    local_size = torch.tensor([tensor.numel()], device="cuda")
    size_list = [torch.tensor([0], device="cuda") for _ in range(world_size)]
    dist.all_gather(size_list, local_size)
    size_list = [int(size.item()) for size in size_list]
    max_size = max(size_list)

    # receiving Tensor from all ranks
    # we pad the tensor because torch all_gather does not support
    # gathering tensors of different shapes
    tensor_list = []
    for _ in size_list:
        tensor_list.append(torch.empty((max_size,), dtype=torch.uint8, device="cuda"))
    if local_size != max_size:
        padding = torch.empty(size=(max_size - local_size,), dtype=torch.uint8, device="cuda")
        tensor = torch.cat((tensor, padding), dim=0)
    dist.all_gather(tensor_list, tensor)

    data_list = []
    for size, tensor in zip(size_list, tensor_list):
        buffer = tensor.cpu().numpy().tobytes()[:size]
        data_list.append(pickle.loads(buffer))

    return data_list


def reduce_dict(input_dict, average=True):
    """
    Args:
        input_dict (dict): all the values will be reduced
        average (bool): whether to do average or sum
    Reduce the values in the dictionary from all processes so that all processes
    have the averaged results. Returns a dict with the same fields as
    input_dict, after reduction.
    """
    world_size = get_world_size()
    if world_size < 2:
        return input_dict
    with torch.no_grad():
        names = []
        values = []
        # sort the keys so that they are consistent across processes
        for k in sorted(input_dict.keys()):
            names.append(k)
            values.append(input_dict[k])
        values = torch.stack(values, dim=0)
        dist.all_reduce(values)
        if average:
            values /= world_size
        reduced_dict = {k: v for k, v in zip(names, values)}
    return reduced_dict


class MetricLogger(object):
    def __init__(self, delimiter="\t"):
        self.meters = defaultdict(SmoothedValue)
        self.delimiter = delimiter

    def update(self, **kwargs):
        for k, v in kwargs.items():
            if isinstance(v, torch.Tensor):
                v = v.item()
            assert isinstance(v, (float, int))
            self.meters[k].update(v)

    def __getattr__(self, attr):
        if attr in self.meters:
            return self.meters[attr]
        if attr in self.__dict__:
            return self.__dict__[attr]
        raise AttributeError("'{}' object has no attribute '{}'".format(
            type(self).__name__, attr))

    def __str__(self):
        loss_str = []
        for name, meter in self.meters.items():
            loss_str.append(
                "{}: {}".format(name, str(meter))
            )
        return self.delimiter.join(loss_str)

    def synchronize_between_processes(self):
        for meter in self.meters.values():
            meter.synchronize_between_processes()

    def add_meter(self, name, meter):
        self.meters[name] = meter

    def log_every(self, iterable, print_freq, header=None):
        i = 0
        if not header:
            header = ''
        start_time = time.time()
        end = time.time()
        iter_time = SmoothedValue(fmt='{avg:.4f}')
        data_time = SmoothedValue(fmt='{avg:.4f}')
        space_fmt = ':' + str(len(str(len(iterable)))) + 'd'
        log_msg = self.delimiter.join([
            header,
            '[{0' + space_fmt + '}/{1}]',
            'eta: {eta}',
            '{meters}',
            'time: {time}',
            'data: {data}',
            'max mem: {memory:.0f}'
        ])
        MB = 1024.0 * 1024.0
        for obj in iterable:
            data_time.update(time.time() - end)
            yield obj
            iter_time.update(time.time() - end)
            if i % print_freq == 0 or i == len(iterable) - 1:
                eta_seconds = iter_time.global_avg * (len(iterable) - i)
                eta_string = str(datetime.timedelta(seconds=int(eta_seconds)))
                print(log_msg.format(
                    i, len(iterable), eta=eta_string,
                    meters=str(self),
                    time=str(iter_time), data=str(data_time),
                    memory=torch.cuda.max_memory_allocated() / MB))
            i += 1
            end = time.time()
        total_time = time.time() - start_time
        total_time_str = str(datetime.timedelta(seconds=int(total_time)))
        print('{} Total time: {} ({:.4f} s / it)'.format(
            header, total_time_str, total_time / len(iterable)))


def collate_fn(batch):
    return tuple(zip(*batch))


def warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor):

    def f(x):
        if x >= warmup_iters:
            return 1
        alpha = float(x) / warmup_iters
        return warmup_factor * (1 - alpha) + alpha

    return torch.optim.lr_scheduler.LambdaLR(optimizer, f)


def mkdir(path):
    try:
        os.makedirs(path)
    except OSError as e:
        if e.errno != errno.EEXIST:
            raise


def setup_for_distributed(is_master):
    """
    This function disables printing when not in master process
    """
    import builtins as __builtin__
    builtin_print = __builtin__.print

    def print(*args, **kwargs):
        force = kwargs.pop('force', False)
        if is_master or force:
            builtin_print(*args, **kwargs)

    __builtin__.print = print


def is_dist_avail_and_initialized():
    if not dist.is_available():
        return False
    if not dist.is_initialized():
        return False
    return True


def get_world_size():
    if not is_dist_avail_and_initialized():
        return 1
    return dist.get_world_size()


def get_rank():
    if not is_dist_avail_and_initialized():
        return 0
    return dist.get_rank()


def is_main_process():
    return get_rank() == 0


def save_on_master(*args, **kwargs):
    if is_main_process():
        torch.save(*args, **kwargs)


def init_distributed_mode(args):
    if 'RANK' in os.environ and 'WORLD_SIZE' in os.environ:
        args.rank = int(os.environ["RANK"])
        args.world_size = int(os.environ['WORLD_SIZE'])
        args.gpu = int(os.environ['LOCAL_RANK'])
    elif 'SLURM_PROCID' in os.environ:
        args.rank = int(os.environ['SLURM_PROCID'])
        args.gpu = args.rank % torch.cuda.device_count()
    else:
        print('Not using distributed mode')
        args.distributed = False
        return

    args.distributed = True

    torch.cuda.set_device(args.gpu)
    args.dist_backend = 'nccl'
    print('| distributed init (rank {}): {}'.format(
        args.rank, args.dist_url), flush=True)
    torch.distributed.init_process_group(backend=args.dist_backend, init_method=args.dist_url,
                                         world_size=args.world_size, rank=args.rank)
    torch.distributed.barrier()
    setup_for_distributed(args.rank == 0)

# %% [markdown]
# # Training Function

# %%
def train_one_epoch(model, optimizer, data_loader, device, epoch, print_freq):
    model.train()
    metric_logger = MetricLogger(delimiter="  ")
    metric_logger.add_meter('lr', SmoothedValue(window_size=1, fmt='{value:.6f}'))
    header = 'Epoch: [{}]'.format(epoch)

    lr_scheduler = None
    if epoch == 0:
        warmup_factor = 1. / 1000
        warmup_iters = min(1000, len(data_loader) - 1)

        lr_scheduler = warmup_lr_scheduler(optimizer, warmup_iters, warmup_factor)

    for images, targets in metric_logger.log_every(data_loader, print_freq, header):
        images = list(image.to(device) for image in images)
        targets = [{k: v.to(device) for k, v in t.items()} for t in targets]

        loss_dict = model(images, targets)

        losses = sum(loss for loss in loss_dict.values())

        # reduce losses over all GPUs for logging purposes
        loss_dict_reduced = reduce_dict(loss_dict)
        losses_reduced = sum(loss for loss in loss_dict_reduced.values())

        optimizer.zero_grad()
        losses.backward()
        optimizer.step()

        if lr_scheduler is not None:
            lr_scheduler.step()

        metric_logger.update(loss=losses_reduced, **loss_dict_reduced)
        metric_logger.update(lr=optimizer.param_groups[0]["lr"])

# %% [markdown]
# # RLE to Mask

# %%
def rle2mask(rle, width, height):
    mask= np.zeros(width* height)
    array = np.asarray([int(x) for x in rle.split()])
    starts = array[0::2]
    lengths = array[1::2]

    current_position = 0
    for index, start in enumerate(starts):
        current_position += start
        mask[current_position:current_position+lengths[index]] = 1
        current_position += lengths[index]

    return mask.reshape(width, height)

# %% [markdown]
# # SIIM Dataset Class

# %%
class SIIMDataset(torch.utils.data.Dataset):
    def __init__(self, df_path, img_dir):
        self.df = pd.read_csv(df_path)
        self.height = 1024
        self.width = 1024
        self.image_dir = img_dir
        self.image_info = collections.defaultdict(dict)

        counter = 0
        for index, row in tqdm(self.df.iterrows(), total=len(self.df)):
            image_id = row['ImageId']
            image_path = os.path.join(self.image_dir, image_id)
            if os.path.exists(image_path + '.png') and row[" EncodedPixels"].strip() != "-1":
                self.image_info[counter]["image_id"] = image_id
                self.image_info[counter]["image_path"] = image_path
                self.image_info[counter]["annotations"] = row[" EncodedPixels"].strip()
                counter += 1

    def __getitem__(self, idx):
        img_path = self.image_info[idx]["image_path"]
        img = Image.open(img_path + '.png').convert("RGB")
        width, height = img.size
        img = img.resize((self.width, self.height), resample=Image.BILINEAR)
        info = self.image_info[idx]

        mask = rle2mask(info['annotations'], width, height)
        mask = Image.fromarray(mask.T)
        mask = mask.resize((self.width, self.height), resample=Image.BILINEAR)
        mask = np.expand_dims(mask, axis=0)

        pos = np.where(np.array(mask)[0, :, :])
        xmin = np.min(pos[1])
        xmax = np.max(pos[1])
        ymin = np.min(pos[0])
        ymax = np.max(pos[0])

        boxes = torch.as_tensor([[xmin, ymin, xmax, ymax]], dtype=torch.float32)
        labels = torch.ones((1,), dtype=torch.int64)
        masks = torch.as_tensor(mask, dtype=torch.uint8)

        image_id = torch.tensor([idx])
        area = (boxes[:, 3] - boxes[:, 1]) * (boxes[:, 2] - boxes[:, 0])
        iscrowd = torch.zeros((1,), dtype=torch.int64)

        target = {}
        target["boxes"] = boxes
        target["labels"] = labels
        target["masks"] = masks
        target["image_id"] = image_id
        target["area"] = area
        target["iscrowd"] = iscrowd
        
        img = transforms.ToTensor()(img)
        
        if random.random() < 0.8:
            height, width = img.shape[-2:]
            img = img.flip(-1)
            bbox = target["boxes"]
            bbox[:, [0, 2]] = width - bbox[:, [2, 0]]
            target["boxes"] = bbox
            target["masks"] = target["masks"].flip(-1)
        
        return img, target

    def __len__(self):
        return len(self.image_info)

# %% [markdown]
# # Create Dataset

# %%
dataset_train = SIIMDataset("train-rle.csv", "siim-png-images/train_png/")
# Out:
# 100%|██████████| 11582/11582 [00:00<00:00, 24563.25it/s]

# %%
len(dataset_train)
# Out:
# 3286

# %% [markdown]
# # Create Mask-RCNN Model

# %%
# create mask rcnn model
num_classes = 2
device = torch.device('cuda:0')

model_ft = torchvision.models.detection.maskrcnn_resnet50_fpn(pretrained=True)
in_features = model_ft.roi_heads.box_predictor.cls_score.in_features
model_ft.roi_heads.box_predictor = FastRCNNPredictor(in_features, num_classes)
in_features_mask = model_ft.roi_heads.mask_predictor.conv5_mask.in_channels
hidden_layer = 256
model_ft.roi_heads.mask_predictor = MaskRCNNPredictor(in_features_mask, hidden_layer, num_classes)
model_ft.to(device)

for param in model_ft.parameters():
    param.requires_grad = True

# %% [markdown]
# # Create Data Loader

# %%
data_loader = torch.utils.data.DataLoader(
    dataset_train, batch_size=4, shuffle=True, num_workers=8,
    collate_fn=lambda x: tuple(zip(*x)))

# %% [markdown]
# # Define Training Parameters

# %%
params = [p for p in model_ft.parameters() if p.requires_grad]
optimizer = torch.optim.SGD(params, lr=0.001, momentum=0.9, weight_decay=0.0005)
lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer,
                                               step_size=5,
                                               gamma=0.1)

# %% [markdown]
# # Train Model

# %%
num_epochs = 72
for epoch in range(num_epochs):
    train_one_epoch(model_ft, optimizer, data_loader, device, epoch, print_freq=200)
    lr_scheduler.step()
# Out:
# Epoch: [0]  [  0/822]  eta: 0:20:40  lr: 0.000002  loss: 4.3196 (4.3196)  loss_classifier: 0.6404 (0.6404)  loss_box_reg: 0.0473 (0.0473)  loss_mask: 3.5453 (3.5453)  loss_objectness: 0.0808 (0.0808)  loss_rpn_box_reg: 0.0059 (0.0059)  time: 1.5096  data: 0.5887  max mem: 6085
# Epoch: [0]  [200/822]  eta: 0:04:28  lr: 0.000246  loss: 0.6779 (1.0238)  loss_classifier: 0.1022 (0.1608)  loss_box_reg: 0.0582 (0.0470)  loss_mask: 0.4370 (0.7335)  loss_objectness: 0.0240 (0.0706)  loss_rpn_box_reg: 0.0076 (0.0120)  time: 0.4333  data: 0.0116  max mem: 8094
# Epoch: [0]  [400/822]  eta: 0:03:02  lr: 0.000489  loss: 0.5501 (0.8261)  loss_classifier: 0.0978 (0.1264)  loss_box_reg: 0.0625 (0.0517)  loss_mask: 0.3690 (0.5846)  loss_objectness: 0.0206 (0.0521)  loss_rpn_box_reg: 0.0066 (0.0113)  time: 0.4358  data: 0.0112  max mem: 8102
# Epoch: [0]  [600/822]  eta: 0:01:36  lr: 0.000732  loss: 0.5502 (0.7497)  loss_classifier: 0.0857 (0.1155)  loss_box_reg: 0.0470 (0.0535)  loss_mask: 0.3893 (0.5276)  loss_objectness: 0.0216 (0.0427)  loss_rpn_box_reg: 0.0062 (0.0104)  time: 0.4344  data: 0.0110  max mem: 8102
# Epoch: [0]  [800/822]  eta: 0:00:09  lr: 0.000976  loss: 0.5516 (0.7028)  loss_classifier: 0.0814 (0.1085)  loss_box_reg: 0.0486 (0.0526)  loss_mask: 0.3712 (0.4930)  loss_objectness: 0.0165 (0.0388)  loss_rpn_box_reg: 0.0091 (0.0100)  time: 0.4347  data: 0.0105  max mem: 8102
# Epoch: [0]  [821/822]  eta: 0:00:00  lr: 0.001000  loss: 0.5293 (0.6996)  loss_classifier: 0.0867 (0.1079)  loss_box_reg: 0.0495 (0.0525)  loss_mask: 0.3702 (0.4906)  loss_objectness: 0.0186 (0.0386)  loss_rpn_box_reg: 0.0069 (0.0100)  time: 0.4272  data: 0.0106  max mem: 8103
# Epoch: [0] Total time: 0:05:56 (0.4340 s / it)
# Epoch: [1]  [  0/822]  eta: 0:18:36  lr: 0.001000  loss: 0.5509 (0.5509)  loss_classifier: 0.0813 (0.0813)  loss_box_reg: 0.0503 (0.0503)  loss_mask: 0.3989 (0.3989)  loss_objectness: 0.0149 (0.0149)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 1.3588  data: 0.9228  max mem: 8103
# Epoch: [1]  [200/822]  eta: 0:04:34  lr: 0.001000  loss: 0.4770 (0.5236)  loss_classifier: 0.0852 (0.0838)  loss_box_reg: 0.0438 (0.0454)  loss_mask: 0.3241 (0.3610)  loss_objectness: 0.0183 (0.0227)  loss_rpn_box_reg: 0.0065 (0.0107)  time: 0.4362  data: 0.0110  max mem: 8103
# Epoch: [1]  [400/822]  eta: 0:03:05  lr: 0.001000  loss: 0.5079 (0.5174)  loss_classifier: 0.0797 (0.0847)  loss_box_reg: 0.0481 (0.0455)  loss_mask: 0.3211 (0.3565)  loss_objectness: 0.0161 (0.0216)  loss_rpn_box_reg: 0.0076 (0.0092)  time: 0.4376  data: 0.0115  max mem: 8125
# Epoch: [1]  [600/822]  eta: 0:01:37  lr: 0.001000  loss: 0.5140 (0.5128)  loss_classifier: 0.0842 (0.0855)  loss_box_reg: 0.0431 (0.0457)  loss_mask: 0.3428 (0.3522)  loss_objectness: 0.0177 (0.0207)  loss_rpn_box_reg: 0.0067 (0.0088)  time: 0.4364  data: 0.0110  max mem: 8125
# Epoch: [1]  [800/822]  eta: 0:00:09  lr: 0.001000  loss: 0.4603 (0.5133)  loss_classifier: 0.0793 (0.0855)  loss_box_reg: 0.0436 (0.0458)  loss_mask: 0.3088 (0.3533)  loss_objectness: 0.0096 (0.0201)  loss_rpn_box_reg: 0.0056 (0.0086)  time: 0.4387  data: 0.0117  max mem: 8125
# Epoch: [1]  [821/822]  eta: 0:00:00  lr: 0.001000  loss: 0.4897 (0.5151)  loss_classifier: 0.0866 (0.0856)  loss_box_reg: 0.0465 (0.0458)  loss_mask: 0.3269 (0.3551)  loss_objectness: 0.0151 (0.0202)  loss_rpn_box_reg: 0.0054 (0.0085)  time: 0.4272  data: 0.0115  max mem: 8125
# Epoch: [1] Total time: 0:06:00 (0.4380 s / it)
# Epoch: [2]  [  0/822]  eta: 0:20:46  lr: 0.001000  loss: 0.3197 (0.3197)  loss_classifier: 0.0651 (0.0651)  loss_box_reg: 0.0423 (0.0423)  loss_mask: 0.2012 (0.2012)  loss_objectness: 0.0080 (0.0080)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 1.5165  data: 1.0778  max mem: 8125
# Epoch: [2]  [200/822]  eta: 0:04:35  lr: 0.001000  loss: 0.4630 (0.4932)  loss_classifier: 0.0852 (0.0863)  loss_box_reg: 0.0433 (0.0451)  loss_mask: 0.2747 (0.3352)  loss_objectness: 0.0121 (0.0178)  loss_rpn_box_reg: 0.0071 (0.0088)  time: 0.4369  data: 0.0108  max mem: 8126
# Epoch: [2]  [400/822]  eta: 0:03:05  lr: 0.001000  loss: 0.4069 (0.4813)  loss_classifier: 0.0791 (0.0840)  loss_box_reg: 0.0428 (0.0441)  loss_mask: 0.2587 (0.3286)  loss_objectness: 0.0108 (0.0165)  loss_rpn_box_reg: 0.0070 (0.0081)  time: 0.4386  data: 0.0106  max mem: 8126
# Epoch: [2]  [600/822]  eta: 0:01:37  lr: 0.001000  loss: 0.4715 (0.4817)  loss_classifier: 0.0845 (0.0835)  loss_box_reg: 0.0413 (0.0441)  loss_mask: 0.3075 (0.3286)  loss_objectness: 0.0152 (0.0172)  loss_rpn_box_reg: 0.0063 (0.0083)  time: 0.4371  data: 0.0112  max mem: 8126
# Epoch: [2]  [800/822]  eta: 0:00:09  lr: 0.001000  loss: 0.4043 (0.4786)  loss_classifier: 0.0766 (0.0831)  loss_box_reg: 0.0382 (0.0440)  loss_mask: 0.2743 (0.3259)  loss_objectness: 0.0119 (0.0174)  loss_rpn_box_reg: 0.0064 (0.0082)  time: 0.4374  data: 0.0106  max mem: 8126
# Epoch: [2]  [821/822]  eta: 0:00:00  lr: 0.001000  loss: 0.4376 (0.4780)  loss_classifier: 0.0779 (0.0830)  loss_box_reg: 0.0439 (0.0440)  loss_mask: 0.2803 (0.3253)  loss_objectness: 0.0148 (0.0174)  loss_rpn_box_reg: 0.0072 (0.0083)  time: 0.4273  data: 0.0109  max mem: 8126
# Epoch: [2] Total time: 0:06:00 (0.4385 s / it)
# Epoch: [3]  [  0/822]  eta: 0:17:56  lr: 0.001000  loss: 0.6374 (0.6374)  loss_classifier: 0.1056 (0.1056)  loss_box_reg: 0.0424 (0.0424)  loss_mask: 0.4468 (0.4468)  loss_objectness: 0.0297 (0.0297)  loss_rpn_box_reg: 0.0130 (0.0130)  time: 1.3093  data: 0.8775  max mem: 8126
# Epoch: [3]  [200/822]  eta: 0:04:34  lr: 0.001000  loss: 0.3985 (0.4564)  loss_classifier: 0.0647 (0.0798)  loss_box_reg: 0.0415 (0.0431)  loss_mask: 0.2698 (0.3088)  loss_objectness: 0.0094 (0.0158)  loss_rpn_box_reg: 0.0053 (0.0088)  time: 0.4366  data: 0.0102  max mem: 8126
# Epoch: [3]  [400/822]  eta: 0:03:05  lr: 0.001000  loss: 0.4483 (0.4547)  loss_classifier: 0.0768 (0.0811)  loss_box_reg: 0.0374 (0.0430)  loss_mask: 0.2973 (0.3054)  loss_objectness: 0.0220 (0.0170)  loss_rpn_box_reg: 0.0070 (0.0082)  time: 0.4375  data: 0.0103  max mem: 8126
# Epoch: [3]  [600/822]  eta: 0:01:37  lr: 0.001000  loss: 0.4295 (0.4529)  loss_classifier: 0.0794 (0.0811)  loss_box_reg: 0.0445 (0.0432)  loss_mask: 0.2965 (0.3045)  loss_objectness: 0.0103 (0.0160)  loss_rpn_box_reg: 0.0054 (0.0080)  time: 0.4389  data: 0.0109  max mem: 8129
# Epoch: [3]  [800/822]  eta: 0:00:09  lr: 0.001000  loss: 0.4302 (0.4520)  loss_classifier: 0.0815 (0.0807)  loss_box_reg: 0.0440 (0.0430)  loss_mask: 0.2883 (0.3044)  loss_objectness: 0.0114 (0.0159)  loss_rpn_box_reg: 0.0051 (0.0080)  time: 0.4386  data: 0.0114  max mem: 8129
# Epoch: [3]  [821/822]  eta: 0:00:00  lr: 0.001000  loss: 0.4315 (0.4521)  loss_classifier: 0.0741 (0.0808)  loss_box_reg: 0.0434 (0.0430)  loss_mask: 0.2694 (0.3044)  loss_objectness: 0.0088 (0.0159)  loss_rpn_box_reg: 0.0050 (0.0080)  time: 0.4285  data: 0.0109  max mem: 8129
# Epoch: [3] Total time: 0:06:00 (0.4389 s / it)
# Epoch: [4]  [  0/822]  eta: 0:19:28  lr: 0.001000  loss: 0.4136 (0.4136)  loss_classifier: 0.0784 (0.0784)  loss_box_reg: 0.0263 (0.0263)  loss_mask: 0.2946 (0.2946)  loss_objectness: 0.0112 (0.0112)  loss_rpn_box_reg: 0.0031 (0.0031)  time: 1.4218  data: 0.9816  max mem: 8129
# Epoch: [4]  [200/822]  eta: 0:04:36  lr: 0.001000  loss: 0.4881 (0.4393)  loss_classifier: 0.0871 (0.0819)  loss_box_reg: 0.0395 (0.0428)  loss_mask: 0.3176 (0.2942)  loss_objectness: 0.0104 (0.0136)  loss_rpn_box_reg: 0.0067 (0.0069)  time: 0.4379  data: 0.0108  max mem: 8129
# Epoch: [4]  [400/822]  eta: 0:03:06  lr: 0.001000  loss: 0.4446 (0.4275)  loss_classifier: 0.0745 (0.0785)  loss_box_reg: 0.0385 (0.0416)  loss_mask: 0.3080 (0.2868)  loss_objectness: 0.0101 (0.0133)  loss_rpn_box_reg: 0.0057 (0.0073)  time: 0.4373  data: 0.0113  max mem: 8129
# Epoch: [4]  [600/822]  eta: 0:01:37  lr: 0.001000  loss: 0.4118 (0.4336)  loss_classifier: 0.0743 (0.0787)  loss_box_reg: 0.0444 (0.0416)  loss_mask: 0.2858 (0.2916)  loss_objectness: 0.0079 (0.0139)  loss_rpn_box_reg: 0.0046 (0.0078)  time: 0.4403  data: 0.0119  max mem: 8129
# Epoch: [4]  [800/822]  eta: 0:00:09  lr: 0.001000  loss: 0.3743 (0.4325)  loss_classifier: 0.0716 (0.0788)  loss_box_reg: 0.0393 (0.0417)  loss_mask: 0.2570 (0.2905)  loss_objectness: 0.0122 (0.0139)  loss_rpn_box_reg: 0.0052 (0.0077)  time: 0.4399  data: 0.0116  max mem: 8134
# Epoch: [4]  [821/822]  eta: 0:00:00  lr: 0.001000  loss: 0.4525 (0.4321)  loss_classifier: 0.0731 (0.0788)  loss_box_reg: 0.0371 (0.0417)  loss_mask: 0.2884 (0.2902)  loss_objectness: 0.0106 (0.0138)  loss_rpn_box_reg: 0.0052 (0.0077)  time: 0.4275  data: 0.0110  max mem: 8134
# Epoch: [4] Total time: 0:06:01 (0.4400 s / it)
# Epoch: [5]  [  0/822]  eta: 0:17:27  lr: 0.000100  loss: 0.4485 (0.4485)  loss_classifier: 0.0904 (0.0904)  loss_box_reg: 0.0493 (0.0493)  loss_mask: 0.2892 (0.2892)  loss_objectness: 0.0080 (0.0080)  loss_rpn_box_reg: 0.0117 (0.0117)  time: 1.2743  data: 0.8390  max mem: 8134
# Epoch: [5]  [200/822]  eta: 0:04:35  lr: 0.000100  loss: 0.3652 (0.4000)  loss_classifier: 0.0682 (0.0737)  loss_box_reg: 0.0347 (0.0406)  loss_mask: 0.2425 (0.2652)  loss_objectness: 0.0063 (0.0120)  loss_rpn_box_reg: 0.0047 (0.0086)  time: 0.4401  data: 0.0114  max mem: 8134
# Epoch: [5]  [400/822]  eta: 0:03:06  lr: 0.000100  loss: 0.3906 (0.3924)  loss_classifier: 0.0704 (0.0726)  loss_box_reg: 0.0384 (0.0400)  loss_mask: 0.2648 (0.2613)  loss_objectness: 0.0060 (0.0108)  loss_rpn_box_reg: 0.0047 (0.0077)  time: 0.4408  data: 0.0116  max mem: 8134
# Epoch: [5]  [600/822]  eta: 0:01:37  lr: 0.000100  loss: 0.4126 (0.3913)  loss_classifier: 0.0732 (0.0724)  loss_box_reg: 0.0362 (0.0397)  loss_mask: 0.2640 (0.2604)  loss_objectness: 0.0124 (0.0112)  loss_rpn_box_reg: 0.0057 (0.0076)  time: 0.4376  data: 0.0113  max mem: 8134
# Epoch: [5]  [800/822]  eta: 0:00:09  lr: 0.000100  loss: 0.3782 (0.3883)  loss_classifier: 0.0665 (0.0724)  loss_box_reg: 0.0380 (0.0397)  loss_mask: 0.2628 (0.2580)  loss_objectness: 0.0080 (0.0110)  loss_rpn_box_reg: 0.0051 (0.0073)  time: 0.4404  data: 0.0119  max mem: 8134
# Epoch: [5]  [821/822]  eta: 0:00:00  lr: 0.000100  loss: 0.3652 (0.3883)  loss_classifier: 0.0684 (0.0724)  loss_box_reg: 0.0374 (0.0397)  loss_mask: 0.2282 (0.2579)  loss_objectness: 0.0078 (0.0110)  loss_rpn_box_reg: 0.0058 (0.0073)  time: 0.4285  data: 0.0105  max mem: 8134
# Epoch: [5] Total time: 0:06:01 (0.4400 s / it)
# Epoch: [6]  [  0/822]  eta: 0:14:51  lr: 0.000100  loss: 0.4805 (0.4805)  loss_classifier: 0.0806 (0.0806)  loss_box_reg: 0.0286 (0.0286)  loss_mask: 0.3402 (0.3402)  loss_objectness: 0.0248 (0.0248)  loss_rpn_box_reg: 0.0063 (0.0063)  time: 1.0844  data: 0.6441  max mem: 8134
# Epoch: [6]  [200/822]  eta: 0:04:34  lr: 0.000100  loss: 0.3407 (0.3792)  loss_classifier: 0.0707 (0.0737)  loss_box_reg: 0.0356 (0.0397)  loss_mask: 0.2216 (0.2474)  loss_objectness: 0.0101 (0.0106)  loss_rpn_box_reg: 0.0064 (0.0077)  time: 0.4396  data: 0.0110  max mem: 8135
# Epoch: [6]  [400/822]  eta: 0:03:05  lr: 0.000100  loss: 0.3781 (0.3819)  loss_classifier: 0.0673 (0.0730)  loss_box_reg: 0.0365 (0.0395)  loss_mask: 0.2376 (0.2511)  loss_objectness: 0.0087 (0.0107)  loss_rpn_box_reg: 0.0052 (0.0075)  time: 0.4385  data: 0.0104  max mem: 8135
# Epoch: [6]  [600/822]  eta: 0:01:37  lr: 0.000100  loss: 0.3363 (0.3812)  loss_classifier: 0.0660 (0.0720)  loss_box_reg: 0.0352 (0.0393)  loss_mask: 0.2257 (0.2525)  loss_objectness: 0.0058 (0.0103)  loss_rpn_box_reg: 0.0043 (0.0071)  time: 0.4404  data: 0.0115  max mem: 8135
# Epoch: [6]  [800/822]  eta: 0:00:09  lr: 0.000100  loss: 0.3848 (0.3803)  loss_classifier: 0.0703 (0.0717)  loss_box_reg: 0.0427 (0.0394)  loss_mask: 0.2524 (0.2520)  loss_objectness: 0.0081 (0.0102)  loss_rpn_box_reg: 0.0047 (0.0071)  time: 0.4396  data: 0.0112  max mem: 8135
# Epoch: [6]  [821/822]  eta: 0:00:00  lr: 0.000100  loss: 0.3928 (0.3805)  loss_classifier: 0.0695 (0.0719)  loss_box_reg: 0.0391 (0.0394)  loss_mask: 0.2491 (0.2519)  loss_objectness: 0.0063 (0.0102)  loss_rpn_box_reg: 0.0054 (0.0071)  time: 0.4286  data: 0.0112  max mem: 8135
# Epoch: [6] Total time: 0:06:01 (0.4398 s / it)
# Epoch: [7]  [  0/822]  eta: 0:18:10  lr: 0.000100  loss: 0.3427 (0.3427)  loss_classifier: 0.0785 (0.0785)  loss_box_reg: 0.0476 (0.0476)  loss_mask: 0.2018 (0.2018)  loss_objectness: 0.0106 (0.0106)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 1.3269  data: 0.8857  max mem: 8135
# Epoch: [7]  [200/822]  eta: 0:04:35  lr: 0.000100  loss: 0.3688 (0.3823)  loss_classifier: 0.0632 (0.0700)  loss_box_reg: 0.0371 (0.0385)  loss_mask: 0.2420 (0.2544)  loss_objectness: 0.0086 (0.0118)  loss_rpn_box_reg: 0.0055 (0.0076)  time: 0.4388  data: 0.0105  max mem: 8135
# Epoch: [7]  [400/822]  eta: 0:03:06  lr: 0.000100  loss: 0.3241 (0.3755)  loss_classifier: 0.0618 (0.0691)  loss_box_reg: 0.0328 (0.0378)  loss_mask: 0.2124 (0.2498)  loss_objectness: 0.0076 (0.0110)  loss_rpn_box_reg: 0.0041 (0.0077)  time: 0.4395  data: 0.0109  max mem: 8135
# Epoch: [7]  [600/822]  eta: 0:01:37  lr: 0.000100  loss: 0.3733 (0.3744)  loss_classifier: 0.0708 (0.0704)  loss_box_reg: 0.0422 (0.0386)  loss_mask: 0.2532 (0.2475)  loss_objectness: 0.0076 (0.0106)  loss_rpn_box_reg: 0.0058 (0.0072)  time: 0.4389  data: 0.0107  max mem: 8135
# Epoch: [7]  [800/822]  eta: 0:00:09  lr: 0.000100  loss: 0.3670 (0.3757)  loss_classifier: 0.0706 (0.0706)  loss_box_reg: 0.0385 (0.0387)  loss_mask: 0.2585 (0.2487)  loss_objectness: 0.0080 (0.0106)  loss_rpn_box_reg: 0.0038 (0.0071)  time: 0.4393  data: 0.0111  max mem: 8138
# Epoch: [7]  [821/822]  eta: 0:00:00  lr: 0.000100  loss: 0.3641 (0.3753)  loss_classifier: 0.0716 (0.0707)  loss_box_reg: 0.0378 (0.0387)  loss_mask: 0.2212 (0.2482)  loss_objectness: 0.0090 (0.0106)  loss_rpn_box_reg: 0.0051 (0.0071)  time: 0.4278  data: 0.0108  max mem: 8138
# Epoch: [7] Total time: 0:06:01 (0.4401 s / it)
# Epoch: [8]  [  0/822]  eta: 0:17:53  lr: 0.000100  loss: 0.3367 (0.3367)  loss_classifier: 0.0740 (0.0740)  loss_box_reg: 0.0468 (0.0468)  loss_mask: 0.2022 (0.2022)  loss_objectness: 0.0089 (0.0089)  loss_rpn_box_reg: 0.0048 (0.0048)  time: 1.3055  data: 0.8691  max mem: 8138
# Epoch: [8]  [200/822]  eta: 0:04:35  lr: 0.000100  loss: 0.3302 (0.3679)  loss_classifier: 0.0636 (0.0700)  loss_box_reg: 0.0343 (0.0384)  loss_mask: 0.2250 (0.2425)  loss_objectness: 0.0072 (0.0097)  loss_rpn_box_reg: 0.0054 (0.0072)  time: 0.4394  data: 0.0105  max mem: 8138
# Epoch: [8]  [400/822]  eta: 0:03:06  lr: 0.000100  loss: 0.3618 (0.3704)  loss_classifier: 0.0678 (0.0700)  loss_box_reg: 0.0426 (0.0382)  loss_mask: 0.2510 (0.2460)  loss_objectness: 0.0064 (0.0094)  loss_rpn_box_reg: 0.0055 (0.0068)  time: 0.4392  data: 0.0111  max mem: 8138
# Epoch: [8]  [600/822]  eta: 0:01:37  lr: 0.000100  loss: 0.3443 (0.3707)  loss_classifier: 0.0635 (0.0703)  loss_box_reg: 0.0377 (0.0386)  loss_mask: 0.1886 (0.2447)  loss_objectness: 0.0079 (0.0100)  loss_rpn_box_reg: 0.0054 (0.0071)  time: 0.4401  data: 0.0114  max mem: 8138
# Epoch: [8]  [800/822]  eta: 0:00:09  lr: 0.000100  loss: 0.3601 (0.3699)  loss_classifier: 0.0689 (0.0700)  loss_box_reg: 0.0363 (0.0383)  loss_mask: 0.2454 (0.2445)  loss_objectness: 0.0075 (0.0100)  loss_rpn_box_reg: 0.0050 (0.0071)  time: 0.4400  data: 0.0114  max mem: 8138
# Epoch: [8]  [821/822]  eta: 0:00:00  lr: 0.000100  loss: 0.3505 (0.3696)  loss_classifier: 0.0604 (0.0699)  loss_box_reg: 0.0350 (0.0383)  loss_mask: 0.2222 (0.2444)  loss_objectness: 0.0096 (0.0101)  loss_rpn_box_reg: 0.0056 (0.0071)  time: 0.4282  data: 0.0115  max mem: 8138
# Epoch: [8] Total time: 0:06:01 (0.4401 s / it)
# Epoch: [9]  [  0/822]  eta: 0:18:43  lr: 0.000100  loss: 0.3427 (0.3427)  loss_classifier: 0.0827 (0.0827)  loss_box_reg: 0.0337 (0.0337)  loss_mask: 0.2139 (0.2139)  loss_objectness: 0.0082 (0.0082)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 1.3662  data: 0.9259  max mem: 8138
# Epoch: [9]  [200/822]  eta: 0:04:36  lr: 0.000100  loss: 0.3366 (0.3605)  loss_classifier: 0.0628 (0.0669)  loss_box_reg: 0.0343 (0.0366)  loss_mask: 0.2199 (0.2415)  loss_objectness: 0.0064 (0.0093)  loss_rpn_box_reg: 0.0053 (0.0063)  time: 0.4403  data: 0.0116  max mem: 8138
# Epoch: [9]  [400/822]  eta: 0:03:06  lr: 0.000100  loss: 0.3823 (0.3575)  loss_classifier: 0.0702 (0.0682)  loss_box_reg: 0.0402 (0.0367)  loss_mask: 0.2580 (0.2365)  loss_objectness: 0.0072 (0.0094)  loss_rpn_box_reg: 0.0057 (0.0067)  time: 0.4385  data: 0.0114  max mem: 8138
# Epoch: [9]  [600/822]  eta: 0:01:37  lr: 0.000100  loss: 0.3558 (0.3656)  loss_classifier: 0.0715 (0.0688)  loss_box_reg: 0.0403 (0.0377)  loss_mask: 0.2299 (0.2429)  loss_objectness: 0.0066 (0.0096)  loss_rpn_box_reg: 0.0055 (0.0066)  time: 0.4392  data: 0.0112  max mem: 8138
# Epoch: [9]  [800/822]  eta: 0:00:09  lr: 0.000100  loss: 0.3348 (0.3662)  loss_classifier: 0.0666 (0.0691)  loss_box_reg: 0.0346 (0.0380)  loss_mask: 0.2174 (0.2426)  loss_objectness: 0.0087 (0.0097)  loss_rpn_box_reg: 0.0052 (0.0068)  time: 0.4401  data: 0.0115  max mem: 8138
# Epoch: [9]  [821/822]  eta: 0:00:00  lr: 0.000100  loss: 0.3615 (0.3662)  loss_classifier: 0.0634 (0.0690)  loss_box_reg: 0.0377 (0.0379)  loss_mask: 0.2499 (0.2426)  loss_objectness: 0.0093 (0.0097)  loss_rpn_box_reg: 0.0050 (0.0069)  time: 0.4269  data: 0.0108  max mem: 8138
# Epoch: [9] Total time: 0:06:01 (0.4400 s / it)
# Epoch: [10]  [  0/822]  eta: 0:18:11  lr: 0.000010  loss: 0.3247 (0.3247)  loss_classifier: 0.0622 (0.0622)  loss_box_reg: 0.0192 (0.0192)  loss_mask: 0.2172 (0.2172)  loss_objectness: 0.0157 (0.0157)  loss_rpn_box_reg: 0.0104 (0.0104)  time: 1.3284  data: 0.8949  max mem: 8138
# Epoch: [10]  [200/822]  eta: 0:04:35  lr: 0.000010  loss: 0.3449 (0.3651)  loss_classifier: 0.0658 (0.0688)  loss_box_reg: 0.0354 (0.0373)  loss_mask: 0.2426 (0.2434)  loss_objectness: 0.0075 (0.0096)  loss_rpn_box_reg: 0.0055 (0.0060)  time: 0.4387  data: 0.0105  max mem: 8138
# Epoch: [10]  [400/822]  eta: 0:03:06  lr: 0.000010  loss: 0.3510 (0.3643)  loss_classifier: 0.0657 (0.0686)  loss_box_reg: 0.0384 (0.0375)  loss_mask: 0.2311 (0.2419)  loss_objectness: 0.0058 (0.0096)  loss_rpn_box_reg: 0.0053 (0.0068)  time: 0.4394  data: 0.0113  max mem: 8138
# Epoch: [10]  [600/822]  eta: 0:01:37  lr: 0.000010  loss: 0.3070 (0.3607)  loss_classifier: 0.0619 (0.0682)  loss_box_reg: 0.0371 (0.0372)  loss_mask: 0.2046 (0.2392)  loss_objectness: 0.0059 (0.0095)  loss_rpn_box_reg: 0.0041 (0.0067)  time: 0.4407  data: 0.0115  max mem: 8138
# Epoch: [10]  [800/822]  eta: 0:00:09  lr: 0.000010  loss: 0.3128 (0.3592)  loss_classifier: 0.0666 (0.0680)  loss_box_reg: 0.0332 (0.0373)  loss_mask: 0.1999 (0.2376)  loss_objectness: 0.0067 (0.0094)  loss_rpn_box_reg: 0.0047 (0.0069)  time: 0.4402  data: 0.0114  max mem: 8138
# Epoch: [10]  [821/822]  eta: 0:00:00  lr: 0.000010  loss: 0.3627 (0.3591)  loss_classifier: 0.0645 (0.0681)  loss_box_reg: 0.0361 (0.0373)  loss_mask: 0.2259 (0.2376)  loss_objectness: 0.0055 (0.0094)  loss_rpn_box_reg: 0.0044 (0.0069)  time: 0.4281  data: 0.0110  max mem: 8138
# Epoch: [10] Total time: 0:06:01 (0.4402 s / it)
# Epoch: [11]  [  0/822]  eta: 0:20:24  lr: 0.000010  loss: 0.2297 (0.2297)  loss_classifier: 0.0483 (0.0483)  loss_box_reg: 0.0263 (0.0263)  loss_mask: 0.1467 (0.1467)  loss_objectness: 0.0036 (0.0036)  loss_rpn_box_reg: 0.0047 (0.0047)  time: 1.4901  data: 1.0518  max mem: 8138
# Epoch: [11]  [200/822]  eta: 0:04:36  lr: 0.000010  loss: 0.3563 (0.3609)  loss_classifier: 0.0679 (0.0682)  loss_box_reg: 0.0366 (0.0377)  loss_mask: 0.2227 (0.2377)  loss_objectness: 0.0066 (0.0100)  loss_rpn_box_reg: 0.0045 (0.0074)  time: 0.4397  data: 0.0113  max mem: 8138
# Epoch: [11]  [400/822]  eta: 0:03:06  lr: 0.000010  loss: 0.3381 (0.3614)  loss_classifier: 0.0665 (0.0685)  loss_box_reg: 0.0397 (0.0373)  loss_mask: 0.2268 (0.2387)  loss_objectness: 0.0069 (0.0096)  loss_rpn_box_reg: 0.0043 (0.0073)  time: 0.4402  data: 0.0114  max mem: 8138
# Epoch: [11]  [600/822]  eta: 0:01:37  lr: 0.000010  loss: 0.3224 (0.3589)  loss_classifier: 0.0587 (0.0682)  loss_box_reg: 0.0310 (0.0371)  loss_mask: 0.2044 (0.2373)  loss_objectness: 0.0058 (0.0093)  loss_rpn_box_reg: 0.0046 (0.0070)  time: 0.4388  data: 0.0109  max mem: 8138
# Epoch: [11]  [800/822]  eta: 0:00:09  lr: 0.000010  loss: 0.3271 (0.3584)  loss_classifier: 0.0604 (0.0680)  loss_box_reg: 0.0326 (0.0372)  loss_mask: 0.2188 (0.2371)  loss_objectness: 0.0084 (0.0092)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 0.4384  data: 0.0108  max mem: 8138
# Epoch: [11]  [821/822]  eta: 0:00:00  lr: 0.000010  loss: 0.3216 (0.3578)  loss_classifier: 0.0645 (0.0679)  loss_box_reg: 0.0377 (0.0372)  loss_mask: 0.2079 (0.2367)  loss_objectness: 0.0060 (0.0091)  loss_rpn_box_reg: 0.0053 (0.0068)  time: 0.4288  data: 0.0106  max mem: 8138
# Epoch: [11] Total time: 0:06:02 (0.4406 s / it)
# Epoch: [12]  [  0/822]  eta: 0:19:02  lr: 0.000010  loss: 0.3993 (0.3993)  loss_classifier: 0.0661 (0.0661)  loss_box_reg: 0.0423 (0.0423)  loss_mask: 0.2654 (0.2654)  loss_objectness: 0.0168 (0.0168)  loss_rpn_box_reg: 0.0087 (0.0087)  time: 1.3902  data: 0.9566  max mem: 8138
# Epoch: [12]  [200/822]  eta: 0:04:36  lr: 0.000010  loss: 0.3712 (0.3550)  loss_classifier: 0.0635 (0.0681)  loss_box_reg: 0.0400 (0.0367)  loss_mask: 0.2521 (0.2329)  loss_objectness: 0.0059 (0.0097)  loss_rpn_box_reg: 0.0041 (0.0076)  time: 0.4385  data: 0.0108  max mem: 8138
# Epoch: [12]  [400/822]  eta: 0:03:06  lr: 0.000010  loss: 0.3412 (0.3529)  loss_classifier: 0.0634 (0.0677)  loss_box_reg: 0.0357 (0.0372)  loss_mask: 0.2187 (0.2316)  loss_objectness: 0.0062 (0.0093)  loss_rpn_box_reg: 0.0046 (0.0072)  time: 0.4400  data: 0.0113  max mem: 8138
# Epoch: [12]  [600/822]  eta: 0:01:37  lr: 0.000010  loss: 0.3553 (0.3544)  loss_classifier: 0.0667 (0.0671)  loss_box_reg: 0.0385 (0.0371)  loss_mask: 0.2331 (0.2343)  loss_objectness: 0.0088 (0.0090)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 0.4389  data: 0.0110  max mem: 8138
# Epoch: [12]  [800/822]  eta: 0:00:09  lr: 0.000010  loss: 0.3767 (0.3559)  loss_classifier: 0.0701 (0.0677)  loss_box_reg: 0.0371 (0.0370)  loss_mask: 0.2308 (0.2352)  loss_objectness: 0.0110 (0.0092)  loss_rpn_box_reg: 0.0057 (0.0068)  time: 0.4388  data: 0.0113  max mem: 8138
# Epoch: [12]  [821/822]  eta: 0:00:00  lr: 0.000010  loss: 0.3577 (0.3562)  loss_classifier: 0.0622 (0.0677)  loss_box_reg: 0.0380 (0.0370)  loss_mask: 0.2397 (0.2353)  loss_objectness: 0.0066 (0.0093)  loss_rpn_box_reg: 0.0051 (0.0069)  time: 0.4286  data: 0.0112  max mem: 8138
# Epoch: [12] Total time: 0:06:01 (0.4402 s / it)
# Epoch: [13]  [  0/822]  eta: 0:19:58  lr: 0.000010  loss: 0.3328 (0.3328)  loss_classifier: 0.0646 (0.0646)  loss_box_reg: 0.0461 (0.0461)  loss_mask: 0.2119 (0.2119)  loss_objectness: 0.0075 (0.0075)  loss_rpn_box_reg: 0.0026 (0.0026)  time: 1.4578  data: 1.0153  max mem: 8138
# Epoch: [13]  [200/822]  eta: 0:04:36  lr: 0.000010  loss: 0.3694 (0.3584)  loss_classifier: 0.0697 (0.0671)  loss_box_reg: 0.0377 (0.0375)  loss_mask: 0.2611 (0.2385)  loss_objectness: 0.0068 (0.0092)  loss_rpn_box_reg: 0.0052 (0.0061)  time: 0.4383  data: 0.0110  max mem: 8138
# Epoch: [13]  [400/822]  eta: 0:03:06  lr: 0.000010  loss: 0.3349 (0.3624)  loss_classifier: 0.0629 (0.0681)  loss_box_reg: 0.0370 (0.0374)  loss_mask: 0.2227 (0.2409)  loss_objectness: 0.0080 (0.0093)  loss_rpn_box_reg: 0.0054 (0.0066)  time: 0.4399  data: 0.0113  max mem: 8138
# Epoch: [13]  [600/822]  eta: 0:01:37  lr: 0.000010  loss: 0.3409 (0.3577)  loss_classifier: 0.0595 (0.0677)  loss_box_reg: 0.0328 (0.0368)  loss_mask: 0.2330 (0.2370)  loss_objectness: 0.0055 (0.0095)  loss_rpn_box_reg: 0.0044 (0.0067)  time: 0.4402  data: 0.0119  max mem: 8138
# Epoch: [13]  [800/822]  eta: 0:00:09  lr: 0.000010  loss: 0.3226 (0.3580)  loss_classifier: 0.0619 (0.0678)  loss_box_reg: 0.0325 (0.0371)  loss_mask: 0.2124 (0.2369)  loss_objectness: 0.0055 (0.0094)  loss_rpn_box_reg: 0.0042 (0.0068)  time: 0.4405  data: 0.0115  max mem: 8138
# Epoch: [13]  [821/822]  eta: 0:00:00  lr: 0.000010  loss: 0.3355 (0.3580)  loss_classifier: 0.0666 (0.0677)  loss_box_reg: 0.0382 (0.0371)  loss_mask: 0.2260 (0.2369)  loss_objectness: 0.0046 (0.0094)  loss_rpn_box_reg: 0.0044 (0.0068)  time: 0.4290  data: 0.0114  max mem: 8138
# Epoch: [13] Total time: 0:06:02 (0.4406 s / it)
# Epoch: [14]  [  0/822]  eta: 0:18:07  lr: 0.000010  loss: 0.3254 (0.3254)  loss_classifier: 0.0585 (0.0585)  loss_box_reg: 0.0342 (0.0342)  loss_mask: 0.1766 (0.1766)  loss_objectness: 0.0176 (0.0176)  loss_rpn_box_reg: 0.0385 (0.0385)  time: 1.3224  data: 0.8876  max mem: 8138
# Epoch: [14]  [200/822]  eta: 0:04:35  lr: 0.000010  loss: 0.3485 (0.3580)  loss_classifier: 0.0641 (0.0693)  loss_box_reg: 0.0321 (0.0371)  loss_mask: 0.2281 (0.2354)  loss_objectness: 0.0064 (0.0096)  loss_rpn_box_reg: 0.0048 (0.0066)  time: 0.4378  data: 0.0107  max mem: 8138
# Epoch: [14]  [400/822]  eta: 0:03:06  lr: 0.000010  loss: 0.3678 (0.3589)  loss_classifier: 0.0668 (0.0687)  loss_box_reg: 0.0356 (0.0375)  loss_mask: 0.2281 (0.2370)  loss_objectness: 0.0092 (0.0093)  loss_rpn_box_reg: 0.0059 (0.0064)  time: 0.4396  data: 0.0116  max mem: 8138
# Epoch: [14]  [600/822]  eta: 0:01:37  lr: 0.000010  loss: 0.3076 (0.3572)  loss_classifier: 0.0623 (0.0678)  loss_box_reg: 0.0341 (0.0370)  loss_mask: 0.2012 (0.2362)  loss_objectness: 0.0051 (0.0093)  loss_rpn_box_reg: 0.0042 (0.0069)  time: 0.4396  data: 0.0114  max mem: 8138
# Epoch: [14]  [800/822]  eta: 0:00:09  lr: 0.000010  loss: 0.3405 (0.3560)  loss_classifier: 0.0686 (0.0675)  loss_box_reg: 0.0378 (0.0370)  loss_mask: 0.2279 (0.2355)  loss_objectness: 0.0058 (0.0092)  loss_rpn_box_reg: 0.0042 (0.0069)  time: 0.4395  data: 0.0108  max mem: 8138
# Epoch: [14]  [821/822]  eta: 0:00:00  lr: 0.000010  loss: 0.3507 (0.3563)  loss_classifier: 0.0633 (0.0674)  loss_box_reg: 0.0332 (0.0369)  loss_mask: 0.2224 (0.2360)  loss_objectness: 0.0042 (0.0092)  loss_rpn_box_reg: 0.0045 (0.0069)  time: 0.4286  data: 0.0111  max mem: 8138
# Epoch: [14] Total time: 0:06:01 (0.4401 s / it)
# Epoch: [15]  [  0/822]  eta: 0:18:58  lr: 0.000001  loss: 0.5034 (0.5034)  loss_classifier: 0.0862 (0.0862)  loss_box_reg: 0.0328 (0.0328)  loss_mask: 0.3432 (0.3432)  loss_objectness: 0.0264 (0.0264)  loss_rpn_box_reg: 0.0148 (0.0148)  time: 1.3848  data: 0.9474  max mem: 8138
# Epoch: [15]  [200/822]  eta: 0:04:35  lr: 0.000001  loss: 0.3215 (0.3563)  loss_classifier: 0.0668 (0.0673)  loss_box_reg: 0.0357 (0.0365)  loss_mask: 0.1819 (0.2359)  loss_objectness: 0.0064 (0.0095)  loss_rpn_box_reg: 0.0048 (0.0071)  time: 0.4394  data: 0.0109  max mem: 8138
# Epoch: [15]  [400/822]  eta: 0:03:06  lr: 0.000001  loss: 0.3239 (0.3543)  loss_classifier: 0.0630 (0.0668)  loss_box_reg: 0.0340 (0.0368)  loss_mask: 0.2155 (0.2349)  loss_objectness: 0.0064 (0.0089)  loss_rpn_box_reg: 0.0049 (0.0069)  time: 0.4392  data: 0.0104  max mem: 8138
# Epoch: [15]  [600/822]  eta: 0:01:37  lr: 0.000001  loss: 0.3436 (0.3534)  loss_classifier: 0.0640 (0.0672)  loss_box_reg: 0.0347 (0.0367)  loss_mask: 0.2210 (0.2338)  loss_objectness: 0.0039 (0.0090)  loss_rpn_box_reg: 0.0039 (0.0066)  time: 0.4391  data: 0.0108  max mem: 8138
# Epoch: [15]  [800/822]  eta: 0:00:09  lr: 0.000001  loss: 0.3797 (0.3567)  loss_classifier: 0.0683 (0.0674)  loss_box_reg: 0.0382 (0.0370)  loss_mask: 0.2502 (0.2364)  loss_objectness: 0.0071 (0.0091)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 0.4383  data: 0.0109  max mem: 8138
# Epoch: [15]  [821/822]  eta: 0:00:00  lr: 0.000001  loss: 0.3163 (0.3564)  loss_classifier: 0.0680 (0.0674)  loss_box_reg: 0.0313 (0.0369)  loss_mask: 0.2033 (0.2362)  loss_objectness: 0.0081 (0.0091)  loss_rpn_box_reg: 0.0050 (0.0068)  time: 0.4288  data: 0.0113  max mem: 8138
# Epoch: [15] Total time: 0:06:01 (0.4403 s / it)
# Epoch: [16]  [  0/822]  eta: 0:19:47  lr: 0.000001  loss: 0.2448 (0.2448)  loss_classifier: 0.0679 (0.0679)  loss_box_reg: 0.0403 (0.0403)  loss_mask: 0.1280 (0.1280)  loss_objectness: 0.0049 (0.0049)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 1.4450  data: 1.0028  max mem: 8138
# Epoch: [16]  [200/822]  eta: 0:04:35  lr: 0.000001  loss: 0.3234 (0.3577)  loss_classifier: 0.0620 (0.0673)  loss_box_reg: 0.0384 (0.0376)  loss_mask: 0.2091 (0.2363)  loss_objectness: 0.0070 (0.0098)  loss_rpn_box_reg: 0.0043 (0.0066)  time: 0.4390  data: 0.0108  max mem: 8138
# Epoch: [16]  [400/822]  eta: 0:03:06  lr: 0.000001  loss: 0.3286 (0.3567)  loss_classifier: 0.0631 (0.0671)  loss_box_reg: 0.0339 (0.0371)  loss_mask: 0.2029 (0.2362)  loss_objectness: 0.0048 (0.0095)  loss_rpn_box_reg: 0.0041 (0.0068)  time: 0.4402  data: 0.0115  max mem: 8138
# Epoch: [16]  [600/822]  eta: 0:01:37  lr: 0.000001  loss: 0.3532 (0.3569)  loss_classifier: 0.0700 (0.0676)  loss_box_reg: 0.0362 (0.0369)  loss_mask: 0.2333 (0.2360)  loss_objectness: 0.0064 (0.0096)  loss_rpn_box_reg: 0.0047 (0.0067)  time: 0.4396  data: 0.0115  max mem: 8138
# Epoch: [16]  [800/822]  eta: 0:00:09  lr: 0.000001  loss: 0.3563 (0.3560)  loss_classifier: 0.0593 (0.0675)  loss_box_reg: 0.0336 (0.0369)  loss_mask: 0.2380 (0.2352)  loss_objectness: 0.0049 (0.0094)  loss_rpn_box_reg: 0.0044 (0.0069)  time: 0.4404  data: 0.0120  max mem: 8138
# Epoch: [16]  [821/822]  eta: 0:00:00  lr: 0.000001  loss: 0.3671 (0.3560)  loss_classifier: 0.0598 (0.0674)  loss_box_reg: 0.0397 (0.0370)  loss_mask: 0.2362 (0.2352)  loss_objectness: 0.0076 (0.0095)  loss_rpn_box_reg: 0.0056 (0.0069)  time: 0.4283  data: 0.0109  max mem: 8138
# Epoch: [16] Total time: 0:06:02 (0.4407 s / it)
# Epoch: [17]  [  0/822]  eta: 0:18:22  lr: 0.000001  loss: 0.3321 (0.3321)  loss_classifier: 0.0602 (0.0602)  loss_box_reg: 0.0427 (0.0427)  loss_mask: 0.2236 (0.2236)  loss_objectness: 0.0013 (0.0013)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 1.3414  data: 0.9033  max mem: 8138
# Epoch: [17]  [200/822]  eta: 0:04:35  lr: 0.000001  loss: 0.3411 (0.3573)  loss_classifier: 0.0636 (0.0686)  loss_box_reg: 0.0372 (0.0371)  loss_mask: 0.2314 (0.2354)  loss_objectness: 0.0045 (0.0096)  loss_rpn_box_reg: 0.0041 (0.0066)  time: 0.4399  data: 0.0105  max mem: 8138
# Epoch: [17]  [400/822]  eta: 0:03:06  lr: 0.000001  loss: 0.3499 (0.3580)  loss_classifier: 0.0690 (0.0680)  loss_box_reg: 0.0382 (0.0372)  loss_mask: 0.2291 (0.2370)  loss_objectness: 0.0068 (0.0094)  loss_rpn_box_reg: 0.0050 (0.0065)  time: 0.4405  data: 0.0103  max mem: 8138
# Epoch: [17]  [600/822]  eta: 0:01:37  lr: 0.000001  loss: 0.3730 (0.3551)  loss_classifier: 0.0658 (0.0672)  loss_box_reg: 0.0413 (0.0370)  loss_mask: 0.2206 (0.2350)  loss_objectness: 0.0078 (0.0093)  loss_rpn_box_reg: 0.0050 (0.0066)  time: 0.4397  data: 0.0110  max mem: 8138
# Epoch: [17]  [800/822]  eta: 0:00:09  lr: 0.000001  loss: 0.3366 (0.3565)  loss_classifier: 0.0592 (0.0674)  loss_box_reg: 0.0338 (0.0370)  loss_mask: 0.2243 (0.2360)  loss_objectness: 0.0065 (0.0093)  loss_rpn_box_reg: 0.0036 (0.0067)  time: 0.4393  data: 0.0117  max mem: 8138
# Epoch: [17]  [821/822]  eta: 0:00:00  lr: 0.000001  loss: 0.3447 (0.3568)  loss_classifier: 0.0692 (0.0675)  loss_box_reg: 0.0405 (0.0371)  loss_mask: 0.2142 (0.2360)  loss_objectness: 0.0083 (0.0093)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 0.4283  data: 0.0106  max mem: 8138
# Epoch: [17] Total time: 0:06:01 (0.4401 s / it)
# Epoch: [18]  [  0/822]  eta: 0:19:22  lr: 0.000001  loss: 0.3435 (0.3435)  loss_classifier: 0.0661 (0.0661)  loss_box_reg: 0.0465 (0.0465)  loss_mask: 0.2205 (0.2205)  loss_objectness: 0.0045 (0.0045)  loss_rpn_box_reg: 0.0059 (0.0059)  time: 1.4138  data: 0.9731  max mem: 8138
# Epoch: [18]  [200/822]  eta: 0:04:35  lr: 0.000001  loss: 0.3232 (0.3577)  loss_classifier: 0.0685 (0.0686)  loss_box_reg: 0.0319 (0.0380)  loss_mask: 0.2060 (0.2346)  loss_objectness: 0.0056 (0.0095)  loss_rpn_box_reg: 0.0039 (0.0071)  time: 0.4394  data: 0.0109  max mem: 8138
# Epoch: [18]  [400/822]  eta: 0:03:06  lr: 0.000001  loss: 0.3569 (0.3540)  loss_classifier: 0.0641 (0.0675)  loss_box_reg: 0.0358 (0.0371)  loss_mask: 0.2468 (0.2336)  loss_objectness: 0.0093 (0.0091)  loss_rpn_box_reg: 0.0044 (0.0068)  time: 0.4387  data: 0.0111  max mem: 8138
# Epoch: [18]  [600/822]  eta: 0:01:37  lr: 0.000001  loss: 0.3441 (0.3567)  loss_classifier: 0.0604 (0.0674)  loss_box_reg: 0.0316 (0.0369)  loss_mask: 0.2335 (0.2360)  loss_objectness: 0.0073 (0.0093)  loss_rpn_box_reg: 0.0056 (0.0070)  time: 0.4396  data: 0.0119  max mem: 8138
# Epoch: [18]  [800/822]  eta: 0:00:09  lr: 0.000001  loss: 0.3517 (0.3544)  loss_classifier: 0.0640 (0.0673)  loss_box_reg: 0.0331 (0.0369)  loss_mask: 0.2273 (0.2341)  loss_objectness: 0.0064 (0.0092)  loss_rpn_box_reg: 0.0047 (0.0069)  time: 0.4403  data: 0.0111  max mem: 8138
# Epoch: [18]  [821/822]  eta: 0:00:00  lr: 0.000001  loss: 0.3375 (0.3545)  loss_classifier: 0.0598 (0.0672)  loss_box_reg: 0.0300 (0.0368)  loss_mask: 0.2251 (0.2342)  loss_objectness: 0.0083 (0.0093)  loss_rpn_box_reg: 0.0052 (0.0070)  time: 0.4277  data: 0.0108  max mem: 8138
# Epoch: [18] Total time: 0:06:01 (0.4402 s / it)
# Epoch: [19]  [  0/822]  eta: 0:20:49  lr: 0.000001  loss: 0.3639 (0.3639)  loss_classifier: 0.0906 (0.0906)  loss_box_reg: 0.0495 (0.0495)  loss_mask: 0.2130 (0.2130)  loss_objectness: 0.0084 (0.0084)  loss_rpn_box_reg: 0.0025 (0.0025)  time: 1.5198  data: 1.0808  max mem: 8138
# Epoch: [19]  [200/822]  eta: 0:04:36  lr: 0.000001  loss: 0.3308 (0.3559)  loss_classifier: 0.0657 (0.0685)  loss_box_reg: 0.0353 (0.0367)  loss_mask: 0.2168 (0.2356)  loss_objectness: 0.0084 (0.0092)  loss_rpn_box_reg: 0.0046 (0.0059)  time: 0.4383  data: 0.0105  max mem: 8138
# Epoch: [19]  [400/822]  eta: 0:03:06  lr: 0.000001  loss: 0.3766 (0.3504)  loss_classifier: 0.0646 (0.0668)  loss_box_reg: 0.0382 (0.0368)  loss_mask: 0.2566 (0.2315)  loss_objectness: 0.0068 (0.0087)  loss_rpn_box_reg: 0.0057 (0.0066)  time: 0.4387  data: 0.0109  max mem: 8138
# Epoch: [19]  [600/822]  eta: 0:01:37  lr: 0.000001  loss: 0.3646 (0.3540)  loss_classifier: 0.0670 (0.0670)  loss_box_reg: 0.0394 (0.0367)  loss_mask: 0.2257 (0.2341)  loss_objectness: 0.0072 (0.0093)  loss_rpn_box_reg: 0.0053 (0.0070)  time: 0.4365  data: 0.0104  max mem: 8138
# Epoch: [19]  [800/822]  eta: 0:00:09  lr: 0.000001  loss: 0.3141 (0.3547)  loss_classifier: 0.0607 (0.0672)  loss_box_reg: 0.0364 (0.0368)  loss_mask: 0.1981 (0.2343)  loss_objectness: 0.0062 (0.0094)  loss_rpn_box_reg: 0.0045 (0.0069)  time: 0.4401  data: 0.0112  max mem: 8138
# Epoch: [19]  [821/822]  eta: 0:00:00  lr: 0.000001  loss: 0.3716 (0.3548)  loss_classifier: 0.0667 (0.0673)  loss_box_reg: 0.0381 (0.0369)  loss_mask: 0.2430 (0.2343)  loss_objectness: 0.0089 (0.0094)  loss_rpn_box_reg: 0.0052 (0.0069)  time: 0.4286  data: 0.0114  max mem: 8138
# Epoch: [19] Total time: 0:06:01 (0.4403 s / it)
# Epoch: [20]  [  0/822]  eta: 0:18:23  lr: 0.000000  loss: 0.3856 (0.3856)  loss_classifier: 0.0628 (0.0628)  loss_box_reg: 0.0362 (0.0362)  loss_mask: 0.2507 (0.2507)  loss_objectness: 0.0320 (0.0320)  loss_rpn_box_reg: 0.0039 (0.0039)  time: 1.3428  data: 0.9003  max mem: 8138
# Epoch: [20]  [200/822]  eta: 0:04:35  lr: 0.000000  loss: 0.3006 (0.3492)  loss_classifier: 0.0592 (0.0661)  loss_box_reg: 0.0340 (0.0359)  loss_mask: 0.1941 (0.2322)  loss_objectness: 0.0080 (0.0089)  loss_rpn_box_reg: 0.0051 (0.0060)  time: 0.4400  data: 0.0113  max mem: 8138
# Epoch: [20]  [400/822]  eta: 0:03:06  lr: 0.000000  loss: 0.3224 (0.3535)  loss_classifier: 0.0602 (0.0666)  loss_box_reg: 0.0346 (0.0366)  loss_mask: 0.2052 (0.2350)  loss_objectness: 0.0055 (0.0089)  loss_rpn_box_reg: 0.0050 (0.0065)  time: 0.4394  data: 0.0109  max mem: 8138
# Epoch: [20]  [600/822]  eta: 0:01:37  lr: 0.000000  loss: 0.3375 (0.3536)  loss_classifier: 0.0619 (0.0667)  loss_box_reg: 0.0355 (0.0366)  loss_mask: 0.2205 (0.2344)  loss_objectness: 0.0067 (0.0092)  loss_rpn_box_reg: 0.0048 (0.0067)  time: 0.4390  data: 0.0108  max mem: 8138
# Epoch: [20]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3551 (0.3559)  loss_classifier: 0.0726 (0.0674)  loss_box_reg: 0.0387 (0.0370)  loss_mask: 0.2122 (0.2355)  loss_objectness: 0.0076 (0.0092)  loss_rpn_box_reg: 0.0046 (0.0068)  time: 0.4398  data: 0.0111  max mem: 8138
# Epoch: [20]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3463 (0.3560)  loss_classifier: 0.0659 (0.0674)  loss_box_reg: 0.0324 (0.0369)  loss_mask: 0.2394 (0.2355)  loss_objectness: 0.0085 (0.0093)  loss_rpn_box_reg: 0.0048 (0.0068)  time: 0.4289  data: 0.0114  max mem: 8138
# Epoch: [20] Total time: 0:06:01 (0.4403 s / it)
# Epoch: [21]  [  0/822]  eta: 0:18:54  lr: 0.000000  loss: 0.2745 (0.2745)  loss_classifier: 0.0457 (0.0457)  loss_box_reg: 0.0291 (0.0291)  loss_mask: 0.1909 (0.1909)  loss_objectness: 0.0059 (0.0059)  loss_rpn_box_reg: 0.0029 (0.0029)  time: 1.3797  data: 0.9456  max mem: 8138
# Epoch: [21]  [200/822]  eta: 0:04:36  lr: 0.000000  loss: 0.3450 (0.3559)  loss_classifier: 0.0593 (0.0661)  loss_box_reg: 0.0361 (0.0371)  loss_mask: 0.2332 (0.2355)  loss_objectness: 0.0054 (0.0094)  loss_rpn_box_reg: 0.0050 (0.0077)  time: 0.4400  data: 0.0113  max mem: 8138
# Epoch: [21]  [400/822]  eta: 0:03:06  lr: 0.000000  loss: 0.3937 (0.3572)  loss_classifier: 0.0660 (0.0677)  loss_box_reg: 0.0301 (0.0372)  loss_mask: 0.2552 (0.2358)  loss_objectness: 0.0083 (0.0095)  loss_rpn_box_reg: 0.0049 (0.0070)  time: 0.4390  data: 0.0113  max mem: 8138
# Epoch: [21]  [600/822]  eta: 0:01:37  lr: 0.000000  loss: 0.3013 (0.3537)  loss_classifier: 0.0630 (0.0670)  loss_box_reg: 0.0309 (0.0369)  loss_mask: 0.1943 (0.2336)  loss_objectness: 0.0060 (0.0093)  loss_rpn_box_reg: 0.0047 (0.0069)  time: 0.4398  data: 0.0112  max mem: 8138
# Epoch: [21]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3338 (0.3553)  loss_classifier: 0.0625 (0.0671)  loss_box_reg: 0.0333 (0.0369)  loss_mask: 0.2347 (0.2349)  loss_objectness: 0.0059 (0.0095)  loss_rpn_box_reg: 0.0051 (0.0069)  time: 0.4403  data: 0.0118  max mem: 8138
# Epoch: [21]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3315 (0.3551)  loss_classifier: 0.0621 (0.0672)  loss_box_reg: 0.0328 (0.0369)  loss_mask: 0.2177 (0.2348)  loss_objectness: 0.0068 (0.0094)  loss_rpn_box_reg: 0.0048 (0.0069)  time: 0.4275  data: 0.0106  max mem: 8138
# Epoch: [21] Total time: 0:06:02 (0.4405 s / it)
# Epoch: [22]  [  0/822]  eta: 0:17:50  lr: 0.000000  loss: 0.3103 (0.3103)  loss_classifier: 0.0612 (0.0612)  loss_box_reg: 0.0182 (0.0182)  loss_mask: 0.2078 (0.2078)  loss_objectness: 0.0178 (0.0178)  loss_rpn_box_reg: 0.0053 (0.0053)  time: 1.3028  data: 0.8692  max mem: 8138
# Epoch: [22]  [200/822]  eta: 0:04:35  lr: 0.000000  loss: 0.3494 (0.3478)  loss_classifier: 0.0661 (0.0663)  loss_box_reg: 0.0332 (0.0365)  loss_mask: 0.2238 (0.2291)  loss_objectness: 0.0083 (0.0091)  loss_rpn_box_reg: 0.0047 (0.0068)  time: 0.4389  data: 0.0112  max mem: 8138
# Epoch: [22]  [400/822]  eta: 0:03:06  lr: 0.000000  loss: 0.3319 (0.3567)  loss_classifier: 0.0616 (0.0678)  loss_box_reg: 0.0356 (0.0371)  loss_mask: 0.2039 (0.2348)  loss_objectness: 0.0067 (0.0095)  loss_rpn_box_reg: 0.0046 (0.0075)  time: 0.4385  data: 0.0112  max mem: 8138
# Epoch: [22]  [600/822]  eta: 0:01:37  lr: 0.000000  loss: 0.3237 (0.3563)  loss_classifier: 0.0612 (0.0675)  loss_box_reg: 0.0346 (0.0371)  loss_mask: 0.2010 (0.2353)  loss_objectness: 0.0062 (0.0094)  loss_rpn_box_reg: 0.0040 (0.0071)  time: 0.4390  data: 0.0113  max mem: 8138
# Epoch: [22]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3502 (0.3549)  loss_classifier: 0.0717 (0.0675)  loss_box_reg: 0.0365 (0.0368)  loss_mask: 0.2388 (0.2345)  loss_objectness: 0.0069 (0.0092)  loss_rpn_box_reg: 0.0050 (0.0068)  time: 0.4391  data: 0.0108  max mem: 8138
# Epoch: [22]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3442 (0.3550)  loss_classifier: 0.0662 (0.0675)  loss_box_reg: 0.0362 (0.0369)  loss_mask: 0.2276 (0.2346)  loss_objectness: 0.0080 (0.0092)  loss_rpn_box_reg: 0.0048 (0.0068)  time: 0.4290  data: 0.0115  max mem: 8138
# Epoch: [22] Total time: 0:06:02 (0.4412 s / it)
# Epoch: [23]  [  0/822]  eta: 0:20:57  lr: 0.000000  loss: 0.3804 (0.3804)  loss_classifier: 0.0678 (0.0678)  loss_box_reg: 0.0395 (0.0395)  loss_mask: 0.2558 (0.2558)  loss_objectness: 0.0067 (0.0067)  loss_rpn_box_reg: 0.0106 (0.0106)  time: 1.5298  data: 1.0846  max mem: 8138
# Epoch: [23]  [200/822]  eta: 0:04:36  lr: 0.000000  loss: 0.3488 (0.3584)  loss_classifier: 0.0564 (0.0675)  loss_box_reg: 0.0326 (0.0380)  loss_mask: 0.2482 (0.2376)  loss_objectness: 0.0059 (0.0086)  loss_rpn_box_reg: 0.0045 (0.0067)  time: 0.4400  data: 0.0114  max mem: 8138
# Epoch: [23]  [400/822]  eta: 0:03:04  lr: 0.000000  loss: 0.3456 (0.3598)  loss_classifier: 0.0632 (0.0677)  loss_box_reg: 0.0349 (0.0375)  loss_mask: 0.2200 (0.2385)  loss_objectness: 0.0083 (0.0094)  loss_rpn_box_reg: 0.0052 (0.0066)  time: 0.4392  data: 0.0110  max mem: 8138
# Epoch: [23]  [600/822]  eta: 0:01:36  lr: 0.000000  loss: 0.3232 (0.3575)  loss_classifier: 0.0633 (0.0676)  loss_box_reg: 0.0351 (0.0371)  loss_mask: 0.1964 (0.2366)  loss_objectness: 0.0075 (0.0092)  loss_rpn_box_reg: 0.0059 (0.0070)  time: 0.4168  data: 0.0117  max mem: 8138
# Epoch: [23]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3265 (0.3556)  loss_classifier: 0.0639 (0.0675)  loss_box_reg: 0.0364 (0.0371)  loss_mask: 0.2048 (0.2348)  loss_objectness: 0.0069 (0.0092)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 0.4392  data: 0.0112  max mem: 8138
# Epoch: [23]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3518 (0.3553)  loss_classifier: 0.0619 (0.0674)  loss_box_reg: 0.0324 (0.0370)  loss_mask: 0.2232 (0.2347)  loss_objectness: 0.0083 (0.0093)  loss_rpn_box_reg: 0.0051 (0.0069)  time: 0.4203  data: 0.0116  max mem: 8138
# Epoch: [23] Total time: 0:05:59 (0.4371 s / it)
# Epoch: [24]  [  0/822]  eta: 0:22:27  lr: 0.000000  loss: 0.2744 (0.2744)  loss_classifier: 0.0475 (0.0475)  loss_box_reg: 0.0320 (0.0320)  loss_mask: 0.1856 (0.1856)  loss_objectness: 0.0050 (0.0050)  loss_rpn_box_reg: 0.0043 (0.0043)  time: 1.6392  data: 1.2072  max mem: 8138
# Epoch: [24]  [200/822]  eta: 0:04:27  lr: 0.000000  loss: 0.3008 (0.3560)  loss_classifier: 0.0555 (0.0676)  loss_box_reg: 0.0358 (0.0369)  loss_mask: 0.1962 (0.2352)  loss_objectness: 0.0059 (0.0096)  loss_rpn_box_reg: 0.0060 (0.0068)  time: 0.4416  data: 0.0122  max mem: 8138
# Epoch: [24]  [400/822]  eta: 0:03:00  lr: 0.000000  loss: 0.3736 (0.3554)  loss_classifier: 0.0648 (0.0678)  loss_box_reg: 0.0404 (0.0371)  loss_mask: 0.2425 (0.2347)  loss_objectness: 0.0063 (0.0091)  loss_rpn_box_reg: 0.0046 (0.0068)  time: 0.4249  data: 0.0154  max mem: 8138
# Epoch: [24]  [600/822]  eta: 0:01:34  lr: 0.000000  loss: 0.3314 (0.3561)  loss_classifier: 0.0679 (0.0676)  loss_box_reg: 0.0346 (0.0372)  loss_mask: 0.2143 (0.2354)  loss_objectness: 0.0056 (0.0091)  loss_rpn_box_reg: 0.0054 (0.0068)  time: 0.4240  data: 0.0141  max mem: 8138
# Epoch: [24]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3671 (0.3567)  loss_classifier: 0.0681 (0.0677)  loss_box_reg: 0.0344 (0.0371)  loss_mask: 0.2503 (0.2357)  loss_objectness: 0.0074 (0.0093)  loss_rpn_box_reg: 0.0055 (0.0069)  time: 0.4236  data: 0.0135  max mem: 8138
# Epoch: [24]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3580 (0.3568)  loss_classifier: 0.0694 (0.0678)  loss_box_reg: 0.0398 (0.0372)  loss_mask: 0.2234 (0.2356)  loss_objectness: 0.0087 (0.0094)  loss_rpn_box_reg: 0.0057 (0.0069)  time: 0.4127  data: 0.0128  max mem: 8138
# Epoch: [24] Total time: 0:05:50 (0.4264 s / it)
# Epoch: [25]  [  0/822]  eta: 0:23:24  lr: 0.000000  loss: 0.2937 (0.2937)  loss_classifier: 0.0615 (0.0615)  loss_box_reg: 0.0381 (0.0381)  loss_mask: 0.1790 (0.1790)  loss_objectness: 0.0097 (0.0097)  loss_rpn_box_reg: 0.0055 (0.0055)  time: 1.7091  data: 1.2650  max mem: 8138
# Epoch: [25]  [200/822]  eta: 0:04:32  lr: 0.000000  loss: 0.3352 (0.3599)  loss_classifier: 0.0634 (0.0686)  loss_box_reg: 0.0370 (0.0375)  loss_mask: 0.2284 (0.2364)  loss_objectness: 0.0064 (0.0097)  loss_rpn_box_reg: 0.0052 (0.0076)  time: 0.4427  data: 0.0120  max mem: 8138
# Epoch: [25]  [400/822]  eta: 0:03:04  lr: 0.000000  loss: 0.3394 (0.3569)  loss_classifier: 0.0717 (0.0683)  loss_box_reg: 0.0342 (0.0370)  loss_mask: 0.2204 (0.2352)  loss_objectness: 0.0076 (0.0093)  loss_rpn_box_reg: 0.0047 (0.0070)  time: 0.4161  data: 0.0125  max mem: 8138
# Epoch: [25]  [600/822]  eta: 0:01:36  lr: 0.000000  loss: 0.3843 (0.3548)  loss_classifier: 0.0598 (0.0680)  loss_box_reg: 0.0364 (0.0372)  loss_mask: 0.2637 (0.2335)  loss_objectness: 0.0079 (0.0092)  loss_rpn_box_reg: 0.0052 (0.0068)  time: 0.4221  data: 0.0134  max mem: 8138
# Epoch: [25]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3446 (0.3553)  loss_classifier: 0.0625 (0.0675)  loss_box_reg: 0.0339 (0.0370)  loss_mask: 0.2304 (0.2347)  loss_objectness: 0.0074 (0.0092)  loss_rpn_box_reg: 0.0039 (0.0068)  time: 0.4231  data: 0.0170  max mem: 8138
# Epoch: [25]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3715 (0.3561)  loss_classifier: 0.0665 (0.0676)  loss_box_reg: 0.0343 (0.0370)  loss_mask: 0.2421 (0.2353)  loss_objectness: 0.0077 (0.0093)  loss_rpn_box_reg: 0.0057 (0.0069)  time: 0.4142  data: 0.0141  max mem: 8138
# Epoch: [25] Total time: 0:05:54 (0.4316 s / it)
# Epoch: [26]  [  0/822]  eta: 0:28:52  lr: 0.000000  loss: 0.3010 (0.3010)  loss_classifier: 0.0459 (0.0459)  loss_box_reg: 0.0431 (0.0431)  loss_mask: 0.2031 (0.2031)  loss_objectness: 0.0048 (0.0048)  loss_rpn_box_reg: 0.0041 (0.0041)  time: 2.1073  data: 1.6685  max mem: 8138
# Epoch: [26]  [200/822]  eta: 0:04:29  lr: 0.000000  loss: 0.3604 (0.3627)  loss_classifier: 0.0687 (0.0685)  loss_box_reg: 0.0385 (0.0381)  loss_mask: 0.2421 (0.2404)  loss_objectness: 0.0053 (0.0092)  loss_rpn_box_reg: 0.0048 (0.0065)  time: 0.4252  data: 0.0135  max mem: 8138
# Epoch: [26]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3309 (0.3596)  loss_classifier: 0.0591 (0.0679)  loss_box_reg: 0.0336 (0.0376)  loss_mask: 0.2124 (0.2382)  loss_objectness: 0.0067 (0.0090)  loss_rpn_box_reg: 0.0043 (0.0069)  time: 0.4257  data: 0.0147  max mem: 8138
# Epoch: [26]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3184 (0.3559)  loss_classifier: 0.0713 (0.0675)  loss_box_reg: 0.0344 (0.0370)  loss_mask: 0.2034 (0.2354)  loss_objectness: 0.0074 (0.0090)  loss_rpn_box_reg: 0.0049 (0.0070)  time: 0.4262  data: 0.0149  max mem: 8138
# Epoch: [26]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3474 (0.3560)  loss_classifier: 0.0597 (0.0675)  loss_box_reg: 0.0302 (0.0370)  loss_mask: 0.2304 (0.2355)  loss_objectness: 0.0061 (0.0091)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 0.4291  data: 0.0142  max mem: 8138
# Epoch: [26]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3465 (0.3561)  loss_classifier: 0.0595 (0.0674)  loss_box_reg: 0.0363 (0.0370)  loss_mask: 0.2351 (0.2357)  loss_objectness: 0.0061 (0.0091)  loss_rpn_box_reg: 0.0044 (0.0069)  time: 0.4144  data: 0.0137  max mem: 8138
# Epoch: [26] Total time: 0:05:51 (0.4278 s / it)
# Epoch: [27]  [  0/822]  eta: 0:27:19  lr: 0.000000  loss: 0.3746 (0.3746)  loss_classifier: 0.0714 (0.0714)  loss_box_reg: 0.0372 (0.0372)  loss_mask: 0.2408 (0.2408)  loss_objectness: 0.0107 (0.0107)  loss_rpn_box_reg: 0.0147 (0.0147)  time: 1.9946  data: 1.5237  max mem: 8138
# Epoch: [27]  [200/822]  eta: 0:04:28  lr: 0.000000  loss: 0.3702 (0.3626)  loss_classifier: 0.0699 (0.0688)  loss_box_reg: 0.0367 (0.0378)  loss_mask: 0.2427 (0.2389)  loss_objectness: 0.0072 (0.0097)  loss_rpn_box_reg: 0.0048 (0.0074)  time: 0.4250  data: 0.0149  max mem: 8138
# Epoch: [27]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3296 (0.3614)  loss_classifier: 0.0686 (0.0684)  loss_box_reg: 0.0357 (0.0376)  loss_mask: 0.2143 (0.2387)  loss_objectness: 0.0064 (0.0095)  loss_rpn_box_reg: 0.0055 (0.0072)  time: 0.4254  data: 0.0148  max mem: 8138
# Epoch: [27]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3097 (0.3587)  loss_classifier: 0.0606 (0.0677)  loss_box_reg: 0.0333 (0.0372)  loss_mask: 0.1919 (0.2375)  loss_objectness: 0.0081 (0.0094)  loss_rpn_box_reg: 0.0049 (0.0069)  time: 0.4224  data: 0.0133  max mem: 8138
# Epoch: [27]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.2970 (0.3558)  loss_classifier: 0.0546 (0.0674)  loss_box_reg: 0.0296 (0.0369)  loss_mask: 0.2085 (0.2352)  loss_objectness: 0.0062 (0.0093)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 0.4266  data: 0.0151  max mem: 8138
# ...
# Epoch: [62]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3532 (0.3558)  loss_classifier: 0.0605 (0.0675)  loss_box_reg: 0.0338 (0.0369)  loss_mask: 0.2451 (0.2356)  loss_objectness: 0.0069 (0.0091)  loss_rpn_box_reg: 0.0050 (0.0068)  time: 0.4123  data: 0.0138  max mem: 8138
# Epoch: [62] Total time: 0:05:52 (0.4287 s / it)
# Epoch: [63]  [  0/822]  eta: 0:27:32  lr: 0.000000  loss: 0.3780 (0.3780)  loss_classifier: 0.0676 (0.0676)  loss_box_reg: 0.0490 (0.0490)  loss_mask: 0.2552 (0.2552)  loss_objectness: 0.0042 (0.0042)  loss_rpn_box_reg: 0.0020 (0.0020)  time: 2.0106  data: 1.5652  max mem: 8138
# Epoch: [63]  [200/822]  eta: 0:04:30  lr: 0.000000  loss: 0.3696 (0.3487)  loss_classifier: 0.0590 (0.0660)  loss_box_reg: 0.0382 (0.0365)  loss_mask: 0.2457 (0.2308)  loss_objectness: 0.0059 (0.0084)  loss_rpn_box_reg: 0.0044 (0.0070)  time: 0.4261  data: 0.0146  max mem: 8138
# Epoch: [63]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3556 (0.3544)  loss_classifier: 0.0731 (0.0675)  loss_box_reg: 0.0395 (0.0371)  loss_mask: 0.2250 (0.2336)  loss_objectness: 0.0082 (0.0090)  loss_rpn_box_reg: 0.0050 (0.0072)  time: 0.4290  data: 0.0171  max mem: 8138
# Epoch: [63]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3202 (0.3563)  loss_classifier: 0.0587 (0.0671)  loss_box_reg: 0.0327 (0.0368)  loss_mask: 0.2264 (0.2364)  loss_objectness: 0.0067 (0.0090)  loss_rpn_box_reg: 0.0050 (0.0069)  time: 0.4300  data: 0.0164  max mem: 8138
# Epoch: [63]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3100 (0.3547)  loss_classifier: 0.0602 (0.0674)  loss_box_reg: 0.0349 (0.0369)  loss_mask: 0.2046 (0.2344)  loss_objectness: 0.0060 (0.0091)  loss_rpn_box_reg: 0.0043 (0.0069)  time: 0.4280  data: 0.0149  max mem: 8138
# Epoch: [63]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3552 (0.3550)  loss_classifier: 0.0660 (0.0675)  loss_box_reg: 0.0351 (0.0369)  loss_mask: 0.2252 (0.2347)  loss_objectness: 0.0066 (0.0091)  loss_rpn_box_reg: 0.0061 (0.0069)  time: 0.4150  data: 0.0144  max mem: 8138
# Epoch: [63] Total time: 0:05:52 (0.4290 s / it)
# Epoch: [64]  [  0/822]  eta: 0:28:36  lr: 0.000000  loss: 0.3880 (0.3880)  loss_classifier: 0.0709 (0.0709)  loss_box_reg: 0.0385 (0.0385)  loss_mask: 0.2669 (0.2669)  loss_objectness: 0.0080 (0.0080)  loss_rpn_box_reg: 0.0037 (0.0037)  time: 2.0880  data: 1.6431  max mem: 8138
# Epoch: [64]  [200/822]  eta: 0:04:30  lr: 0.000000  loss: 0.3902 (0.3612)  loss_classifier: 0.0663 (0.0681)  loss_box_reg: 0.0355 (0.0372)  loss_mask: 0.2462 (0.2407)  loss_objectness: 0.0067 (0.0084)  loss_rpn_box_reg: 0.0061 (0.0068)  time: 0.4260  data: 0.0148  max mem: 8138
# Epoch: [64]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3712 (0.3569)  loss_classifier: 0.0672 (0.0672)  loss_box_reg: 0.0401 (0.0366)  loss_mask: 0.2556 (0.2367)  loss_objectness: 0.0064 (0.0090)  loss_rpn_box_reg: 0.0048 (0.0072)  time: 0.4267  data: 0.0160  max mem: 8138
# Epoch: [64]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3240 (0.3527)  loss_classifier: 0.0586 (0.0672)  loss_box_reg: 0.0335 (0.0367)  loss_mask: 0.2108 (0.2326)  loss_objectness: 0.0086 (0.0093)  loss_rpn_box_reg: 0.0043 (0.0069)  time: 0.4255  data: 0.0165  max mem: 8138
# Epoch: [64]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3301 (0.3552)  loss_classifier: 0.0612 (0.0672)  loss_box_reg: 0.0352 (0.0370)  loss_mask: 0.2040 (0.2347)  loss_objectness: 0.0070 (0.0093)  loss_rpn_box_reg: 0.0041 (0.0069)  time: 0.4285  data: 0.0163  max mem: 8138
# Epoch: [64]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3432 (0.3548)  loss_classifier: 0.0621 (0.0672)  loss_box_reg: 0.0354 (0.0370)  loss_mask: 0.2293 (0.2344)  loss_objectness: 0.0051 (0.0092)  loss_rpn_box_reg: 0.0053 (0.0069)  time: 0.4138  data: 0.0141  max mem: 8138
# Epoch: [64] Total time: 0:05:52 (0.4287 s / it)
# Epoch: [65]  [  0/822]  eta: 0:22:59  lr: 0.000000  loss: 0.4816 (0.4816)  loss_classifier: 0.0860 (0.0860)  loss_box_reg: 0.0336 (0.0336)  loss_mask: 0.3493 (0.3493)  loss_objectness: 0.0051 (0.0051)  loss_rpn_box_reg: 0.0075 (0.0075)  time: 1.6780  data: 1.2337  max mem: 8138
# Epoch: [65]  [200/822]  eta: 0:04:29  lr: 0.000000  loss: 0.3443 (0.3504)  loss_classifier: 0.0615 (0.0663)  loss_box_reg: 0.0368 (0.0374)  loss_mask: 0.2406 (0.2312)  loss_objectness: 0.0075 (0.0083)  loss_rpn_box_reg: 0.0042 (0.0071)  time: 0.4286  data: 0.0150  max mem: 8138
# Epoch: [65]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3412 (0.3562)  loss_classifier: 0.0732 (0.0672)  loss_box_reg: 0.0354 (0.0368)  loss_mask: 0.2054 (0.2362)  loss_objectness: 0.0064 (0.0089)  loss_rpn_box_reg: 0.0044 (0.0070)  time: 0.4262  data: 0.0141  max mem: 8138
# Epoch: [65]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3140 (0.3544)  loss_classifier: 0.0606 (0.0671)  loss_box_reg: 0.0331 (0.0371)  loss_mask: 0.2112 (0.2346)  loss_objectness: 0.0079 (0.0087)  loss_rpn_box_reg: 0.0037 (0.0069)  time: 0.4261  data: 0.0148  max mem: 8138
# Epoch: [65]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3434 (0.3551)  loss_classifier: 0.0696 (0.0671)  loss_box_reg: 0.0357 (0.0368)  loss_mask: 0.2370 (0.2349)  loss_objectness: 0.0072 (0.0093)  loss_rpn_box_reg: 0.0042 (0.0069)  time: 0.4242  data: 0.0147  max mem: 8138
# Epoch: [65]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.2999 (0.3542)  loss_classifier: 0.0630 (0.0670)  loss_box_reg: 0.0309 (0.0368)  loss_mask: 0.1767 (0.2343)  loss_objectness: 0.0068 (0.0093)  loss_rpn_box_reg: 0.0045 (0.0069)  time: 0.4154  data: 0.0141  max mem: 8138
# Epoch: [65] Total time: 0:05:52 (0.4285 s / it)
# Epoch: [66]  [  0/822]  eta: 0:28:08  lr: 0.000000  loss: 0.4226 (0.4226)  loss_classifier: 0.0708 (0.0708)  loss_box_reg: 0.0383 (0.0383)  loss_mask: 0.2548 (0.2548)  loss_objectness: 0.0447 (0.0447)  loss_rpn_box_reg: 0.0141 (0.0141)  time: 2.0540  data: 1.6327  max mem: 8138
# Epoch: [66]  [200/822]  eta: 0:04:29  lr: 0.000000  loss: 0.3501 (0.3597)  loss_classifier: 0.0622 (0.0677)  loss_box_reg: 0.0371 (0.0374)  loss_mask: 0.2450 (0.2366)  loss_objectness: 0.0071 (0.0098)  loss_rpn_box_reg: 0.0048 (0.0081)  time: 0.4246  data: 0.0148  max mem: 8138
# Epoch: [66]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3047 (0.3538)  loss_classifier: 0.0634 (0.0673)  loss_box_reg: 0.0327 (0.0371)  loss_mask: 0.2025 (0.2334)  loss_objectness: 0.0077 (0.0090)  loss_rpn_box_reg: 0.0044 (0.0071)  time: 0.4252  data: 0.0153  max mem: 8138
# Epoch: [66]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3709 (0.3544)  loss_classifier: 0.0715 (0.0671)  loss_box_reg: 0.0338 (0.0368)  loss_mask: 0.2498 (0.2342)  loss_objectness: 0.0086 (0.0091)  loss_rpn_box_reg: 0.0065 (0.0071)  time: 0.4243  data: 0.0152  max mem: 8138
# Epoch: [66]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3463 (0.3547)  loss_classifier: 0.0659 (0.0671)  loss_box_reg: 0.0336 (0.0369)  loss_mask: 0.2415 (0.2348)  loss_objectness: 0.0072 (0.0091)  loss_rpn_box_reg: 0.0060 (0.0068)  time: 0.4266  data: 0.0158  max mem: 8138
# Epoch: [66]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3567 (0.3555)  loss_classifier: 0.0662 (0.0672)  loss_box_reg: 0.0390 (0.0370)  loss_mask: 0.2379 (0.2352)  loss_objectness: 0.0082 (0.0091)  loss_rpn_box_reg: 0.0047 (0.0068)  time: 0.4164  data: 0.0146  max mem: 8138
# Epoch: [66] Total time: 0:05:52 (0.4292 s / it)
# Epoch: [67]  [  0/822]  eta: 0:29:43  lr: 0.000000  loss: 0.2750 (0.2750)  loss_classifier: 0.0418 (0.0418)  loss_box_reg: 0.0243 (0.0243)  loss_mask: 0.1984 (0.1984)  loss_objectness: 0.0051 (0.0051)  loss_rpn_box_reg: 0.0053 (0.0053)  time: 2.1694  data: 1.6655  max mem: 8138
# Epoch: [67]  [200/822]  eta: 0:04:29  lr: 0.000000  loss: 0.3181 (0.3578)  loss_classifier: 0.0617 (0.0674)  loss_box_reg: 0.0350 (0.0371)  loss_mask: 0.2171 (0.2379)  loss_objectness: 0.0054 (0.0088)  loss_rpn_box_reg: 0.0044 (0.0066)  time: 0.4261  data: 0.0155  max mem: 8138
# Epoch: [67]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3532 (0.3579)  loss_classifier: 0.0665 (0.0675)  loss_box_reg: 0.0379 (0.0368)  loss_mask: 0.2330 (0.2376)  loss_objectness: 0.0083 (0.0093)  loss_rpn_box_reg: 0.0068 (0.0067)  time: 0.4271  data: 0.0157  max mem: 8138
# Epoch: [67]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3610 (0.3578)  loss_classifier: 0.0662 (0.0673)  loss_box_reg: 0.0374 (0.0368)  loss_mask: 0.2288 (0.2375)  loss_objectness: 0.0083 (0.0092)  loss_rpn_box_reg: 0.0052 (0.0070)  time: 0.4263  data: 0.0139  max mem: 8138
# Epoch: [67]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3780 (0.3561)  loss_classifier: 0.0603 (0.0675)  loss_box_reg: 0.0346 (0.0370)  loss_mask: 0.2464 (0.2355)  loss_objectness: 0.0098 (0.0092)  loss_rpn_box_reg: 0.0059 (0.0069)  time: 0.4271  data: 0.0158  max mem: 8138
# Epoch: [67]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3351 (0.3553)  loss_classifier: 0.0600 (0.0674)  loss_box_reg: 0.0318 (0.0369)  loss_mask: 0.2000 (0.2349)  loss_objectness: 0.0074 (0.0092)  loss_rpn_box_reg: 0.0046 (0.0069)  time: 0.4134  data: 0.0138  max mem: 8138
# Epoch: [67] Total time: 0:05:52 (0.4285 s / it)
# Epoch: [68]  [  0/822]  eta: 0:26:51  lr: 0.000000  loss: 0.3991 (0.3991)  loss_classifier: 0.0881 (0.0881)  loss_box_reg: 0.0452 (0.0452)  loss_mask: 0.2445 (0.2445)  loss_objectness: 0.0152 (0.0152)  loss_rpn_box_reg: 0.0061 (0.0061)  time: 1.9608  data: 1.5014  max mem: 8138
# Epoch: [68]  [200/822]  eta: 0:04:29  lr: 0.000000  loss: 0.3031 (0.3537)  loss_classifier: 0.0625 (0.0668)  loss_box_reg: 0.0361 (0.0367)  loss_mask: 0.1902 (0.2340)  loss_objectness: 0.0053 (0.0089)  loss_rpn_box_reg: 0.0046 (0.0073)  time: 0.4269  data: 0.0159  max mem: 8138
# Epoch: [68]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3464 (0.3565)  loss_classifier: 0.0656 (0.0680)  loss_box_reg: 0.0365 (0.0372)  loss_mask: 0.2040 (0.2348)  loss_objectness: 0.0059 (0.0093)  loss_rpn_box_reg: 0.0044 (0.0072)  time: 0.4253  data: 0.0154  max mem: 8138
# Epoch: [68]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3214 (0.3559)  loss_classifier: 0.0665 (0.0674)  loss_box_reg: 0.0347 (0.0369)  loss_mask: 0.2066 (0.2351)  loss_objectness: 0.0091 (0.0094)  loss_rpn_box_reg: 0.0054 (0.0071)  time: 0.4279  data: 0.0154  max mem: 8138
# Epoch: [68]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3548 (0.3563)  loss_classifier: 0.0693 (0.0675)  loss_box_reg: 0.0320 (0.0368)  loss_mask: 0.2192 (0.2358)  loss_objectness: 0.0075 (0.0094)  loss_rpn_box_reg: 0.0046 (0.0069)  time: 0.4251  data: 0.0152  max mem: 8138
# Epoch: [68]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3599 (0.3563)  loss_classifier: 0.0664 (0.0674)  loss_box_reg: 0.0364 (0.0368)  loss_mask: 0.2389 (0.2359)  loss_objectness: 0.0084 (0.0094)  loss_rpn_box_reg: 0.0051 (0.0069)  time: 0.4175  data: 0.0201  max mem: 8138
# Epoch: [68] Total time: 0:05:51 (0.4281 s / it)
# Epoch: [69]  [  0/822]  eta: 0:25:08  lr: 0.000000  loss: 0.2731 (0.2731)  loss_classifier: 0.0406 (0.0406)  loss_box_reg: 0.0290 (0.0290)  loss_mask: 0.1863 (0.1863)  loss_objectness: 0.0120 (0.0120)  loss_rpn_box_reg: 0.0053 (0.0053)  time: 1.8356  data: 1.4163  max mem: 8138
# Epoch: [69]  [200/822]  eta: 0:04:29  lr: 0.000000  loss: 0.3070 (0.3593)  loss_classifier: 0.0613 (0.0678)  loss_box_reg: 0.0341 (0.0368)  loss_mask: 0.1932 (0.2371)  loss_objectness: 0.0080 (0.0101)  loss_rpn_box_reg: 0.0054 (0.0074)  time: 0.4254  data: 0.0148  max mem: 8138
# Epoch: [69]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3426 (0.3511)  loss_classifier: 0.0617 (0.0672)  loss_box_reg: 0.0359 (0.0369)  loss_mask: 0.2316 (0.2302)  loss_objectness: 0.0055 (0.0095)  loss_rpn_box_reg: 0.0053 (0.0073)  time: 0.4245  data: 0.0146  max mem: 8138
# Epoch: [69]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3541 (0.3532)  loss_classifier: 0.0619 (0.0671)  loss_box_reg: 0.0328 (0.0367)  loss_mask: 0.2218 (0.2330)  loss_objectness: 0.0089 (0.0094)  loss_rpn_box_reg: 0.0046 (0.0070)  time: 0.4269  data: 0.0166  max mem: 8138
# Epoch: [69]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3665 (0.3553)  loss_classifier: 0.0633 (0.0674)  loss_box_reg: 0.0370 (0.0369)  loss_mask: 0.2291 (0.2350)  loss_objectness: 0.0074 (0.0091)  loss_rpn_box_reg: 0.0058 (0.0069)  time: 0.4264  data: 0.0147  max mem: 8138
# Epoch: [69]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3224 (0.3552)  loss_classifier: 0.0683 (0.0674)  loss_box_reg: 0.0404 (0.0370)  loss_mask: 0.2103 (0.2348)  loss_objectness: 0.0053 (0.0091)  loss_rpn_box_reg: 0.0043 (0.0069)  time: 0.4117  data: 0.0134  max mem: 8138
# Epoch: [69] Total time: 0:05:51 (0.4278 s / it)
# Epoch: [70]  [  0/822]  eta: 0:27:54  lr: 0.000000  loss: 0.3227 (0.3227)  loss_classifier: 0.0677 (0.0677)  loss_box_reg: 0.0446 (0.0446)  loss_mask: 0.1979 (0.1979)  loss_objectness: 0.0069 (0.0069)  loss_rpn_box_reg: 0.0056 (0.0056)  time: 2.0374  data: 1.5905  max mem: 8138
# Epoch: [70]  [200/822]  eta: 0:04:29  lr: 0.000000  loss: 0.3664 (0.3522)  loss_classifier: 0.0700 (0.0683)  loss_box_reg: 0.0392 (0.0373)  loss_mask: 0.2479 (0.2301)  loss_objectness: 0.0083 (0.0098)  loss_rpn_box_reg: 0.0033 (0.0068)  time: 0.4300  data: 0.0170  max mem: 8138
# Epoch: [70]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3213 (0.3502)  loss_classifier: 0.0614 (0.0666)  loss_box_reg: 0.0355 (0.0364)  loss_mask: 0.1920 (0.2304)  loss_objectness: 0.0058 (0.0097)  loss_rpn_box_reg: 0.0055 (0.0069)  time: 0.4305  data: 0.0173  max mem: 8159
# Epoch: [70]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3264 (0.3515)  loss_classifier: 0.0603 (0.0667)  loss_box_reg: 0.0360 (0.0363)  loss_mask: 0.2100 (0.2324)  loss_objectness: 0.0062 (0.0093)  loss_rpn_box_reg: 0.0045 (0.0068)  time: 0.4252  data: 0.0151  max mem: 8159
# Epoch: [70]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3343 (0.3549)  loss_classifier: 0.0634 (0.0672)  loss_box_reg: 0.0363 (0.0369)  loss_mask: 0.2387 (0.2346)  loss_objectness: 0.0089 (0.0094)  loss_rpn_box_reg: 0.0052 (0.0069)  time: 0.4254  data: 0.0160  max mem: 8159
# Epoch: [70]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3430 (0.3550)  loss_classifier: 0.0609 (0.0672)  loss_box_reg: 0.0319 (0.0369)  loss_mask: 0.2209 (0.2346)  loss_objectness: 0.0083 (0.0094)  loss_rpn_box_reg: 0.0052 (0.0070)  time: 0.4134  data: 0.0139  max mem: 8159
# Epoch: [70] Total time: 0:05:51 (0.4282 s / it)
# Epoch: [71]  [  0/822]  eta: 0:23:03  lr: 0.000000  loss: 0.3603 (0.3603)  loss_classifier: 0.0645 (0.0645)  loss_box_reg: 0.0481 (0.0481)  loss_mask: 0.2284 (0.2284)  loss_objectness: 0.0119 (0.0119)  loss_rpn_box_reg: 0.0075 (0.0075)  time: 1.6835  data: 1.2706  max mem: 8159
# Epoch: [71]  [200/822]  eta: 0:04:29  lr: 0.000000  loss: 0.2924 (0.3499)  loss_classifier: 0.0538 (0.0654)  loss_box_reg: 0.0285 (0.0361)  loss_mask: 0.1918 (0.2315)  loss_objectness: 0.0050 (0.0091)  loss_rpn_box_reg: 0.0056 (0.0077)  time: 0.4279  data: 0.0158  max mem: 8159
# Epoch: [71]  [400/822]  eta: 0:03:01  lr: 0.000000  loss: 0.3338 (0.3530)  loss_classifier: 0.0637 (0.0669)  loss_box_reg: 0.0398 (0.0365)  loss_mask: 0.2167 (0.2327)  loss_objectness: 0.0079 (0.0096)  loss_rpn_box_reg: 0.0051 (0.0072)  time: 0.4248  data: 0.0149  max mem: 8159
# Epoch: [71]  [600/822]  eta: 0:01:35  lr: 0.000000  loss: 0.3569 (0.3562)  loss_classifier: 0.0646 (0.0674)  loss_box_reg: 0.0326 (0.0365)  loss_mask: 0.2588 (0.2357)  loss_objectness: 0.0092 (0.0094)  loss_rpn_box_reg: 0.0050 (0.0072)  time: 0.4308  data: 0.0199  max mem: 8159
# Epoch: [71]  [800/822]  eta: 0:00:09  lr: 0.000000  loss: 0.3532 (0.3548)  loss_classifier: 0.0586 (0.0674)  loss_box_reg: 0.0359 (0.0368)  loss_mask: 0.2262 (0.2343)  loss_objectness: 0.0066 (0.0094)  loss_rpn_box_reg: 0.0045 (0.0069)  time: 0.4252  data: 0.0149  max mem: 8159
# Epoch: [71]  [821/822]  eta: 0:00:00  lr: 0.000000  loss: 0.3365 (0.3545)  loss_classifier: 0.0550 (0.0672)  loss_box_reg: 0.0359 (0.0368)  loss_mask: 0.2252 (0.2342)  loss_objectness: 0.0068 (0.0093)  loss_rpn_box_reg: 0.0048 (0.0069)  time: 0.4123  data: 0.0137  max mem: 8159
# Epoch: [71] Total time: 0:05:52 (0.4283 s / it)

# %% [markdown]
# # Mask to RLE helper

# %%
def mask_to_rle(img, width, height):
    rle = []
    lastColor = 0
    currentPixel = 0
    runStart = -1
    runLength = 0

    for x in range(width):
        for y in range(height):
            currentColor = img[x][y]
            if currentColor != lastColor:
                if currentColor == 1:
                    runStart = currentPixel
                    runLength = 1
                else:
                    rle.append(str(runStart))
                    rle.append(str(runLength))
                    runStart = -1
                    runLength = 0
                    currentPixel = 0
            elif runStart > -1:
                runLength += 1
            lastColor = currentColor
            currentPixel+=1
    return " " + " ".join(rle)

# %% [markdown]
# # Convert Model to Evaluation Mode

# %%
for param in model_ft.parameters():
    param.requires_grad = False

model_ft.eval()
# Out:
# MaskRCNN(
#   (transform): GeneralizedRCNNTransform()
#   (backbone): BackboneWithFPN(
#     (body): IntermediateLayerGetter(
#       (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#       (bn1): FrozenBatchNorm2d()
#       (relu): ReLU(inplace)
#       (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#       (layer1): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#           (downsample): Sequential(
#             (0): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#             (1): FrozenBatchNorm2d()
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#       )
#       (layer2): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(256, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#           (downsample): Sequential(
#             (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d()
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#       )
#       (layer3): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#           (downsample): Sequential(
#             (0): Conv2d(512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d()
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#         (3): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#         (4): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#         (5): Bottleneck(
#           (conv1): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#       )
#       (layer4): Sequential(
#         (0): Bottleneck(
#           (conv1): Conv2d(1024, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#           (downsample): Sequential(
#             (0): Conv2d(1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False)
#             (1): FrozenBatchNorm2d()
#           )
#         )
#         (1): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#         (2): Bottleneck(
#           (conv1): Conv2d(2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn1): FrozenBatchNorm2d()
#           (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#           (bn2): FrozenBatchNorm2d()
#           (conv3): Conv2d(512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False)
#           (bn3): FrozenBatchNorm2d()
#           (relu): ReLU(inplace)
#         )
#       )
#     )
#     (fpn): FeaturePyramidNetwork(
#       (inner_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#         (1): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#         (2): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#         (3): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#       )
#       (layer_blocks): ModuleList(
#         (0): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#         (3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       )
#       (extra_blocks): LastLevelMaxPool()
#     )
#   )
#   (rpn): RegionProposalNetwork(
#     (anchor_generator): AnchorGenerator()
#     (head): RPNHead(
#       (conv): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (cls_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (bbox_pred): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
#   (roi_heads): RoIHeads(
#     (box_roi_pool): MultiScaleRoIAlign()
#     (box_head): TwoMLPHead(
#       (fc6): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc7): Linear(in_features=1024, out_features=1024, bias=True)
#     )
#     (box_predictor): FastRCNNPredictor(
#       (cls_score): Linear(in_features=1024, out_features=2, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=8, bias=True)
#     )
#     (mask_roi_pool): MultiScaleRoIAlign()
#     (mask_head): MaskRCNNHeads(
#       (mask_fcn1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu1): ReLU(inplace)
#       (mask_fcn2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu2): ReLU(inplace)
#       (mask_fcn3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu3): ReLU(inplace)
#       (mask_fcn4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#       (relu4): ReLU(inplace)
#     )
#     (mask_predictor): MaskRCNNPredictor(
#       (conv5_mask): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (relu): ReLU(inplace)
#       (mask_fcn_logits): Conv2d(256, 2, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )

# %% [markdown]
# # Get Test Data

# %%
sample_df = pd.read_csv("sample_submission.csv")

# this part was taken from @raddar's kernel: https://www.kaggle.com/raddar/better-sample-submission
masks_ = sample_df.groupby('ImageId')['ImageId'].count().reset_index(name='N')
masks_ = masks_.loc[masks_.N >= 1].ImageId.values
###
sample_df = sample_df.drop_duplicates('ImageId', keep='last').reset_index(drop=True)

# %%
tt = transforms.ToTensor()
sublist = []
counter = 0
threshold = 0.90
for index, row in tqdm(sample_df.iterrows(), total=len(sample_df)):
    image_id = row['ImageId']
    if image_id in masks_:
        img_path = os.path.join('siim-png-images/test_png', image_id + '.png')

        img = Image.open(img_path).convert("RGB")
        width, height = img.size
        img = img.resize((1024, 1024), resample=Image.BILINEAR)
        img = tt(img)
        result = model_ft([img.to(device)])[0]
        if len(result["masks"]) > 0:
            counter += 1
            mask_added = 0
            for ppx in range(len(result["masks"])):
                if result["scores"][ppx] >= threshold:
                    mask_added += 1
                    res = transforms.ToPILImage()(result["masks"][ppx].permute(1, 2, 0).cpu().numpy())
                    res = np.asarray(res.resize((width, height), resample=Image.BILINEAR))
                    res = (res[:, :] * 255. > 127).astype(np.uint8).T
                    rle = mask_to_rle(res, width, height)
                    sublist.append([image_id, rle])
            if mask_added == 0:
                rle = " -1"
                sublist.append([image_id, rle])
        else:
            rle = " -1"
            sublist.append([image_id, rle])
    else:
        rle = " -1"
        sublist.append([image_id, rle])

submission_df = pd.DataFrame(sublist, columns=sample_df.columns.values)
submission_df.to_csv("submission-mask-rcnn-0.90.csv", index=False)
print(counter)
# Out:
# 100%|██████████| 1372/1372 [01:50<00:00, 11.77it/s]
# 1361
